# %% [markdown]
# # AWS Glue Orchestration
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lakelogic/LakeLogic/blob/main/examples/05_orchestration/aws_glue/aws_glue_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/lakelogic/LakeLogic/blob/main/examples/05_orchestration/aws_glue/aws_glue_demo.ipynb)
#
# ## Business Scenario
#
# Glue is a managed ETL scheduler in AWS. You need a template to run LakeLogic as a Glue job.
#
# ## Value Proposition
#
# - Managed AWS scheduling
# - Simple job configuration
# - Consistent LakeLogic execution
#
# ---
#
# ## Goals
#
# 1. Configure a Glue job
# 2. Run LakeLogic via the driver
# 3. Monitor Glue runs

# %% [markdown]
# ## Step 1: Review the Template
#
# These files define the orchestration configuration:
#
# - aws_glue_job.yaml

# %% [markdown]
# ## Step 2: Configure Registry and Environment
#
# Set registry path, secrets, and storage destinations for your environment.

# %%
# Example driver call
lakelogic_driver_cmd = (
    'lakelogic-driver --registry contracts/_registry.yaml '
    '--layers bronze,silver --summary-path output/run_summary.json'
)
print(lakelogic_driver_cmd)

# %% [markdown]
# ## Step 3: Deploy
#
# Apply the template in your orchestration platform and monitor runs.
