# %% [markdown]
# # Azure Data Factory
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/lakelogic/LakeLogic/blob/main/examples/05_orchestration/azure_data_factory/adf_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/lakelogic/LakeLogic/blob/main/examples/05_orchestration/azure_data_factory/adf_demo.ipynb)
#
# ## Business Scenario
#
# ADF pipelines schedule and move data in Azure. You need a pipeline template to run LakeLogic reliably.
#
# ## Value Proposition
#
# - Managed Azure orchestration
# - Pipeline-based scheduling
# - Reusable LakeLogic execution
#
# ---
#
# ## Goals
#
# 1. Review ADF pipeline JSON
# 2. Configure linked services
# 3. Deploy pipeline

# %% [markdown]
# ## Step 1: Review the Template
#
# These files define the orchestration configuration:
#
# - adf_pipeline.json
# - adf_pipeline.yaml
# - synapse_pipeline.json
# - synapse_pipeline.yaml

# %% [markdown]
# ## Step 2: Configure Registry and Environment
#
# Set registry path, secrets, and storage destinations for your environment.

# %%
# Example driver call
lakelogic_driver_cmd = (
    'lakelogic-driver --registry contracts/_registry.yaml '
    '--layers bronze,silver --summary-path output/run_summary.json'
)
print(lakelogic_driver_cmd)

# %% [markdown]
# ## Step 3: Deploy
#
# Apply the template in your orchestration platform and monitor runs.
