# %% [markdown]
# ⏱️ **Time required:** ~3 minutes | **Type:** Domain pipeline (run all cells)

# %% [markdown]
# # 🚗 RideFlow Marketplace — Domain Pipeline
#
# **Domain Owner:** Marketplace Engineering
# **System:** rideflow
#
# This notebook represents the **Marketplace domain team's** autonomous pipeline. It generates synthetic ride-sharing data, processes it through the full Medallion architecture (Bronze → Silver → Gold), and publishes **Data Products** that other domains can consume.
#
# | Published Data Product | Layer | Description |
# | :-- | :-- | :-- |
# | `silver_rideflow_trips` | Silver | Deduplicated, typed trip fact table |
# | `silver_rideflow_driver_profiles` | Silver | Cleaned driver dimension |
# | `silver_rideflow_rider_profiles` | Silver | Cleaned rider dimension |
# | `gold_rideflow_trip_kpis` | Gold | Revenue, volume, distance KPIs |
# | `gold_rideflow_rider_lifetime_value` | Gold | Rider LTV analysis |
# | `gold_rideflow_surge_pricing_model` | Gold | Dynamic surge multipliers |

# %% [markdown]
# ---
# ## Step 1 · Environment Setup
#
# Install dependencies, detect runtime (Colab vs local), and configure paths.

# %%
import os, subprocess, sys

# ── Install lakelogic ─────────────────────────────────────────────────
# Update the path below to match your local lakelogic checkout.
# On Colab (or if the path doesn't exist), falls back to PyPI.
_LAKELOGIC_LOCAL = r"C:\_Personal\_SaaS\lakelogic"

if os.path.isdir(_LAKELOGIC_LOCAL):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", _LAKELOGIC_LOCAL, "-q"])
    print(f"\u2705 Installed lakelogic (editable) from {_LAKELOGIC_LOCAL}")
else:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "lakelogic", "-q"])
    print("\u2705 Installed lakelogic from PyPI")
# Out:
# ✅ Installed lakelogic (editable) from C:\_Personal\_SaaS\lakelogic

# %%
import subprocess, sys, importlib, os

# Install LakeLogic + dashboard dependencies if missing
for pkg in ["lakelogic", "panel", "hvplot", "pyparsing"]:
    if importlib.util.find_spec(pkg) is None:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", f"{pkg}[polars]" if pkg == "lakelogic" else pkg])

# Detect environment
IN_COLAB = "google.colab" in sys.modules
print(f"Running in: {'Google Colab' if IN_COLAB else 'Local'}")


import _setup as s
# Out:
# Running in: Local
# lakelogic v1.18.0 | Local | c:\_Personal\_SaaS\lakelogic\examples\colab

# %%
import panel as pn
import polars as pl
import lakelogic as ll
from pathlib import Path
from datetime import datetime, timezone

# Panel init — use colab comms if in Colab
if IN_COLAB:
    pn.extension('tabulator', comms='colab')
else:
    pn.extension('tabulator', design='bootstrap')

# Paths
DOMAIN_ROOT = Path("assets/domains_rideflow/marketplace/rideflow")
SYSTEM_YAML = str(DOMAIN_ROOT / "_system.yaml")
LAKEHOUSE = Path("./lakehouse")
LANDING_ROOT = LAKEHOUSE / "_data" / "landing_marketplace" / "rideflow"

print(f"lakelogic v{ll.__version__}")
print(f"Lakehouse: {LAKEHOUSE.resolve()}")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a112f63c-5d87-48ae-a0ef-32139a39cac3'>
#   <div id="c9d3bc6a-244e-451d-a64a-36d31ce21c96" data-root-id="a112f63c-5d87-48ae-a0ef-32139a39cac3" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0a64d1dd-9067-4e0e-942f-dbda182bf8ea":{"version":"3.9.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"9e0e1502-89e9-4532-9c01-a5b057dac9dc","attributes":{"notifications":{"type":"object","name":"Notifications","id":"597ce42c-626f-4391-9cda-9c5ac802601f"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"a112f63c-5d87-48ae-a0ef-32139a39cac3"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"f3c2ebf6-cc95-4e3b-8b04-f764e9344b32","attributes":{"plot_id":"a112f63c-5d87-48ae-a0ef-32139a39cac3","comm_id":"692e84d1bbd74a3f896c320fe5c14cca","client_comm_id":"03a6124cb83e4ab29a05d031d4282000"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"0a64d1dd-9067-4e0e-942f-dbda182bf8ea","roots":{"a112f63c-5d87-48ae-a0ef-32139a39cac3":"c9d3bc6a-244e-451d-a64a-36d31ce21c96"},"root_ids":["a112f63c-5d87-48ae-a0ef-32139a39cac3"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# lakelogic v1.18.0
# Lakehouse: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse

# %% [markdown]
# ---
# ## Step 2 · Load the Data Contract Registry
#
# The `_system.yaml` registry is the single source of truth for this entire platform.
# It declares every entity, its schema contract, lineage rules, materialization strategy, and cost model.
#
# > Changing the `environment` parameter is all it takes to switch between local prototyping and Azure production.

# %%
from lakelogic.core.registry import DomainRegistry

ENV = "colab" if IN_COLAB else "local"
registry = DomainRegistry.from_yaml(SYSTEM_YAML, environment=ENV, storage_mode="direct")

print(f"Domain:  {registry.domain}")
print(f"System:  {registry.system}")
print(f"Env:     {ENV}")
print(f"\nContracts loaded: {len(registry.get_active_contracts())}")
for c in registry.get_active_contracts():
    print(f"  [{c.layer:6s}] {c.entity}")
# Out:
# 2026-04-27 05:31:56.033 | INFO     | lakelogic.core.registry:from_yaml:402 - Domain config inherited from assets\domains_rideflow\marketplace\_domain.yaml
# Domain:  marketplace
# System:  rideflow
# Env:     local
#
# Contracts loaded: 15
#   [bronze] rider_profiles
#   [bronze] rider_app_events
#   [bronze] driver_profiles
#   [bronze] driver_telemetry
#   [bronze] trip_requests
#   [bronze] trip_completed
#   [bronze] trip_cancellations
#   [silver] silver_rideflow_driver_profiles
#   [silver] silver_rideflow_driver_telemetry
#   [silver] silver_rideflow_rider_profiles
#   [silver] silver_rideflow_trips
#   [gold  ] gold_rideflow_trip_kpis
#   [gold  ] gold_rideflow_driver_scorecard
#   [gold  ] gold_rideflow_rider_daily_metrics
#   [gold  ] gold_rideflow_surge_pricing_model

# %% [markdown]
# ---
# ## Step 3 · Pipeline Lineage DAG
#
# An interactive topological map of the RideFlow Data Mesh, automatically generated from the declarative `depends_on` rules in the Data Contracts.

# %%
from IPython.display import HTML
from lakelogic.pipeline.runner import LakehousePipeline

pipeline = LakehousePipeline(registry)
display(HTML(pipeline.visualize_dag(title="")))
# Out:
# 2026-04-27 05:32:08.318 | DEBUG    | lakelogic.pipeline.runner:__init__:176 - Disabled DeletionVectors by default in Spark session for OSS compatibility.
#         <div style="font-family:'Inter','Segoe UI',sans-serif;background:#0d0d0f;
#              background-image:radial-gradient(circle at 1px 1px,#1a1a1f 1px,transparent 0);
#              background-size:24px 24px;padding:30px 30px 20px;border-radius:12px;position:relative;overflow-x:auto;">
#           <h2 style="color:#fff;font-size:1.2rem;margin:0 0 4px;"
#               >📊 Pipeline DAG — marketplace / rideflow</h2>
#           <p style="color:#666;font-size:0.8rem;margin:0 0 24px;">15 contracts • 3 layers</p>
#           <div style="position:relative;width:2050px;height:1310px;">
#             <div style="position:absolute;left:50px;top:4px;font-size:0.65rem;font-weight:700;color:#2dd4bf;letter-spacing:0.1em;opacity:0.6;">EXTERNAL</div><div style="position:absolute;left:460px;top:4px;font-size:0.65rem;font-weight:700;color:#daa520;letter-spacing:0.1em;opacity:0.6;">BRONZE</div><div style="position:absolute;left:870px;top:4px;font-size:0.65rem;font-weight:700;color:#8fa4b8;letter-spacing:0.1em;opacity:0.6;">SILVER</div><div style="position:absolute;left:1280px;top:4px;font-size:0.65rem;font-weight:700;color:#ffd700;letter-spacing:0.1em;opacity:0.6;">GOLD</div>
#             <svg style="position:absolute;top:0;left:0;width:100%;
#                         height:100%;pointer-events:none;"
#                  viewBox="0 0 2050 1310">
#               <defs>
#                 <marker id="dag-arrow" viewBox="0 0 12 10"
#                         refX="11" refY="5" markerWidth="10"
#                         markerHeight="8" orient="auto-start-reverse">
#                   <path d="M 0 0 L 12 5 L 0 10 z" fill="#555"/>
#                 </marker>
#                 <marker id="dag-arrow-dep" viewBox="0 0 12 10"
#                         refX="11" refY="5" markerWidth="10"
#                         markerHeight="8" orient="auto-start-reverse">
#                   <path d="M 0 0 L 12 5 L 0 10 z" fill="#4a9eff"/>
#                 </marker>
#               </defs>
#               <path d="M 1010,150 C 1210,190 1210,190 1010,230" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1010,510 C 1210,550 1210,550 1010,590" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1010,150 C 1210,190 1210,550 1010,590" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,640 C 1230,640 1200,100 1280,100" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,640 C 1230,640 1200,280 1280,280" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,100 C 1230,100 1200,280 1280,280" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,640 C 1230,640 1200,460 1280,460" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,460 C 1230,460 1200,460 1280,460" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 740,460 C 820,460 790,100 870,100" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 740,640 C 820,640 790,280 870,280" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 740,100 C 820,100 790,460 870,460" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 740,1000 C 820,1000 790,640 870,640" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,100 460,100" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,280 460,280" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,460 460,460" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,640 460,640" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,820 460,820" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,1000 460,1000" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,1180 460,1180" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 1560,460 C 1640,460 1610,200 1690,200" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 1560,460 C 1640,460 1610,380 1690,380" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
#
#             </svg>
#
#             <div class="dag-node"
#                  style="left:460px;top:50px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="background:#22c55e;box-shadow:0 0 6px #22c55e;"
#                    ></div>
#               <div class="dag-hdr">
#                 <div class="dag-icon" style="background:#b8860b22;color:#daa520;">📋</div>
#                 <div class="dag-ttl">Bronze — RideFlow Rider Profiles</div>
#               </div>
#               <div class="dag-sys">RIDEFLOW</div>
#               <div class="dag-badges">
#                 <span class="dag-badge" style="background:#b8860b33;color:#daa520;">BRONZE</span>
#                 <span class="dag-badge dag-badge-ver">📄 V1.0.0</span>
#
#                 <span class="dag-badge dag-badge-pii">🔒 6 PII</span>
#               </div>
#             </div>
#             <div class="dag-node"
#                  style="left:460px;top:230px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="background:#22c55e;box-shadow:0 0 6px #22c55e;"
#                    ></div>
#               <div class="dag-hdr">
#                 <div class="dag-icon" style="background:#b8860b22;color:#daa520;">📋</div>
#                 <div class="dag-ttl">Bronze — RideFlow Rider App Events</div>
#               </div>
#               <div class="dag-sys">RIDEFLOW</div>
#               <div class="dag-badges">
#                 <span class="dag-badge" style="background:#b8860b33;color:#daa520;">BRONZE</span>
#                 <span class="dag-badge dag-badge-ver">📄 V1.0.0</span>
#
#                 <span class="dag-badge dag-badge-pii">🔒 1 PII</span>
#               </div>
#             </div>
#             <div class="dag-node"
#                  style="left:460px;top:410px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="background:#22c55e;box-shadow:0 0 6px #22c55e;"
#                    ></div>
#               <div class="dag-hdr">
#                 <div class="dag-icon" style="background:#b8860b22;color:#daa520;">📋</div>
#                 <div class="dag-ttl">Bronze — RideFlow Driver Profiles</div>
#               </div>
#               <div class="dag-sys">RIDEFLOW</div>
#               <div class="dag-badges">
#                 <span class="dag-badge" style="background:#b8860b33;color:#daa520;">BRONZE</span>
#                 <span class="dag-badge dag-badge-ver">📄 V1.0.0</span>
#
#                 <span class="dag-badge dag-badge-pii">🔒 7 PII</span>
#               </div>
#             </div>
#             <div class="dag-node"
#                  style="left:460px;top:590px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="back

# %% [markdown]
# ---
# ## Step 4 · Generate Streaming Data
#
# The `StreamingSimulator` generates **24 hours** of realistic ride-sharing data:
# - **Dimension entities** (riders, drivers) with stable identity pools
# - **Fact entities** (trip requests → completions → cancellations) following hour-of-day demand curves
# - **Event entities** (telemetry, app events) proportional to active trips
#
# All entities maintain **referential integrity** — every `rider_id` in a trip exists in the rider pool.

# %%
from lakelogic.core.streaming import StreamingSimulator
from datetime import timedelta

sim = StreamingSimulator.rideflow_marketplace(
    landing_root=str(LANDING_ROOT),
    window_minutes=60,
    start_time=datetime.now(timezone.utc) - timedelta(days=3),
    seed=42,
    initial_riders=200,
    initial_drivers=100,
)

print("🚀 Streaming simulator configured")
print(f"   Landing root: {LANDING_ROOT}")
print(f"   Window size:  60 minutes")
print(f"   Entities:     7 (2 dimensions, 3 facts, 2 events)")
# Out:
# 🚀 Streaming simulator configured
#    Landing root: lakehouse\_data\landing_marketplace\rideflow
#    Window size:  60 minutes
#    Entities:     7 (2 dimensions, 3 facts, 2 events)

# %%
# Generate 24 hours of simulated streaming data
NUM_WINDOWS = 24

total_rows = 0
windows = []
for window in sim.run(num_windows=NUM_WINDOWS, micro_batches=10, up_to=datetime.now(timezone.utc), resume=True):
    windows.append(window)
    total_rows += window.total_rows

print(f"\n{'='*60}")
if not windows:
    print("✅ No new windows generated. The simulator has caught up to the current time (up_to constraint reached).")
else:
    print(f"✅ Generated {total_rows:,} total rows across {len(windows)} windows")
    print(f"   Seed window:    {windows[0].total_rows:,} rows (initial pool)")
    print(f"   Avg per window: {total_rows // len(windows):,} rows")

# FK consistency check
fk = sim.validate_fk_consistency()
print(f"\n🔗 FK Consistency:")
print(f"   Riders:    {fk['total_riders']}")
print(f"   Drivers:   {fk['total_drivers']}")
print(f"   Healthy:   {'✅' if fk['fk_pools_healthy'] else '❌'}")
# Out:
# 2026-04-27 05:32:08.398 | INFO     | lakelogic.core.streaming:_rebuild_state_from_landing:808 - Resumed: 0 riders, 0 drivers rebuilt. Next window: 2026-04-25T03:00:00+00:00
# 2026-04-27 05:32:08.410 | INFO     | lakelogic.core.streaming:_seed_initial_pools:608 - 🌱 Seeded initial pools: 200 riders, 100 drivers
# 2026-04-27 05:32:08.459 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   0 | 2026-04-25 03:00 |   287 rows | rider_profiles=6 driver_profiles=2 trip_requests=31 trip_completed=21 trip_cancellations=4 driver_telemetry=150 rider_app_events=73 | 10 micro-batches/entity
# 2026-04-27 05:32:08.506 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   1 | 2026-04-25 04:00 |   270 rows | rider_profiles=6 driver_profiles=2 trip_requests=28 trip_completed=22 trip_cancellations=4 driver_telemetry=146 rider_app_events=62 | 10 micro-batches/entity
# 2026-04-27 05:32:08.553 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   2 | 2026-04-25 05:00 |   338 rows | rider_profiles=6 driver_profiles=2 trip_requests=27 trip_completed=25 trip_cancellations=4 driver_telemetry=203 rider_app_events=71 | 10 micro-batches/entity
# 2026-04-27 05:32:08.606 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   3 | 2026-04-25 06:00 |   364 rows | rider_profiles=6 driver_profiles=2 trip_requests=44 trip_completed=27 trip_cancellations=5 driver_telemetry=193 rider_app_events=87 | 10 micro-batches/entity
# 2026-04-27 05:32:08.673 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   4 | 2026-04-25 07:00 |   567 rows | rider_profiles=6 driver_profiles=2 trip_requests=55 trip_completed=42 trip_cancellations=9 driver_telemetry=317 rider_app_events=136 | 10 micro-batches/entity
# 2026-04-27 05:32:08.752 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   5 | 2026-04-25 08:00 |   848 rows | rider_profiles=6 driver_profiles=2 trip_requests=91 trip_completed=60 trip_cancellations=12 driver_telemetry=491 rider_app_events=186 | 10 micro-batches/entity
# 2026-04-27 05:32:08.895 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   6 | 2026-04-25 09:00 |   654 rows | rider_profiles=7 driver_profiles=2 trip_requests=68 trip_completed=51 trip_cancellations=11 driver_telemetry=369 rider_app_events=146 | 10 micro-batches/entity
# 2026-04-27 05:32:09.080 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   7 | 2026-04-25 10:00 |   615 rows | rider_profiles=7 driver_profiles=2 trip_requests=60 trip_completed=50 trip_cancellations=7 driver_telemetry=369 rider_app_events=120 | 10 micro-batches/entity
# 2026-04-27 05:32:09.363 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   8 | 2026-04-25 11:00 |   617 rows | rider_profiles=7 driver_profiles=2 trip_requests=72 trip_completed=59 trip_cancellations=10 driver_telemetry=320 rider_app_events=147 | 10 micro-batches/entity
# 2026-04-27 05:32:09.564 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   9 | 2026-04-25 12:00 |   630 rows | rider_profiles=7 driver_profiles=2 trip_requests=76 trip_completed=49 trip_cancellations=8 driver_telemetry=336 rider_app_events=152 | 10 micro-batches/entity
# 2026-04-27 05:32:09.772 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  10 | 2026-04-25 13:00 |   662 rows | rider_profiles=7 driver_profiles=2 trip_requests=59 trip_completed=57 trip_cancellations=8 driver_telemetry=409 rider_app_events=120 | 10 micro-batches/entity
# 2026-04-27 05:32:09.933 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  11 | 2026-04-25 14:00 |   595 rows | rider_profiles=8 driver_profiles=2 trip_requests=74 trip_completed=55 trip_cancellations=7 driver_telemetry=337 rider_app_events=112 | 10 micro-batches/entity
# 2026-04-27 05:32:10.037 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  12 | 2026-04-25 15:00 |   675 rows | rider_profiles=8 driver_profiles=2 trip_requests=72 trip_completed=57 trip_cancellations=7 driver_telemetry=389 rider_app_events=140 | 10 micro-batches/entity
# 2026-04-27 05:32:10.169 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  13 | 2026-04-25 16:00 |   748 rows | rider_profiles=8 driver_profiles=2 trip_requests=85 trip_completed=64 trip_cancellations=9 driver_telemetry=454 rider_app_events=126 | 10 micro-batches/entity
# 2026-04-27 05:32:10.265 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  14 | 2026-04-25 17:00 |   870 rows | rider_profiles=8 driver_profiles=2 trip_requests=85 trip_completed=76 trip_cancellations=12 driver_telemetry=506 rider_app_events=181 | 10 micro-batches/entity
# 2026-04-27 05:32:10.413 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  15 | 2026-04-25 18:00 |   839 rows | rider_profiles=9 driver_profiles=2 trip_requests=97 trip_completed=74 trip_cancellations=12 driver_telemetry=452 rider_app_events=193 | 10 micro-batches/entity
# 2026-04-27 05:32:10.517 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  16 | 2026-04-25 19:00 |   719 rows | rider_profiles=9 driver_profiles=2 trip_requests=95 trip_completed=66 trip_cancellations=9 driver_telemetry=406 rider_app_events=132 | 10 micro-batches/entity
# 2026-04-27 05:32:10.610 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  17 | 2026-04-25 20:00 |   686 rows | rider_profiles=9 driver_profiles=2 trip_requests=64 trip_completed=56 trip_cancellations=9 driver_telemetry=430 rider_app_events=116 | 10 micro-batches/entity
# 2026-04-27 05:32:10.686 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  18 | 2026-04-25 21:00 |   539 rows | rider_profiles=9 driver_profiles=2 trip_requests=53 trip_completed=44 trip_cancellations=9 driver_telemetry=304 rider_app_events=118 | 10 micro-batches/entity
# 2026-04-27 05:32:10.769 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  19 | 2026-04-25 22:00 |   432 rows | rider_profiles=10 driver_profiles=2 trip_requests=45 trip_completed=37 trip_cancellations=7 driver_telemetry=243 rider_app_events=88 | 10 micro-batches/entity
# 2026-04-27 05:32:10.828 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  20 | 2026-04-25 23:00 |   380 rows | rider_profiles=10 driver_profiles=2 trip_requests=42 trip_completed=32 trip_cancellations=5 driver_telemetry=214 rider_app_events=75 | 10 micro-batches/entity
# 2026-04-27 05:32:10.893 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  21 | 2026-04-26 00:00 |   379 rows | rider_profiles=10 driver_profiles=2 trip_requests=34 trip_completed=28 trip_cancellations=5 driver_telemetry=223 rider_app_events=77 | 10 micro-batches/entity
# 2026-04-27 05:32:10.953 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  22 | 2026-04-26 01:00 |   354 rows | rider_profiles=11 driver_profiles=2 trip_requests=30 trip_completed=26 trip_cancellations=5 driver_telemetry=201 rider_app_events=79 | 10 micro-batches/entity
# 2026-04-27 05:32:11.006 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  23 | 2026-04-26 02:00 |   317 rows | rider_profiles=11 driver_profiles=2 trip_requests=29 trip_completed=25 trip_cancellations=5 driver_telemetry=180 rider_app_events=65 | 10 micro-batches/entity
# ============================================================
# ✅ Generated 13,685 total rows across 25 windows
#    Seed window:    300 rows (initial pool)
#    Avg per window: 547 rows
#
# 🔗 FK Consistency:
#    Riders:    391
#    Drivers:   148
#    Healthy:   ✅

# %%
# Verify partition structure
import glob

for entity in ["trip_requests", "trip_completed", "rider_profiles"]:
    files = glob.glob(str(LANDING_ROOT / entity / "**/*.csv"), recursive=True)
    print(f"  {entity}: {len(files)} partition files")
    if files:
        # Show first and last partition path
        files.sort()
        print(f"    First: {files[0].split(entity)[-1]}")
        print(f"    Last:  {files[-1].split(entity)[-1]}")
# Out:
#   trip_requests: 230 partition files
#     First: \y_2026\m_04\d_25\h_03\batch_00_a5c5d5.csv
#     Last:  \y_2026\m_04\d_26\h_02\batch_09_b98574.csv
#   trip_completed: 226 partition files
#     First: \y_2026\m_04\d_25\h_03\batch_00_44f5dd.csv
#     Last:  \y_2026\m_04\d_26\h_02\batch_08_2e418e.csv
#   rider_profiles: 182 partition files
#     First: \y_2026\m_04\d_25\h_03\batch_00_4b51aa.csv
#     Last:  \y_2026\m_04\d_26\h_02\batch_05_1f9e3a.csv

# %% [markdown]
# ---
# ## Step 4.5 · Inject Deterministic Edge Cases (TC-001 to TC-008)
#
# The StreamingSimulator above generated realistic, time-aware trip data with organic variance.
# Now we surgically inject **exactly 800 edge-case rows** into the `trip_completed` landing directory.
# These represent 8 specific failure modes that the pipeline's quarantine layer must catch:
#
# | TC | Description | Rows | What the pipeline should catch |
# | :-- | :-- | --: | :-- |
# | TC-001 | Negative fare | 120 | Business logic: `fare_amount >= 0` |
# | TC-002 | driver_id = rider_id | 80 | Self-service fraud detection |
# | TC-003 | Dropoff before pickup | 150 | Temporal sanity: `dropoff_at > pickup_at` |
# | TC-004 | Distance > 500km | 100 | Geospatial bounds check |
# | TC-005 | SQL injection in notes | 150 | Security / input sanitization |
# | TC-006 | Surge > 5.0x | 80 | Cap violation: `surge_multiplier <= 5.0` |
# | TC-007 | Unknown city code | 60 | Referential integrity check |
# | TC-008 | Duplicate trip_id | 60 | Idempotency / uniqueness constraint |
#
# After the pipeline runs, we expect:
# ```
# source_count = good_count + bad_count
# "100% reconciliation. Every row accounted for."
# ```

# %%
# ── Deterministic Edge-Case Injection ────────────────────────────────────
# Injects exactly 800 mutated rows into the trip_completed landing zone
# so the pipeline quarantine layer can demonstrate 100% reconciliation.

import polars as pl
import uuid, random
from datetime import datetime, timedelta, timezone

random.seed(42)
NUM_EDGE_CASES = 800

CITY_PROFILES = {
    "LON": {"timezone": "Europe/London",   "base_trips_per_hour": 500},
    "NYC": {"timezone": "US/Eastern",      "base_trips_per_hour": 800},
    "BER": {"timezone": "Europe/Berlin",   "base_trips_per_hour": 200},
    "PAR": {"timezone": "Europe/Paris",    "base_trips_per_hour": 350},
    "TYO": {"timezone": "Asia/Tokyo",      "base_trips_per_hour": 600},
    "SYD": {"timezone": "Australia/Sydney", "base_trips_per_hour": 150},
}

cities = list(CITY_PROFILES.keys())
base_time = datetime(2026, 4, 15, 8, 0, tzinfo=timezone.utc)

# Generate 800 base rows with valid structure
records = []
for i in range(NUM_EDGE_CASES):
    trip_id = str(uuid.uuid4())
    rider_id = f"R-{uuid.uuid4().hex[:8]}"
    driver_id = f"D-{uuid.uuid4().hex[:8]}"
    city = random.choice(cities)
    hr = random.choices(range(24), weights=[1,1,1,1,1,1,1,3,3,1,1,1,1,1,1,1,1,3,4,4,3,1,1,1])[0]
    req_dt = base_time.replace(hour=hr, minute=random.randint(0, 59))
    pickup_dt = req_dt + timedelta(minutes=random.randint(1, 10))
    dropoff_dt = req_dt + timedelta(minutes=random.randint(15, 60))

    records.append({
        "trip_id": trip_id,
        "rider_id": rider_id,
        "driver_id": driver_id,
        "trip_type": random.choice(["ride", "eats_delivery"]),
        "pickup_lat": str(round(random.uniform(51.4, 51.6), 6)),
        "pickup_lng": str(round(random.uniform(-0.2, 0.1), 6)),
        "dropoff_lat": str(round(random.uniform(51.4, 51.6), 6)),
        "dropoff_lng": str(round(random.uniform(-0.2, 0.1), 6)),
        "city_code": city,
        "requested_at": req_dt.strftime("%Y-%m-%dT%H:%M:%SZ"),
        "pickup_at": pickup_dt.strftime("%Y-%m-%dT%H:%M:%SZ"),
        "dropoff_at": dropoff_dt.strftime("%Y-%m-%dT%H:%M:%SZ"),
        "distance_km": str(round(random.uniform(1, 25), 1)),
        "duration_minutes": str(random.randint(5, 45)),
        "fare_amount": str(round(random.uniform(5, 80), 2)),
        "surge_multiplier": str(round(random.uniform(1.0, 3.5), 2)),
        "tip_amount": str(round(random.uniform(0, 10), 2)),
        "payment_method": random.choice(["card", "apple_pay", "google_pay", "cash"]),
        "rider_rating": str(random.randint(1, 5)),
        "driver_rating": str(random.randint(1, 5)),
        "notes": "",
    })

# ── Apply TC-001 to TC-008 mutations ──────────────────────────────────────
for i in range(0, 120):   records[i]["fare_amount"] = "-15.50"               # TC-001: Negative fare
for i in range(120, 200): records[i]["driver_id"] = records[i]["rider_id"]    # TC-002: Self-service fraud
for i in range(200, 350):                                                      # TC-003: Time travel
    records[i]["pickup_at"]  = "2026-04-15T12:00:00Z"
    records[i]["dropoff_at"] = "2026-04-15T11:00:00Z"
for i in range(350, 450): records[i]["distance_km"] = "650.5"                 # TC-004: Impossible trip
for i in range(450, 600): records[i]["notes"] = "DROP TABLE trips; SELECT * FROM users;"  # TC-005
for i in range(600, 680): records[i]["surge_multiplier"] = "5.8"              # TC-006: Cap violation
for i in range(680, 740): records[i]["city_code"] = "XYZ"                     # TC-007: Unknown market
dup_id = records[0]["trip_id"]  # Reuse first trip's ID
for i in range(740, 800): records[i]["trip_id"] = dup_id                      # TC-008: Duplicate ID

random.shuffle(records)
edge_df = pl.DataFrame(records)

# Write to the trip_completed landing directory as a separate partition file
edge_dir = LANDING_ROOT / "trip_completed" / "y_2026" / "m_04" / "d_15" / "h_99"
edge_dir.mkdir(parents=True, exist_ok=True)
edge_file = edge_dir / "edge_cases.csv"
edge_df.write_csv(str(edge_file))

print(f"\u2705 Injected {NUM_EDGE_CASES} deterministic edge cases into landing zone")
print(f"   File: {edge_file}")
print()
print(f"   TC-001  Negative fare:         120 rows")
print(f"   TC-002  driver_id=rider_id:      80 rows")
print(f"   TC-003  Dropoff before pickup:  150 rows")
print(f"   TC-004  Distance > 500km:       100 rows")
print(f"   TC-005  SQL injection in notes: 150 rows")
print(f"   TC-006  Surge > 5.0x:            80 rows")
print(f"   TC-007  Unknown city code:        60 rows")
print(f"   TC-008  Duplicate trip_id:        60 rows")
print(f"   {'='*45}")
print(f"   TOTAL edge cases:               {NUM_EDGE_CASES} rows")
# Out:
# ✅ Injected 800 deterministic edge cases into landing zone
#    File: lakehouse\_data\landing_marketplace\rideflow\trip_completed\y_2026\m_04\d_15\h_99\edge_cases.csv
#
#    TC-001  Negative fare:         120 rows
#    TC-002  driver_id=rider_id:      80 rows
#    TC-003  Dropoff before pickup:  150 rows
#    TC-004  Distance > 500km:       100 rows
#    TC-005  SQL injection in notes: 150 rows
#    TC-006  Surge > 5.0x:            80 rows
#    TC-007  Unknown city code:        60 rows
#    TC-008  Duplicate trip_id:        60 rows
#    =============================================
#    TOTAL edge cases:               800 rows

# %% [markdown]
# ---
# ## Pipeline Config
#
# - **retry_attempts**: Max retries if a dataset fails due to temporary network or storage glitches.
# - **retry_base_wait_seconds**: Initial wait time before retrying. Automatically scales up (e.g., 5s, 10s, 20s) to avoid overwhelming the system.
# - **parallel**: Processes independent datasets simultaneously across multiple CPU threads for much faster ingestion.
# - **engine**: Defines the compute backend (`polars` for local speed, `spark` for distributed clusters).
# - **reload_layers**: Forces a complete historical wipe and reload of specific layers (e.g., `"silver,gold"`).

# %%
retry_attempts = 1
parallel = False
retry_base_wait_seconds = 5
engine = "duckdb"
reload_layers = ""
enable_incremental_streaming = False

# %% [markdown]
# ---
# ## Step 5 · Bronze Ingestion
#
# Ingest the streaming landing data into Bronze Delta tables. Every row gets lineage columns (`_lakelogic_source`, `_lakelogic_processed_at`, `_lakelogic_run_id`) automatically injected.

# %%
from lakelogic.pipeline.runner import LakehousePipeline
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

print("Starting Bronze Ingestion via LakeLogic Pipeline Driver...")
runner = LakehousePipeline(registry, engine=engine)

summary = runner.run(
    target_layers="bronze", 
    reload_layers = reload_layers,
    dry_run=False,
    environment=ENV,
    retry_attempts=retry_attempts,
    retry_base_wait_seconds=retry_base_wait_seconds,
    parallel=False
)
print(summary)
# Out:
# 2026-04-27 05:32:11.199 | INFO     | lakelogic.pipeline.runner:run:1479 - Pipeline storage mode: direct
# 2026-04-27 05:32:11.202 | INFO     | lakelogic.pipeline.runner:run:1580 - ── Processing Layer: BRONZE (7 contracts) ──
# 2026-04-27 05:32:11.205 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:11.206 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [bronze] rider_profiles | Contract: Bronze — RideFlow Rider Profiles v1.0.0
# Starting Bronze Ingestion via LakeLogic Pipeline Driver...
# 2026-04-27 05:32:11.273 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\rider_profiles via duckdb
# 2026-04-27 05:32:11.428 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2984 - Date-partitioned scan: no files found in 24 partitions (2026-04-27 to 2026-04-27)
# 2026-04-27 05:32:11.429 | INFO     | lakelogic.core.processor:run_source:1478 - No source files found in partitioned path; skipping run.
# 2026-04-27 05:32:11.674 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:11.676 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:11.677 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:11.678 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for rider_profiles - proceeding to ensure target schema existence.
# 2026-04-27 05:32:11.680 | INFO     | lakelogic.core.materialization:materialize_dataframe:3145 - Materialization skipped: dataframe has no columns (empty incremental batch).
# 2026-04-27 05:32:11.683 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:11.759 | INFO     | lakelogic.pipeline.runner:_execute_post_ingestion_cleanup:1849 -   🧹 Post-ingestion: deleted landing files for rider_profiles
# 2026-04-27 05:32:11.769 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:11.770 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [bronze] rider_app_events | Contract: Bronze — RideFlow Rider App Events v1.0.0
# 2026-04-27 05:32:11.792 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\rider_app_events via duckdb
# 2026-04-27 05:32:12.038 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2984 - Date-partitioned scan: no files found in 24 partitions (2026-04-27 to 2026-04-27)
# 2026-04-27 05:32:12.039 | INFO     | lakelogic.core.processor:run_source:1478 - No source files found in partitioned path; skipping run.
# 2026-04-27 05:32:12.387 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:12.392 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:12.393 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:12.397 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for rider_app_events - proceeding to ensure target schema existence.
# 2026-04-27 05:32:12.400 | INFO     | lakelogic.core.materialization:materialize_dataframe:3145 - Materialization skipped: dataframe has no columns (empty incremental batch).
# 2026-04-27 05:32:12.402 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:12.497 | INFO     | lakelogic.pipeline.runner:_execute_post_ingestion_cleanup:1849 -   🧹 Post-ingestion: deleted landing files for rider_app_events
# 2026-04-27 05:32:12.504 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:12.505 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [bronze] driver_profiles | Contract: Bronze — RideFlow Driver Profiles v1.0.0
# 2026-04-27 05:32:12.536 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\driver_profiles via duckdb
# 2026-04-27 05:32:12.684 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2984 - Date-partitioned scan: no files found in 24 partitions (2026-04-27 to 2026-04-27)
# 2026-04-27 05:32:12.685 | INFO     | lakelogic.core.processor:run_source:1478 - No source files found in partitioned path; skipping run.
# 2026-04-27 05:32:12.909 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:12.911 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:12.913 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:12.916 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for driver_profiles - proceeding to ensure target schema existence.
# 2026-04-27 05:32:12.917 | INFO     | lakelogic.core.materialization:materialize_dataframe:3145 - Materialization skipped: dataframe has no columns (empty incremental batch).
# 2026-04-27 05:32:12.918 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:12.944 | INFO     | lakelogic.pipeline.runner:_execute_post_ingestion_cleanup:1849 -   🧹 Post-ingestion: deleted landing files for driver_profiles
# 2026-04-27 05:32:12.953 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:12.955 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [bronze] driver_telemetry | Contract: Bronze — RideFlow Driver Telemetry v1.0.0
# 2026-04-27 05:32:12.975 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\driver_telemetry via duckdb
# 2026-04-27 05:32:13.078 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2984 - Date-partitioned scan: no files found in 24 partitions (2026-04-27 to 2026-04-27)
# 2026-04-27 05:32:13.079 | INFO     | lakelogic.core.processor:run_source:1478 - No source files found in partitioned path; skipping run.
# 2026-04-27 05:32:13.273 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:13.274 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:13.274 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:13.275 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for driver_telemetry - proceeding to ensure target schema existence.
# 2026-04-27 05:32:13.277 | INFO     | lakelogic.core.materialization:materialize_dataframe:3145 - Materialization skipped: dataframe has no columns (empty incremental batch).
# 2026-04-27 05:32:13.279 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:13.343 | INFO     | lakelogic.pipeline.runner:_execute_post_ingestion_cleanup:1849 -   🧹 Post-ingestion: deleted landing files for driver_telemetry
# 2026-04-27 05:32:13.352 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:13.353 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [bronze] trip_requests | Contract: Bronze — RideFlow Trip Requests v1.0.0
# 2026-04-27 05:32:13.382 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\trip_requests via duckdb
# 2026-04-27 05:32:13.607 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2984 - Date-partitioned scan: no files found in 24 partitions (2026-04-27 to 2026-04-27)
# 2026-04-27 05:32:13.608 | INFO     | lakelogic.core.processor:run_source:1478 - No source files found in partitioned path; skipping run.
# 2026-04-27 05:32:13.949 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:13.950 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:13.951 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:13.951 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for trip_requests - proceeding to ensure target schema existence.
# 2026-04-27 05:32:13.953 | INFO     | lakelogic.core.materialization:materialize_dataframe:3145 - Materialization skipped: dataframe has no columns (empty incremental batch).
# 2026-04-27 05:32:13.954 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:14.023 | INFO     | lakelogic.pipeline.runner:_execute_post_ingestion_cleanup:1849 -   🧹 Post-ingestion: deleted landing files for trip_requests
# 2026-04-27 05:32:14.030 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:14.031 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [bronze] trip_completed | Contract: Bronze — RideFlow Trip Completed v1.0.0
# 2026-04-27 05:32:14.055 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\trip_completed via duckdb
# 2026-04-27 05:32:14.183 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2984 - Date-partitioned scan: no files found in 24 partitions (2026-04-27 to 2026-04-27)
# 2026-04-27 05:32:14.183 | INFO     | lakelogic.core.processor:run_source:1478 - No source files found in partitioned path; skipping run.
# 2026-04-27 05:32:14.382 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:14.383 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:14.384 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:14.384 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for trip_completed - proceeding to ensure target schema existence.
# 2026-04-27 05:32:14.385 | INFO     | lakelogic.core.materialization:materialize_dataframe:3145 - Materialization skipped: dataframe has no columns (empty incremental batch).
# 2026-04-27 05:32:14.386 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:14.457 | INFO     | lakelogic.pipeline.runner:_execute_post_ingestion_cleanup:1849 -   🧹 Post-ingestion: deleted landing files for trip_completed
# 2026-04-27 05:32:14.466 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:14.468 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [bronze] trip_cancellations | Contract: Bronze — RideFlow Trip Cancellations v1.0.0
# 2026-04-27 05:32:14.491 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\trip_cancellations via duckdb
# 2026-04-27 05:32:14.636 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2984 - Date-partitioned scan: no files found in 24 partitions (2026-04-27 to 2026-04-27)
# 2026-04-27 05:32:14.637 | INFO     | lakelogic.core.processor:run_source:1478 - No source files found in partitioned path; skipping run.
# 2026-04-27 05:32:14.853 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:14.854 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:14.854 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:14.855 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for trip_cancellations - proceeding to ensure target schema existence.
# 2026-04-27 05:32:14.856 | INFO     | lakelogic.core.materialization:materialize_dataframe:3145 - Materialization skipped: dataframe has no columns (empty incremental batch).
# 2026-04-27 05:32:14.857 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:14.913 | INFO     | lakelogic.pipeline.runner:_execute_post_ingestion_cleanup:1849 -   🧹 Post-ingestion: deleted landing files for trip_cancellations
# ================================================================================
#  PIPELINE RUN SUMMARY
# ================================================================================
#   Pipeline run    : e67413d3-7882-4d2c-96ea-261e03b3855d
#   Environment     : local
#   Dry run         : False
#
#   Table Name                             Layer    Status     Rows     Good/Qrtn
#   ------------------------------------------------------------------------------
#   bronze_rideflow_rider_profiles         bronze   no_new_ro  ?        -
#   bronze_rideflow_rider_app_events       bronze   no_new_ro  ?        -
#   bronze_rideflow_driver_profiles        bronze   no_new_ro  ?        -
#   bronze_rideflow_driver_telemetry       bronze   no_new_ro  ?        -
#   bronze_rideflow_trip_requests          bronze   no_new_ro  ?        -
#   bronze_rideflow_trip_completed         bronze   no_new_ro  ?        -
#   bronze_rideflow_trip_cancellations     bronze   no_new_ro  ?        -
# ================================================================================

# %% [markdown]
# ---
# ## Step 6 · Silver Processing
#
# Silver layer: type casting, deduplication, and merge. Schema enforcement quarantines rows that don't match the contract — no silent data corruption.

# %%
print("Starting Silver Processing via LakeLogic Pipeline Driver...")

summary = runner.run(
    target_layers="silver", 
    reload_layers = reload_layers,
    dry_run=False,
    environment=ENV,
    retry_attempts=retry_attempts,
    retry_base_wait_seconds=retry_base_wait_seconds,
    parallel=parallel
)
print(summary)
# Out:
# 2026-04-27 05:32:14.933 | INFO     | lakelogic.pipeline.runner:run:1479 - Pipeline storage mode: direct
# 2026-04-27 05:32:14.937 | INFO     | lakelogic.pipeline.runner:run:1580 - ── Processing Layer: SILVER (4 contracts) ──
# 2026-04-27 05:32:14.938 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:14.939 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [silver] silver_rideflow_driver_profiles | Contract: Silver — Rideflow Driver Profiles v1.0.0
# 2026-04-27 05:32:14.958 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_driver_profiles via duckdb
# 2026-04-27 05:32:15.083 | INFO     | lakelogic.core.processor:run_source:1808 - Incremental load: filtering _lakelogic_processed_at > '2026-04-27T03:59:38+00:00' (strategy: pipeline_log)
# 2026-04-27 05:32:15.094 | INFO     | lakelogic.core.processor:run_source:1830 - Incremental load: no new rows since last run — processing empty frame to preserve contract schema.
# Starting Silver Processing via LakeLogic Pipeline Driver...
# 2026-04-27 05:32:15.186 | WARNING  | lakelogic.core.masking_engine:apply:377 - PII fields detected without masking strategy: [name, email, phone, date_of_birth, home_address, licence_number, licence_plate, bank_account_last_four, city_code]. Set 'masking:' (nullify|hash|redact|partial|encrypt) in your contract to enable masking for these fields.
# 2026-04-27 05:32:15.186 | INFO     | lakelogic.core.masking_engine:apply:384 - No PII fields with explicit masking strategy — skipping masking.
# 2026-04-27 05:32:15.187 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 0 | Total: 0 | Good: 0 | Quarantine: 0 | Ratio: n/a
# 2026-04-27 05:32:15.221 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for silver_rideflow_driver_profiles - proceeding to ensure target schema existence.
# 2026-04-27 05:32:15.224 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\silver\silver_rideflow_driver_profiles\data.delta
# 2026-04-27 05:32:15.236 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 1 column(s) to match existing Delta table schema
# 2026-04-27 05:32:15.316 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 0 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_driver_profiles (strategy=merge, pk=['driver_id'])
# 2026-04-27 05:32:15.318 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:15.507 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:15.512 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:15.513 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:15.518 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:15.518 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [silver] silver_rideflow_rider_profiles | Contract: Silver — Rideflow Rider Profiles v1.0.0
# 2026-04-27 05:32:15.536 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_rider_profiles via duckdb
# 2026-04-27 05:32:15.649 | INFO     | lakelogic.core.processor:run_source:1808 - Incremental load: filtering _lakelogic_processed_at > '2026-04-27T03:59:36+00:00' (strategy: pipeline_log)
# 2026-04-27 05:32:15.657 | INFO     | lakelogic.core.processor:run_source:1830 - Incremental load: no new rows since last run — processing empty frame to preserve contract schema.
# 2026-04-27 05:32:15.706 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:758 - Quality Check: rider_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-27 05:32:15.728 | WARNING  | lakelogic.core.masking_engine:apply:377 - PII fields detected without masking strategy: [name, email, phone, date_of_birth, home_address, city_code]. Set 'masking:' (nullify|hash|redact|partial|encrypt) in your contract to enable masking for these fields.
# 2026-04-27 05:32:15.730 | INFO     | lakelogic.core.masking_engine:apply:384 - No PII fields with explicit masking strategy — skipping masking.
# 2026-04-27 05:32:15.732 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 0 | Total: 0 | Good: 0 | Quarantine: 0 | Ratio: n/a
# 2026-04-27 05:32:15.833 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for silver_rideflow_rider_profiles - proceeding to ensure target schema existence.
# 2026-04-27 05:32:15.841 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\silver\silver_rideflow_rider_profiles\data.delta
# 2026-04-27 05:32:15.951 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 0 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_rider_profiles (strategy=merge, pk=['rider_id'])
# 2026-04-27 05:32:15.952 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:16.157 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:16.158 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:16.159 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:16.166 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:16.167 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [silver] silver_rideflow_driver_telemetry | Contract: Silver — Rideflow Driver Telemetry v1.0.0
# 2026-04-27 05:32:16.183 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_driver_telemetry via duckdb
# 2026-04-27 05:32:16.301 | INFO     | lakelogic.core.processor:run_source:1808 - Incremental load: filtering _lakelogic_processed_at > '2026-04-27T03:59:38+00:00' (strategy: pipeline_log)
# 2026-04-27 05:32:16.313 | INFO     | lakelogic.core.processor:run_source:1830 - Incremental load: no new rows since last run — processing empty frame to preserve contract schema.
# 2026-04-27 05:32:16.362 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:758 - Quality Check: telemetry_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-27 05:32:16.384 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 0 | Total: 0 | Good: 0 | Quarantine: 0 | Ratio: n/a
# 2026-04-27 05:32:16.405 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for silver_rideflow_driver_telemetry - proceeding to ensure target schema existence.
# 2026-04-27 05:32:16.410 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\silver\silver_rideflow_driver_telemetry\data.delta
# 2026-04-27 05:32:16.420 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 1 column(s) to match existing Delta table schema
# 2026-04-27 05:32:16.504 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 0 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_driver_telemetry (strategy=merge, pk=['telemetry_id'])
# 2026-04-27 05:32:16.505 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:16.705 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:16.706 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:16.706 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:16.715 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:16.716 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [silver] silver_rideflow_trips | Contract: Silver — Rideflow Trips v1.0.0
# 2026-04-27 05:32:16.734 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_trip_completed via duckdb
# 2026-04-27 05:32:16.860 | INFO     | lakelogic.core.processor:run_source:1808 - Incremental load: filtering _lakelogic_processed_at > '2026-04-27T03:59:40+00:00' (strategy: pipeline_log)
# 2026-04-27 05:32:16.873 | INFO     | lakelogic.core.processor:run_source:1830 - Incremental load: no new rows since last run — processing empty frame to preserve contract schema.
# 2026-04-27 05:32:16.982 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 0 | Total: 0 | Good: 0 | Quarantine: 0 | Ratio: n/a
# 2026-04-27 05:32:17.005 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for silver_rideflow_trips - proceeding to ensure target schema existence.
# 2026-04-27 05:32:17.010 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\silver\silver_rideflow_trips\data.delta
# 2026-04-27 05:32:17.021 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 7 column(s) to match existing Delta table schema
# 2026-04-27 05:32:17.146 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 0 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_trips (strategy=merge, pk=['trip_id'])
# 2026-04-27 05:32:17.148 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:17.367 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:17.369 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:17.369 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# ================================================================================
#  PIPELINE RUN SUMMARY
# ================================================================================
#   Pipeline run    : e67413d3-7882-4d2c-96ea-261e03b3855d
#   Environment     : local
#   Dry run         : False
#
#   Table Name                             Layer    Status     Rows     Good/Qrtn
#   ------------------------------------------------------------------------------
#   silver_rideflow_driver_profiles        silver   no_new_ro  0        0/0
#   silver_rideflow_rider_profiles         silver   no_new_ro  0        0/0
#   silver_rideflow_driver_telemetry       silver   no_new_ro  0        0/0
#   silver_rideflow_trips                  silver   no_new_ro  0        0/0
# ================================================================================

# %% [markdown]
# ---
# ## Step 6.5 · Gold Processing (Business KPIs & ML Models)
#
# Gold layer: where the business value is unlocked! Generates Trip KPIs, Rider LTV (Lifetime Value), and the AI-driven Surge Pricing data feeds.

# %%
# Generate surge inference landing data for the Surge Pricing ML Model contract
import polars as pl
import random, uuid
from datetime import datetime, timezone, timedelta

SURGE_LANDING = LAKEHOUSE / "marketplace" / "surge_inference_landing"
SURGE_LANDING.mkdir(parents=True, exist_ok=True)

random.seed(42)
cities = ["LON", "MAN", "BIR", "LDS", "BRS", "EDI", "GLA"]
n = 200

surge_df = pl.DataFrame({
    "inference_id": [str(uuid.uuid4()) for _ in range(n)],
    "model_version": [random.choice(["v2.1.0", "v2.2.0", "v2.3.0-beta"]) for _ in range(n)],
    "city_code": [random.choice(cities) for _ in range(n)],
    "demand_index": [round(random.uniform(0.5, 8.5), 2) for _ in range(n)],
    "surge_multiplier": [round(random.uniform(1.0, 4.2), 2) for _ in range(n)],
    "timestamp": [
        datetime.now(timezone.utc) - timedelta(minutes=random.randint(0, 1440))
        for _ in range(n)
    ],
})

surge_df.write_parquet(SURGE_LANDING / "inferences.parquet")
print(f"✅ Generated {n} surge inference records → {SURGE_LANDING}")
surge_df.head(3)
# Out:
# ✅ Generated 200 surge inference records → lakehouse\marketplace\surge_inference_landing
# shape: (3, 6)
# ┌──────────────────┬───────────────┬───────────┬──────────────┬──────────────────┬─────────────────┐
# │ inference_id     ┆ model_version ┆ city_code ┆ demand_index ┆ surge_multiplier ┆ timestamp       │
# │ ---              ┆ ---           ┆ ---       ┆ ---          ┆ ---              ┆ ---             │
# │ str              ┆ str           ┆ str       ┆ f64          ┆ f64              ┆ datetime[μs,    │
# │                  ┆               ┆           ┆              ┆                  ┆ UTC]            │
# ╞══════════════════╪═══════════════╪═══════════╪══════════════╪══════════════════╪═════════════════╡
# │ 529f3af3-aee0-4a ┆ v2.3.0-beta   ┆ LON       ┆ 5.86         ┆ 2.42             ┆ 2026-04-26      │
# │ 65-8ff3-743d83ef ┆               ┆           ┆              ┆                  ┆ 11:47:17.396029 │
# │ 8594             ┆               ┆           ┆              ┆                  ┆ UTC             │
# │ d01b4f2d-000f-49 ┆ v2.1.0        ┆ MAN       ┆ 3.01         ┆ 3.61             ┆ 2026-04-27      │
# │ 9b-90c4-02bcfb3d ┆               ┆           ┆              ┆                  ┆ 01:02:17.396029 │
# │ 3c52             ┆               ┆           ┆              ┆                  ┆ UTC             │
# │ a6abe7df-6d0c-45 ┆ v2.1.0        ┆ BRS       ┆ 2.62         ┆ 3.85             ┆ 2026-04-27      │
# │ 27-9e3c-85e96869 ┆               ┆           ┆              ┆                  ┆ 04:07:17.396029 │
# │ 5f88             ┆               ┆           ┆              ┆                  ┆ UTC             │
# └──────────────────┴───────────────┴───────────┴──────────────┴──────────────────┴─────────────────┘

# %%
print("Starting Gold Processing via LakeLogic Pipeline Driver...\n")

summary = runner.run(
    target_layers="gold", 
    reload_layers=reload_layers,
    dry_run=False,
    environment=ENV,
    retry_attempts=retry_attempts,
    retry_base_wait_seconds=retry_base_wait_seconds,
    parallel=parallel
)
print(summary)
# Out:
# 2026-04-27 05:32:17.423 | INFO     | lakelogic.pipeline.runner:run:1479 - Pipeline storage mode: direct
# 2026-04-27 05:32:17.427 | INFO     | lakelogic.pipeline.runner:run:1580 - ── Processing Layer: GOLD (4 contracts) ──
# 2026-04-27 05:32:17.429 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:17.433 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [gold] gold_rideflow_trip_kpis | Contract: Gold — Trip KPIs v1.0.0
# 2026-04-27 05:32:17.457 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\silver\silver_rideflow_trips via duckdb
# Starting Gold Processing via LakeLogic Pipeline Driver...
# 2026-04-27 05:32:17.659 | INFO     | lakelogic.core.processor:run_source:1808 - Incremental load: filtering _lakelogic_processed_at > '2026-04-27T03:59:43+00:00' (strategy: pipeline_log)
# 2026-04-27 05:32:17.674 | INFO     | lakelogic.core.processor:run_source:1830 - Incremental load: no new rows since last run — processing empty frame to preserve contract schema.
# 2026-04-27 05:32:17.856 | INFO     | lakelogic.engines.duckdb:_register_links:172 - Registered link 'silver_trips_full' from lakehouse\marketplace\silver\silver_rideflow_trips (type=delta)
# 2026-04-27 05:32:18.005 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 0 | Total: 0 | Good: 0 | Quarantine: 0 | Ratio: n/a
# 2026-04-27 05:32:18.031 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for gold_rideflow_trip_kpis - proceeding to ensure target schema existence.
# 2026-04-27 05:32:18.035 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\gold\gold_rideflow_trip_kpis\data.delta
# 2026-04-27 05:32:18.042 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 6 column(s) to match existing Delta table schema
# 2026-04-27 05:32:18.092 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 0 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_trip_kpis (strategy=merge, pk=['kpi_date', 'city_code'])
# 2026-04-27 05:32:18.092 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:18.284 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:18.285 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:18.286 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:18.291 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:18.292 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [gold] gold_rideflow_driver_scorecard | Contract: Gold — Driver Scorecard v1.0.0
# 2026-04-27 05:32:18.311 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\silver\silver_rideflow_trips via duckdb
# 2026-04-27 05:32:18.435 | INFO     | lakelogic.core.processor:run_source:1808 - Incremental load: filtering _lakelogic_processed_at > '2026-04-27T03:59:43+00:00' (strategy: pipeline_log)
# 2026-04-27 05:32:18.449 | INFO     | lakelogic.core.processor:run_source:1830 - Incremental load: no new rows since last run — processing empty frame to preserve contract schema.
# 2026-04-27 05:32:18.597 | INFO     | lakelogic.engines.duckdb:_register_links:172 - Registered link 'silver_trips_full' from lakehouse\marketplace\silver\silver_rideflow_trips (type=delta)
# 2026-04-27 05:32:18.740 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 0 | Total: 0 | Good: 0 | Quarantine: 0 | Ratio: n/a
# 2026-04-27 05:32:18.765 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for gold_rideflow_driver_scorecard - proceeding to ensure target schema existence.
# 2026-04-27 05:32:18.769 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\gold\gold_rideflow_driver_scorecard\data.delta
# 2026-04-27 05:32:18.777 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 5 column(s) to match existing Delta table schema
# 2026-04-27 05:32:18.835 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 0 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_driver_scorecard (strategy=merge, pk=['driver_id'])
# 2026-04-27 05:32:18.836 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:19.029 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:19.031 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:19.033 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:19.037 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:19.038 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [gold] gold_rideflow_rider_daily_metrics | Contract: Gold — Daily Rider Metrics v1.0.0
# 2026-04-27 05:32:19.057 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\silver\silver_rideflow_trips via duckdb
# 2026-04-27 05:32:19.200 | INFO     | lakelogic.core.processor:run_source:1808 - Incremental load: filtering _lakelogic_processed_at > '2026-04-27T03:59:43+00:00' (strategy: pipeline_log)
# 2026-04-27 05:32:19.212 | INFO     | lakelogic.core.processor:run_source:1830 - Incremental load: no new rows since last run — processing empty frame to preserve contract schema.
# 2026-04-27 05:32:19.397 | INFO     | lakelogic.engines.duckdb:_register_links:172 - Registered link 'silver_trips_full' from lakehouse\marketplace\silver\silver_rideflow_trips (type=delta)
# 2026-04-27 05:32:19.534 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 0 | Total: 0 | Good: 0 | Quarantine: 0 | Ratio: n/a
# 2026-04-27 05:32:19.556 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2082 - No new rows for gold_rideflow_rider_daily_metrics - proceeding to ensure target schema existence.
# 2026-04-27 05:32:19.562 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\gold\gold_rideflow_rider_daily_metrics\data.delta
# 2026-04-27 05:32:19.570 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 5 column(s) to match existing Delta table schema
# 2026-04-27 05:32:19.650 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 0 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_rider_daily_metrics (strategy=merge, pk=['rider_id', 'activity_date'])
# 2026-04-27 05:32:19.651 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:19.866 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:19.869 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:19.869 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# 2026-04-27 05:32:19.875 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2034 -   ─────────────────────────────────────────────────────────
# 2026-04-27 05:32:19.875 | INFO     | lakelogic.pipeline.runner:_process_single_contract:2035 -   📄 [gold] gold_rideflow_surge_pricing_model | Contract: Gold — Surge Pricing ML Model Log v1.0.0
# 2026-04-27 05:32:19.900 | INFO     | lakelogic.core.processor:run_source:1375 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\surge_inference_landing via duckdb
# 2026-04-27 05:32:19.951 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:758 - Quality Check: inference_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-27 05:32:19.970 | INFO     | lakelogic.core.processor:run:819 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 200 | Total: 200 | Good: 200 | Quarantine: 0 | Ratio: 0.00%
# 2026-04-27 05:32:20.017 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 2 column(s) to match existing Delta table schema
# 2026-04-27 05:32:20.074 | INFO     | lakelogic.core.materialization:materialize_dataframe:3454 - Materialized 200 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_surge_pricing_model (strategy=merge, pk=['inference_id'])
# 2026-04-27 05:32:20.075 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-27 05:32:20.258 | INFO     | lakelogic.core.run_log:_write_run_log_table:872 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-27 05:32:20.261 | INFO     | lakelogic.core.run_log:write_run_log:1068 - 📡 [1/5] Observatory config resolved: True
# 2026-04-27 05:32:20.263 | INFO     | lakelogic.core.run_log:write_run_log:1166 - 📡 [SKIP] Observatory disabled or not configured: cfg=True, enabled=False
# ================================================================================
#  PIPELINE RUN SUMMARY
# ================================================================================
#   Pipeline run    : e67413d3-7882-4d2c-96ea-261e03b3855d
#   Environment     : local
#   Dry run         : False
#
#   Table Name                             Layer    Status     Rows     Good/Qrtn
#   ------------------------------------------------------------------------------
#   gold_rideflow_trip_kpis                gold     no_new_ro  0        0/0
#   gold_rideflow_driver_scorecard         gold     no_new_ro  0        0/0
#   gold_rideflow_rider_daily_metrics      gold     no_new_ro  0        0/0
#   gold_rideflow_surge_pricing_model      gold     success    200      200/0
# ================================================================================

# %% [markdown]
# ---
# ## Step 7 · Quick Data Preview
#
# Inspect the Silver trips table — the main fact table driving the dashboard.

# %%
trips_path = LAKEHOUSE / registry.domain / registry.silver_layer / "silver_rideflow_trips"

if trips_path.exists():
    try:
        trips_df = pl.read_delta(str(trips_path))
    except Exception:
        parquets = list(trips_path.rglob("*.parquet"))
        trips_df = pl.read_parquet(parquets[0]) if parquets else pl.DataFrame()

    print(f"Silver trips: {len(trips_df):,} rows, {len(trips_df.columns)} columns")
    print(f"\nColumns: {trips_df.columns}")
    print(f"\nSample (5 rows):")
    display(trips_df.head(5))

    # Quick stats
    if "fare_amount" in trips_df.columns:
        fare_col = trips_df["fare_amount"].cast(pl.Float64, strict=False)
        print(f"\n📊 Fare stats:  min=£{fare_col.min():.2f}  avg=£{fare_col.mean():.2f}  max=£{fare_col.max():.2f}")
    if "city_code" in trips_df.columns:
        print(f"🏙️ Cities: {trips_df['city_code'].unique().sort().to_list()}")
else:
    print("⚠️ Silver trips table not found — check the pipeline cells above.")
# Out:
# Silver trips: 1,783 rows, 26 columns
#
# Columns: ['trip_id', 'rider_id', 'driver_id', 'trip_type', 'pickup_lat', 'pickup_lng', 'dropoff_lat', 'dropoff_lng', 'city_code', 'requested_at', 'pickup_at', 'dropoff_at', 'distance_km', 'duration_minutes', 'fare_amount', 'surge_multiplier', 'tip_amount', 'payment_method', 'rider_rating', 'driver_rating', 'notes', '_lakelogic_source', '_lakelogic_processed_at', '_lakelogic_run_id', '_lakelogic_created_at', '_lakelogic_created_by']
#
# Sample (5 rows):
# shape: (5, 26)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ tri ┆ rid ┆ dri ┆ tri ┆ pic ┆ pic ┆ dro ┆ dro ┆ cit ┆ req ┆ pic ┆ dro ┆ dis ┆ dur ┆ far ┆ sur ┆ tip ┆ pay ┆ rid ┆ dri ┆ not ┆ _la ┆ _la ┆ _la ┆ _la ┆ _la │
# │ p_i ┆ er_ ┆ ver ┆ p_t ┆ kup ┆ kup ┆ pof ┆ pof ┆ y_c ┆ ues ┆ kup ┆ pof ┆ tan ┆ ati ┆ e_a ┆ ge_ ┆ _am ┆ men ┆ er_ ┆ ver ┆ es  ┆ kel ┆ kel ┆ kel ┆ kel ┆ kel │
# │ d   ┆ id  ┆ _id ┆ ype ┆ _la ┆ _ln ┆ f_l ┆ f_l ┆ ode ┆ ted ┆ _at ┆ f_a ┆ ce_ ┆ on_ ┆ mou ┆ mul ┆ oun ┆ t_m ┆ rat ┆ _ra ┆ --- ┆ ogi ┆ ogi ┆ ogi ┆ ogi ┆ ogi │
# │ --- ┆ --- ┆ --- ┆ --- ┆ t   ┆ g   ┆ at  ┆ ng  ┆ --- ┆ _at ┆ --- ┆ t   ┆ km  ┆ min ┆ nt  ┆ tip ┆ t   ┆ eth ┆ ing ┆ tin ┆ str ┆ c_s ┆ c_p ┆ c_r ┆ c_c ┆ c_c │
# │ str ┆ str ┆ str ┆ str ┆ --- ┆ --- ┆ --- ┆ --- ┆ str ┆ --- ┆ dat ┆ --- ┆ --- ┆ ute ┆ --- ┆ lie ┆ --- ┆ od  ┆ --- ┆ g   ┆     ┆ our ┆ roc ┆ un_ ┆ rea ┆ rea │
# │     ┆     ┆     ┆     ┆ str ┆ str ┆ str ┆ str ┆     ┆ dat ┆ eti ┆ dat ┆ f32 ┆ s   ┆ f32 ┆ r   ┆ f32 ┆ --- ┆ f32 ┆ --- ┆     ┆ ce  ┆ ess ┆ id  ┆ ted ┆ ted │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eti ┆ me[ ┆ eti ┆     ┆ --- ┆     ┆ --- ┆     ┆ str ┆     ┆ f32 ┆     ┆ --- ┆ ed_ ┆ --- ┆ _at ┆ _by │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ me[ ┆ μs] ┆ me[ ┆     ┆ i32 ┆     ┆ f32 ┆     ┆     ┆     ┆     ┆     ┆ str ┆ at  ┆ str ┆ --- ┆ --- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ μs] ┆     ┆ μs] ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ --- ┆     ┆ str ┆ str │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆     ┆     │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ 54c ┆ R-4 ┆ D-1 ┆ eat ┆ 51. ┆ 0.0 ┆ 51. ┆ -0. ┆ XYZ ┆ 202 ┆ 202 ┆ 202 ┆ 9.4 ┆ 19  ┆ 11. ┆ 3.4 ┆ 1.1 ┆ cas ┆ 4.0 ┆ 4.0 ┆     ┆ C:\ ┆ 202 ┆ 6b1 ┆ 202 ┆ col │
# │ cb0 ┆ f7b ┆ bcf ┆ s_d ┆ 552 ┆ 167 ┆ 433 ┆ 169 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆     ┆     ┆ 91  ┆ 7   ┆ 2   ┆ h   ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ 57f ┆ 6-0 ┆ li  │
# │ 6c- ┆ 7fe ┆ d95 ┆ eli ┆ 5   ┆ 57  ┆ 948 ┆ 965 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ b0- ┆ 4-2 ┆     │
# │ d34 ┆ 5   ┆ 3   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 7T0 ┆ 946 ┆ 7T0 ┆     │
# │ c-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 20: ┆ 21: ┆ 21: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 3:5 ┆ d-4 ┆ 3:5 ┆     │
# │ 31c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 58: ┆ 05: ┆ 15: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 9:4 ┆ f5e ┆ 9:4 ┆     │
# │ -97 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 3+0 ┆ -b8 ┆ 3+0 ┆     │
# │ 66- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 89- ┆ 0:0 ┆     │
# │ 3d4 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 28b ┆ 0   ┆     │
# │ 100 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ f2c ┆     ┆     │
# │ c61 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ 027 ┆     ┆     │
# │ a97 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ de0 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ 75c ┆ R-7 ┆ D-d ┆ eat ┆ 51. ┆ -0. ┆ 51. ┆ -0. ┆ XYZ ┆ 202 ┆ 202 ┆ 202 ┆ 15. ┆ 42  ┆ 48. ┆ 2.0 ┆ 3.9 ┆ app ┆ 3.0 ┆ 3.0 ┆     ┆ C:\ ┆ 202 ┆ 6b1 ┆ 202 ┆ col │
# │ 42b ┆ 5dc ┆ cc5 ┆ s_d ┆ 432 ┆ 035 ┆ 550 ┆ 068 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 8   ┆     ┆ 200 ┆ 9   ┆ 9   ┆ le_ ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ 57f ┆ 6-0 ┆ li  │
# │ 4c- ┆ 0ef ┆ b95 ┆ eli ┆ 549 ┆ 967 ┆ 409 ┆ 297 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆ 001 ┆     ┆     ┆ pay ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ b0- ┆ 4-2 ┆     │
# │ 512 ┆ 1   ┆ 2   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 7T0 ┆ 946 ┆ 7T0 ┆     │
# │ 1-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 18: ┆ 18: ┆ 18: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 3:5 ┆ d-4 ┆ 3:5 ┆     │
# │ af5 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 06: ┆ 09: ┆ 43: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 9:4 ┆ f5e ┆ 9:4 ┆     │
# │ -b6 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 3+0 ┆ -b8 ┆ 3+0 ┆     │
# │ a0- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 89- ┆ 0:0 ┆     │
# │ 041 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 28b ┆ 0   ┆     │
# │ d25 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ f2c ┆     ┆     │
# │ 039 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ 027 ┆     ┆     │
# │ 4b9 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ de0 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ 36c ┆ R-4 ┆ D-0 ┆ eat ┆ 51. ┆ -0. ┆ 51. ┆ -0. ┆ LON ┆ 202 ┆ 202 ┆ 202 ┆ 18. ┆ 22  ┆ 75. ┆ 5.8 ┆ 2.9 ┆ goo ┆ 1.0 ┆ 5.0 ┆     ┆ C:\ ┆ 202 ┆ 6b1 ┆ 202 ┆ col │
# │ aad ┆ 111 ┆ 44f ┆ s_d ┆ 534 ┆ 063 ┆ 464 ┆ 146 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 299 ┆     ┆ 860 ┆     ┆ 7   ┆ gle ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ 57f ┆ 6-0 ┆ li  │
# │ 90- ┆ aab ┆ bf2 ┆ eli ┆ 781 ┆ 942 ┆ 087 ┆ 983 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆ 999 ┆     ┆ 001 ┆     ┆     ┆ _pa ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ b0- ┆ 4-2 ┆     │
# │ de9 ┆ f   ┆ 0   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆ y   ┆     ┆     ┆     ┆ nal ┆ 7T0 ┆ 946 ┆ 7T0 ┆     │
# │ 1-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 05: ┆ 05: ┆ 05: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 3:5 ┆ d-4 ┆ 3:5 ┆     │
# │ b81 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00: ┆ 10: ┆ 52: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 9:4 ┆ f5e ┆ 9:4 ┆     │
# │ -a1 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 3+0 ┆ -b8 ┆ 3+0 ┆     │
# │ 60- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 89- ┆ 0:0 ┆     │
# │ a1e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 28b ┆ 0   ┆     │
# │ 3b8 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ f2c ┆     ┆     │
# │ 957 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ 027 ┆     ┆     │
# │ 3d3 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ de0 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ d32 ┆ R-6 ┆ D-d ┆ eat ┆ 51. ┆ 0.0 ┆ 51. ┆ -0. ┆ LON ┆ 202 ┆ 202 ┆ 202 ┆ 21. ┆ 16  ┆ 15. ┆ 1.2 ┆ 4.5 ┆ cas ┆ 3.0 ┆ 5.0 ┆     ┆ C:\ ┆ 202 ┆ 6b1 ┆ 202 ┆ col │
# │ b39 ┆ 9d0 ┆ ae1 ┆ s_d ┆ 456 ┆ 228 ┆ 561 ┆ 076 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 5   ┆     ┆ 25  ┆ 8   ┆ 5   ┆ h   ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ 57f ┆ 6-0 ┆ li  │
# │ 04- ┆ 7ed ┆ be4 ┆ eli ┆ 935 ┆ 78  ┆ 762 ┆ 129 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ b0- ┆ 4-2 ┆     │
# │ a7a ┆ 8   ┆ f   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 7T0 ┆ 946 ┆ 7T0 ┆     │
# │ f-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 12: ┆ 12: ┆ 11: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 3:5 ┆ d-4 ┆ 3:5 ┆     │
# │ ec7 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 15: ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 9:4 ┆ f5e ┆ 9:4 ┆     │
# │ -8d ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 3+0 ┆ -b8 ┆ 3+0 ┆     │
# │ 16- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 89- ┆ 0:0 ┆     │
# │ 16b ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 28b ┆ 0   ┆     │
# │ 329 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ f2c ┆     ┆     │
# │ 06e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ 027 ┆     ┆     │
# │ 47a ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ de0 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ 1a0 ┆ R-e ┆ D-2 ┆ rid ┆ 51. ┆ -0. ┆ 51. ┆ 0.0 ┆ PAR ┆ 202 ┆ 202 ┆ 202 ┆ 18. ┆ 19  ┆ 11. ┆ 1.0 ┆ 2.1 ┆ cas ┆ 3.0 ┆ 4.0 ┆     ┆ C:\ ┆ 202 ┆ 6b1 ┆ 202 ┆ col │
# │ 0fa ┆ 25b ┆ 2bb ┆ e   ┆ 437 ┆ 169 ┆ 453 ┆ 145 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 5   ┆     ┆ 76  ┆ 4   ┆ 7   ┆ h   ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ 57f ┆ 6-0 ┆ li  │
# │ 77- ┆ 79f ┆ 8c1 ┆     ┆ 188 ┆ 318 ┆ 839 ┆ 59  ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ b0- ┆ 4-2 ┆     │
# │ 739 ┆ 2   ┆ d   ┆     ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 7T0 ┆ 946 ┆ 7T0 ┆     │
# │ 1-4 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 07: ┆ 12: ┆ 11: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 3:5 ┆ d-4 ┆ 3:5 ┆     │
# │ dd0 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 01: ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 9:4 ┆ f5e ┆ 9:4 ┆     │
# │ -a8 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 3+0 ┆ -b8 ┆ 3+0 ┆     │
# │ d3- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 89- ┆ 0:0 ┆     │
# │ 6c9 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 28b ┆ 0   ┆     │
# │ 81b ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ f2c ┆     ┆     │
# │ 093 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ 027 ┆     ┆     │
# │ 834 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ de0 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘
# 📊 Fare stats:  min=£2.00  avg=£39.87  max=£144.38
# 🏙️ Cities: ['BER', 'LON', 'NYC', 'PAR', 'SYD', 'TYO', 'XYZ']

# %% [markdown]
# ---
# ## Step 8 · Pipeline Audit Trail
#
# Every pipeline run is logged with row counts, durations, quarantine ratios, and estimated costs.

# %%
log_path = LAKEHOUSE / registry.domain / "_logs" 

column_list = ["run_id", "contract", "dataset", "status", "timestamp", "run_duration_seconds", 
"engine",  "counts_source",	"counts_total",	"counts_good",	"counts_quarantined",
"quarantine_ratio",	"estimated_cost",	"cost_currency",]
if log_path.exists():
    try:
        from deltalake import DeltaTable
        logs_df = pl.from_arrow(DeltaTable(str(log_path)).to_pyarrow_table())
        print(f"Run logs: {len(logs_df)} entries")
        display(logs_df.select("*").head(2))
    except ImportError:
        logs_df = pl.read_delta(str(log_path))
        print(f"Run logs: {len(logs_df)} entries")
        display(logs_df.select(column_list).head(10))
    except Exception as e:
        print(f"Run log read error: {e}")
else:
    print("No run log yet — this is expected for the first pipeline run.")
# Out:
# Run logs: 30 entries
# shape: (2, 30)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ pip ┆ run ┆ tim ┆ sta ┆ end ┆ run ┆ eng ┆ con ┆ sta ┆ dat ┆ dom ┆ sys ┆ env ┆ dat ┆ sta ┆ err ┆ sou ┆ cou ┆ cou ┆ cou ┆ cou ┆ qua ┆ est ┆ cos ┆ cos ┆ max ┆ max ┆ dlt ┆ slo ┆ rep │
# │ eli ┆ _id ┆ est ┆ rt_ ┆ _ti ┆ _du ┆ ine ┆ tra ┆ ge  ┆ ase ┆ ain ┆ tem ┆ iro ┆ a_l ┆ tus ┆ or_ ┆ rce ┆ nts ┆ nts ┆ nts ┆ nts ┆ ran ┆ ima ┆ t_c ┆ t_c ┆ _so ┆ _wa ┆ _st ┆ _js ┆ ort │
# │ ne_ ┆ --- ┆ amp ┆ tim ┆ me  ┆ rat ┆ --- ┆ ct  ┆ --- ┆ t   ┆ --- ┆ --- ┆ nme ┆ aye ┆ --- ┆ mes ┆ _pa ┆ _so ┆ _to ┆ _go ┆ _qu ┆ tin ┆ ted ┆ urr ┆ onf ┆ urc ┆ ter ┆ ate ┆ on  ┆ _js │
# │ run ┆ str ┆ --- ┆ e   ┆ --- ┆ ion ┆ str ┆ --- ┆ str ┆ --- ┆ str ┆ str ┆ nt  ┆ r   ┆ str ┆ sag ┆ th  ┆ urc ┆ tal ┆ od  ┆ ara ┆ e_r ┆ _co ┆ enc ┆ ide ┆ e_m ┆ mar ┆ _js ┆ --- ┆ on  │
# │ _id ┆     ┆ str ┆ --- ┆ str ┆ _se ┆     ┆ str ┆     ┆ str ┆     ┆     ┆ --- ┆ --- ┆     ┆ e   ┆ --- ┆ e   ┆ --- ┆ --- ┆ nti ┆ ati ┆ st  ┆ y   ┆ nce ┆ tim ┆ k_v ┆ on  ┆ str ┆ --- │
# │ --- ┆     ┆     ┆ str ┆     ┆ con ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆ str ┆     ┆ --- ┆ str ┆ --- ┆ i64 ┆ i64 ┆ ned ┆ o   ┆ --- ┆ --- ┆ --- ┆ e   ┆ alu ┆ --- ┆     ┆ str │
# │ str ┆     ┆     ┆     ┆     ┆ ds  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆ i64 ┆     ┆     ┆ --- ┆ --- ┆ f64 ┆ str ┆ str ┆ --- ┆ e   ┆ str ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆ --- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ i64 ┆ f64 ┆     ┆     ┆     ┆ f64 ┆ --- ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆ f64 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆     ┆     │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ e67 ┆ ba4 ┆ 202 ┆ 202 ┆ 202 ┆ 0.1 ┆ duc ┆ Gol ┆ def ┆ gol ┆ mar ┆ rid ┆ loc ┆ gol ┆ suc ┆ nul ┆ C:\ ┆ 200 ┆ 200 ┆ 200 ┆ 0   ┆ 0.0 ┆ 0.0 ┆ USD ┆ non ┆ 1.7 ┆ nul ┆ nul ┆ {"f ┆ {"r │
# │ 413 ┆ 098 ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 019 ┆ kdb ┆ d — ┆ aul ┆ d_r ┆ ket ┆ efl ┆ al  ┆ d   ┆ cee ┆ l   ┆ _Pe ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e   ┆ 773 ┆ l   ┆ l   ┆ res ┆ un_ │
# │ d3- ┆ a3- ┆ 4-2 ┆ 4-2 ┆ 4-2 ┆ 94  ┆     ┆ Sur ┆ t   ┆ ide ┆ pla ┆ ow  ┆     ┆     ┆ ded ┆     ┆ rso ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e9  ┆     ┆     ┆ hne ┆ id" │
# │ 788 ┆ 37f ┆ 7T0 ┆ 7T0 ┆ 7T0 ┆     ┆     ┆ ge  ┆     ┆ flo ┆ ce  ┆     ┆     ┆     ┆     ┆     ┆ nal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ :   │
# │ 2-4 ┆ f-4 ┆ 4:3 ┆ 4:3 ┆ 4:3 ┆     ┆     ┆ Pri ┆     ┆ w_s ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ "ba │
# │ d2c ┆ c14 ┆ 2:1 ┆ 2:1 ┆ 2:2 ┆     ┆     ┆ cin ┆     ┆ urg ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"s ┆ 409 │
# │ -96 ┆ -8a ┆ 9+0 ┆ 9.9 ┆ 0.0 ┆     ┆     ┆ g   ┆     ┆ e_p ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 8a3 │
# │ ea- ┆ b0- ┆ 0:0 ┆ 041 ┆ 064 ┆     ┆     ┆ ML  ┆     ┆ ric ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ -37 │
# │ 261 ┆ b08 ┆ 0   ┆ 87+ ┆ 27+ ┆     ┆     ┆ Mod ┆     ┆ ing ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ ff- │
# │ e03 ┆ 719 ┆     ┆ 00: ┆ 00: ┆     ┆     ┆ el  ┆     ┆ _mo ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 4c1 │
# │ b38 ┆ 56f ┆     ┆ 00  ┆ 00  ┆     ┆     ┆ Log ┆     ┆ del ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 4-8 │
# │ 55d ┆ 77e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ ab0 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ -b0 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ 871 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 956 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ f77 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ e", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "pi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ pel │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d_s ┆ ine │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ _ru │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ n_i │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ sur ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ d": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ge_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ "e6 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ inf ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 741 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ere ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 3d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nce ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ -78 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_s ┆ 82- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ndi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 4d2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ng  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ c-9 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ 6ea │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ -26 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 1e0 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 3b3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ 855 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_p ┆ d", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ass ┆ "en │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ gin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "du │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "av ┆ ckd │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ail ┆ b", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ abi ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lit ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ y": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"r ┆ ":  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Go │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ ld  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ Sur │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ ge  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ Pri │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ cin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ g   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ ML  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ Mod │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ el  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d": ┆ Log │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ ",  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "ro ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_c ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oun ┆ _fi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t": ┆ le_ │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"… ┆ n…  │
# │ e67 ┆ c0c ┆ 202 ┆ 202 ┆ 202 ┆ 0.3 ┆ duc ┆ Gol ┆ def ┆ gol ┆ mar ┆ rid ┆ loc ┆ gol ┆ suc ┆ nul ┆ C:\ ┆ 0   ┆ 0   ┆ 0   ┆ 0   ┆ nul ┆ 0.0 ┆ USD ┆ non ┆ nul ┆ nul ┆ nul ┆ {"f ┆ {"r │
# │ 413 ┆ c9c ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 420 ┆ kdb ┆ d — ┆ aul ┆ d_r ┆ ket ┆ efl ┆ al  ┆ d   ┆ cee ┆ l   ┆ _Pe ┆     ┆     ┆     ┆     ┆ l   ┆     ┆     ┆ e   ┆ l   ┆ l   ┆ l   ┆ res ┆ un_ │
# │ d3- ┆ ab- ┆ 4-2 ┆ 4-2 ┆ 4-2 ┆ 24  ┆     ┆ Dai ┆ t   ┆ ide ┆ pla ┆ ow  ┆     ┆     ┆ ded ┆     ┆ rso ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hne ┆ id" │
# │ 788 ┆ d8c ┆ 7T0 ┆ 7T0 ┆ 7T0 ┆     ┆     ┆ ly  ┆     ┆ flo ┆ ce  ┆     ┆     ┆     ┆     ┆     ┆ nal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ :   │
# │ 2-4 ┆ a-4 ┆ 4:3 ┆ 4:3 ┆ 4:3 ┆     ┆     ┆ Rid ┆     ┆ w_r ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ "c0 │
# │ d2c ┆ 1c1 ┆ 2:1 ┆ 2:1 ┆ 2:1 ┆     ┆     ┆ er  ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"s ┆ cc9 │
# │ -96 ┆ -9c ┆ 9+0 ┆ 9.2 ┆ 9.5 ┆     ┆     ┆ Met ┆     ┆ r_d ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ cab │
# │ ea- ┆ 6e- ┆ 0:0 ┆ 139 ┆ 558 ┆     ┆     ┆ ric ┆     ┆ ail ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ -d8 │
# │ 261 ┆ 34a ┆ 0   ┆ 96+ ┆ 61+ ┆     ┆     ┆ s   ┆     ┆ y_m ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ ca- │
# │ e03 ┆ 29d ┆     ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆ etr ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 41c │
# │ b38 ┆ 9dc ┆     ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆ ics ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 1-9 │
# │ 55d ┆ 18f ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ c6e │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ -34 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ a29 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ d9d │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ c18 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ f", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "pi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ pel │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d_s ┆ ine │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ _ru │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ n_i │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ sil ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ d": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ver ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ "e6 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \si ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 741 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lve ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 3d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ r_r ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ -78 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_s ┆ 82- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 4d2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ c-9 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ 6ea │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ -26 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 1e0 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 3b3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ 855 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_p ┆ d", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ass ┆ "en │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ gin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "du │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "av ┆ ckd │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ail ┆ b", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ abi ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lit ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ y": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"r ┆ ":  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Go │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ ld  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ Dai │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ ly  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ Rid │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ er  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ Met │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ ric │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ s", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d": ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ _fi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "ro ┆ le_ │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_c ┆ nam │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oun ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t": ┆ n…  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"… ┆     │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %% [markdown]
# ---
# ## Step 8b · Quarantine View

# %%
table_name = 'gold_rideflow_rider_lifetime_value'
quarantine_path = LAKEHOUSE / registry.domain / "_quarantine" / table_name

if quarantine_path.exists():
    try:
        from deltalake import DeltaTable
        quarantines_df = pl.from_arrow(DeltaTable(str(quarantine_path)).to_pyarrow_table())
        print(f"quarantine quarantines: {len(quarantines_df)} entries")
        display(quarantines_df.select("*").head(2))
    except ImportError:
        quarantines_df = pl.read_delta(str(quarantine_path))
        print(f"Run quarantines: {len(quarantines_df)} entries")
        display(quarantines_df.select(column_list).head(10))
    except Exception as e:
        print(f"Run quarantine read error: {e}")
else:
    print("No run quarantine yet — this is expected for the first pipeline run.")
# Out:
# No run quarantine yet — this is expected for the first pipeline run.

# %% [markdown]
# ---
# ## Step 9 · 🚗 Launch Live Dashboard
#
# The payoff! A real-time Panel dashboard that auto-refreshes from the Silver Delta tables every 3 seconds.
#
# **5 Analytical Views:**
# - 📈 Trip Volume Timeline (with Hour / Day / Week / Month aggregation)
# - ⭐ Top 10 Drivers by Revenue (cross-table join with driver profiles)
# - 🏙️ Revenue by City
# - 👍 Driver Quality Distribution
# - ⚡ Surge Multiplier Profile
#
# > **Tip:** Use `dashboard.show()` to pop the dashboard out into a full browser tab for the best experience.

# %%
import importlib
import assets.dashboards.shared.streaming_dashboard
importlib.reload(assets.dashboards.shared.streaming_dashboard)
# Out:
# <module 'assets.dashboards.shared.streaming_dashboard' from 'c:\\_Personal\\_SaaS\\lakelogic\\examples\\colab\\assets\\dashboards\\shared\\streaming_dashboard.py'>

# %%
sys.path.insert(0, ".")
from assets.dashboards.shared.streaming_dashboard import create_streaming_dashboard_inline

dashboard = create_streaming_dashboard_inline(
    lakehouse_root=str(LAKEHOUSE),
    domain=registry.domain,
    system=registry.system,
    refresh_ms=3000,
)
dashboard
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='da7ffe3b-e341-4920-9158-85e238268ee3'>
#   <div id="e81c4dfa-0dc5-4c0e-bb26-72ee58b92afc" data-root-id="da7ffe3b-e341-4920-9158-85e238268ee3" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"672ea564-ba44-42e4-a661-9197bdf83812":{"version":"3.9.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"0e052e71-240a-4085-8248-140666776749","attributes":{"notifications":{"type":"object","name":"Notifications","id":"19710d6f-1d45-455e-97fb-a6e9a49c97cc"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"da7ffe3b-e341-4920-9158-85e238268ee3"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"33a1933b-2a49-4d42-b1cf-0c53215f8865","attributes":{"plot_id":"da7ffe3b-e341-4920-9158-85e238268ee3","comm_id":"afebd39b4f35414c8004066203b32833","client_comm_id":"ef08a0662df5411194c257e848603ff5"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"672ea564-ba44-42e4-a661-9197bdf83812","roots":{"da7ffe3b-e341-4920-9158-85e238268ee3":"e81c4dfa-0dc5-4c0e-bb26-72ee58b92afc"},"root_ids":["da7ffe3b-e341-4920-9158-85e238268ee3"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'3b9231e8-5ada-4cc8-9479-66c8bf5c49e1': {'version…

# %% [markdown]
# ---
# ## Step 10 · 🦆 Build Local DuckDB Catalog
#
# Create a persistent `lakehouse_catalog.duckdb` file that maps all your Delta tables as SQL views.
# Open this file in **DBeaver** (DuckDB driver) to browse and query your entire lakehouse with standard SQL.
#
# ```sql
# -- Once opened in DBeaver, just run:
# SELECT * FROM silver_trips WHERE city_code = 'LON' LIMIT 100;
# ```

# %%
import duckdb

catalog_path = str(LAKEHOUSE / f"lakehouse_catalog_{registry.domain}.duckdb")
con = duckdb.connect(catalog_path)

con.execute("INSTALL delta; LOAD delta;")

# Build views for every Delta table in the lakehouse
domain_root = LAKEHOUSE / registry.domain
for layer in ["bronze", "silver", "gold", "quarantine", "_logs"]:
    layer_path = domain_root / layer
    if not layer_path.exists():
        continue
    for table_dir in sorted(layer_path.iterdir()):
        if table_dir.is_dir() and not table_dir.name.startswith("_"):
            view_name = table_dir.name
            try:
                con.execute(f"CREATE OR REPLACE VIEW {view_name} AS SELECT * FROM delta_scan('{table_dir.as_posix()}')")
                row_count = con.execute(f"SELECT COUNT(*) FROM {view_name}").fetchone()[0]
                print(f"  ✅ {view_name}: {row_count:,} rows")
            except Exception as e:
                print(f"  ⚠️ {view_name}: {e}")

con.close()
print(f"\n🦆 Catalog saved → {catalog_path}")
print("   Open this file in DBeaver (DuckDB driver) to browse your lakehouse!")
# Out:
#   ✅ bronze_rideflow_driver_profiles: 148 rows
#   ✅ bronze_rideflow_driver_telemetry: 7,642 rows
#   ✅ bronze_rideflow_rider_app_events: 2,802 rows
#   ✅ bronze_rideflow_rider_profiles: 391 rows
#   ✅ bronze_rideflow_trip_cancellations: 183 rows
#   ✅ bronze_rideflow_trip_completed: 1,903 rows
#   ✅ bronze_rideflow_trip_requests: 1,416 rows
#   ✅ silver_rideflow_driver_profiles: 148 rows
#   ✅ silver_rideflow_driver_telemetry: 7,642 rows
#   ✅ silver_rideflow_rider_profiles: 391 rows
#   ✅ silver_rideflow_trips: 1,783 rows
#   ✅ gold_rideflow_driver_scorecard: 823 rows
#   ✅ gold_rideflow_rider_daily_metrics: 1,030 rows
#   ✅ gold_rideflow_surge_pricing_model: 400 rows
#   ✅ gold_rideflow_trip_kpis: 19 rows
#
# 🦆 Catalog saved → lakehouse\lakehouse_catalog_marketplace.duckdb
#    Open this file in DBeaver (DuckDB driver) to browse your lakehouse!

# %% [markdown]
# ---
# ## 🔄 Bonus: Incremental Streaming Mode
#
# Re-run the simulator for the **next 7 hours** of synthetic data and trigger a full pipeline pass after each window.
# This simulates what would happen in production with **Databricks Structured Streaming** — new micro-batches
# land every hour, and the pipeline incrementally ingests them through Bronze → Silver → Gold.
#
# | Parameter | Value |
# | :-- | :-- |
# | Simulation horizon | 7 hours from now |
# | Window cadence | 60 min (1 window = 1 simulated hour) |
# | Inter-window pause | 10 s (adjustable — set higher to watch dashboard animate) |
# | Pipeline layers | Bronze → Silver → Gold (full pass each window) |

# %%
import time
from datetime import datetime, timedelta, timezone

if enable_incremental_streaming:

    # ── Configuration ─────────────────────────────────────────────────
    STREAM_HOURS       = 7          # Simulate 7 hours into the future
    PAUSE_SECONDS      = 10         # Pause between windows (increase to watch dashboard animate)
    MICRO_BATCHES      = 10         # Files per entity per window

    stream_until = datetime.now(timezone.utc) + timedelta(hours=STREAM_HOURS)

    print(f"🔄 Incremental Streaming Mode")
    print(f"   Generating {STREAM_HOURS} hours of future data → up to {stream_until.strftime('%Y-%m-%d %H:%M UTC')}")
    print(f"   Pause between windows: {PAUSE_SECONDS}s")
    print(f"   Pipeline engine: {engine}")
    print(f"{'='*70}")

    cumulative_rows = 0
    window_count = 0
    t_start = time.time()

    for window in sim.run(
        num_windows=STREAM_HOURS,
        include_seed=False,
        micro_batches=MICRO_BATCHES,
        up_to=stream_until,
        resume=True,
    ):
        window_count += 1
        cumulative_rows += window.total_rows

        print(f"\n⏱  Window {window_count}/{STREAM_HOURS} | "
              f"{window.timestamp.strftime('%Y-%m-%d %H:%M')} | "
              f"+{window.total_rows:,} rows  (cumulative: {cumulative_rows:,})")

        # ── Re-ingest through the full pipeline ───────────────────────
        print(f"   🏗  Running pipeline (Bronze → Silver → Gold)...")
        runner = LakehousePipeline(registry, engine=engine)
        summary = runner.run(
            target_layers="bronze,silver,gold",
            retry_attempts=retry_attempts,
            retry_base_wait_seconds=retry_base_wait_seconds,
            parallel=parallel,
        )

        # Quick summary of what changed
        ingested = [r for r in summary.results if r.get('status') == 'success']
        skipped  = [r for r in summary.results if r.get('status') in ('no_new_data', 'no_new_rows')]
        print(f"   ✅ Pipeline pass complete: {len(ingested)} ingested, {len(skipped)} skipped")

        # ── Pause before next window ──────────────────────────────────
        if window_count < STREAM_HOURS:
            print(f"   ⏸  Pausing {PAUSE_SECONDS}s before next window...")
            time.sleep(PAUSE_SECONDS)

    elapsed = time.time() - t_start
    print(f"\n{'='*70}")
    print(f"✅ Incremental streaming complete!")
    print(f"   Windows processed: {window_count}")
    print(f"   Total rows generated: {cumulative_rows:,}")
    print(f"   Elapsed wall time: {elapsed/60:.1f} min")
    print(f"   Dashboard should now reflect {STREAM_HOURS} additional hours of data.")
else:
    print("⏭  Incremental streaming disabled (set enable_incremental_streaming = True to activate)")
# Out:
# ⏭  Incremental streaming disabled (set enable_incremental_streaming = True to activate)

# %% [markdown]
# ---
# ## ✅ Data Products Published
#
# This domain pipeline has successfully generated and published the following data products to the shared lakehouse:
#
# | Data Product | Consumers |
# | :-- | :-- |
# | `silver_rideflow_trips` | Payments (reconciliation), Operations (support enrichment) |
# | `silver_rideflow_driver_profiles` | Operations (background checks), Marketing (attribution) |
# | `gold_rideflow_trip_kpis` | Executive Dashboard, Mesh Products |
# | `gold_rideflow_rider_lifetime_value` | Marketing (LTV attribution), Finance (forecasting) |
#
# Other domain pipelines (`08_rideflow_payments`, `09_rideflow_operations`, `10_rideflow_marketing`) read from these outputs — never from our internal Bronze tables. This enforces clean Data Mesh boundaries.
#
# ### Next Notebooks
#
# - **`08_rideflow_payments.ipynb`** — Payments domain pipeline (Stripe charges, payouts, reconciliation)
# - **`12_compliance_gdpr_rtbf.ipynb`** — Execute a Right-to-Be-Forgotten request across all domains
# - **`14_data_mesh_dashboards.ipynb`** — Live observability across all domain pipelines
