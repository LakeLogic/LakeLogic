# %% [markdown]
# ⏱️ **Time required:** ~3 minutes | **Type:** Domain pipeline (run all cells)

# %% [markdown]
# # 🚗 RideFlow Marketplace — Domain Pipeline
#
# **Domain Owner:** Marketplace Engineering
# **System:** rideflow
#
# This notebook represents the **Marketplace domain team's** autonomous pipeline. It generates synthetic ride-sharing data, processes it through the full Medallion architecture (Bronze → Silver → Gold), and publishes **Data Products** that other domains can consume.
#
# | Published Data Product | Layer | Description |
# | :-- | :-- | :-- |
# | `silver_rideflow_trips` | Silver | Deduplicated, typed trip fact table |
# | `silver_rideflow_driver_profiles` | Silver | Cleaned driver dimension |
# | `silver_rideflow_rider_profiles` | Silver | Cleaned rider dimension |
# | `gold_rideflow_trip_kpis` | Gold | Revenue, volume, distance KPIs |
# | `gold_rideflow_rider_lifetime_value` | Gold | Rider LTV analysis |
# | `gold_rideflow_surge_pricing_model` | Gold | Dynamic surge multipliers |

# %% [markdown]
# ---
# ## Step 1 · Environment Setup
#
# Install dependencies, detect runtime (Colab vs local), and configure paths.

# %%
import os, subprocess, sys

# ── Install lakelogic ─────────────────────────────────────────────────
# Update the path below to match your local lakelogic checkout.
# On Colab (or if the path doesn't exist), falls back to PyPI.
_LAKELOGIC_LOCAL = r"C:\_Personal\_SaaS\lakelogic"

if os.path.isdir(_LAKELOGIC_LOCAL):
    subprocess.check_call([sys.executable, "-m", "pip", "install", "-e", _LAKELOGIC_LOCAL, "-q"])
    print(f"\u2705 Installed lakelogic (editable) from {_LAKELOGIC_LOCAL}")
else:
    subprocess.check_call([sys.executable, "-m", "pip", "install", "lakelogic", "-q"])
    print("\u2705 Installed lakelogic from PyPI")
# Out:
# ✅ Installed lakelogic (editable) from C:\_Personal\_SaaS\lakelogic

# %%
import subprocess, sys, importlib, os

# Install LakeLogic + dashboard dependencies if missing
for pkg in ["lakelogic", "panel", "hvplot"]:
    if importlib.util.find_spec(pkg) is None:
        subprocess.check_call([sys.executable, "-m", "pip", "install", "-q", f"{pkg}[polars]" if pkg == "lakelogic" else pkg])

# Detect environment
IN_COLAB = "google.colab" in sys.modules
print(f"Running in: {'Google Colab' if IN_COLAB else 'Local'}")


import _setup as s
# Out:
# Running in: Local
# lakelogic v1.18.0 | Local | c:\_Personal\_SaaS\lakelogic\examples\colab

# %%
import panel as pn
import polars as pl
import lakelogic as ll
from pathlib import Path
from datetime import datetime, timezone

# Panel init — use colab comms if in Colab
if IN_COLAB:
    pn.extension('tabulator', comms='colab')
else:
    pn.extension('tabulator', design='bootstrap')

# Paths
DOMAIN_ROOT = Path("assets/domains_rideflow/marketplace/rideflow")
SYSTEM_YAML = str(DOMAIN_ROOT / "_system.yaml")
LAKEHOUSE = Path("./lakehouse")
LANDING_ROOT = LAKEHOUSE / "_data" / "landing_marketplace" / "rideflow"

print(f"lakelogic v{ll.__version__}")
print(f"Lakehouse: {LAKEHOUSE.resolve()}")
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f7d9cf21-5901-4ac7-b076-f1bbea471754'>
#   <div id="da2d45f3-ed03-4e00-b25e-3a0de0dfc350" data-root-id="f7d9cf21-5901-4ac7-b076-f1bbea471754" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"3bbdc14e-1b25-4091-8f35-2a2da57d3380":{"version":"3.9.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"1fd115e4-5932-48de-92ac-65c35a455cab","attributes":{"notifications":{"type":"object","name":"Notifications","id":"ebcb0255-5de0-4d11-8ef8-4dc6b30dd901"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f7d9cf21-5901-4ac7-b076-f1bbea471754"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"54da47f1-19f8-4749-8f2c-df3be88e2305","attributes":{"plot_id":"f7d9cf21-5901-4ac7-b076-f1bbea471754","comm_id":"32dc8ef178f349c7a0851afde4f64a7d","client_comm_id":"7512153c019448a6863605d7963bee55"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"3bbdc14e-1b25-4091-8f35-2a2da57d3380","roots":{"f7d9cf21-5901-4ac7-b076-f1bbea471754":"da2d45f3-ed03-4e00-b25e-3a0de0dfc350"},"root_ids":["f7d9cf21-5901-4ac7-b076-f1bbea471754"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# lakelogic v1.18.0
# Lakehouse: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse

# %% [markdown]
# ---
# ## Step 2 · Load the Data Contract Registry
#
# The `_system.yaml` registry is the single source of truth for this entire platform.
# It declares every entity, its schema contract, lineage rules, materialization strategy, and cost model.
#
# > Changing the `environment` parameter is all it takes to switch between local prototyping and Azure production.

# %%
from lakelogic.core.registry import DomainRegistry

ENV = "colab" if IN_COLAB else "local"
registry = DomainRegistry.from_yaml(SYSTEM_YAML, environment=ENV, storage_mode="direct")

print(f"Domain:  {registry.domain}")
print(f"System:  {registry.system}")
print(f"Env:     {ENV}")
print(f"\nContracts loaded: {len(registry.get_active_contracts())}")
for c in registry.get_active_contracts():
    print(f"  [{c.layer:6s}] {c.entity}")
# Out:
# 2026-04-25 08:50:06.051 | INFO     | lakelogic.core.registry:from_yaml:401 - Domain config inherited from assets\domains_rideflow\marketplace\_domain.yaml
# 2026-04-25 08:50:06.055 | INFO     | lakelogic.core.registry:_validate_observatory_config:286 - ✅ Observatory (_system.yaml): config validated — endpoint=http://127.0.0.1:3007/api/v1/operations/run-logs/ingest, emit_on=['success', 'partial', 'failed'], environments=['dev', 'prod', 'staging', 'local']
# Domain:  marketplace
# System:  rideflow
# Env:     local
#
# Contracts loaded: 15
#   [bronze] rider_profiles
#   [bronze] rider_app_events
#   [bronze] driver_profiles
#   [bronze] driver_telemetry
#   [bronze] trip_requests
#   [bronze] trip_completed
#   [bronze] trip_cancellations
#   [silver] silver_rideflow_driver_profiles
#   [silver] silver_rideflow_driver_telemetry
#   [silver] silver_rideflow_rider_profiles
#   [silver] silver_rideflow_trips
#   [gold  ] gold_rideflow_trip_kpis
#   [gold  ] gold_rideflow_driver_scorecard
#   [gold  ] gold_rideflow_rider_lifetime_value
#   [gold  ] gold_rideflow_surge_pricing_model

# %% [markdown]
# ---
# ## Step 3 · Pipeline Lineage DAG
#
# An interactive topological map of the RideFlow Data Mesh, automatically generated from the declarative `depends_on` rules in the Data Contracts.

# %%
from IPython.display import HTML
from lakelogic.pipeline.runner import LakehousePipeline

pipeline = LakehousePipeline(registry)
display(HTML(pipeline.visualize_dag(title="")))
# Out:
# 2026-04-25 08:50:12.935 | DEBUG    | lakelogic.pipeline.runner:__init__:176 - Disabled DeletionVectors by default in Spark session for OSS compatibility.
#         <div style="font-family:'Inter','Segoe UI',sans-serif;background:#0d0d0f;
#              background-image:radial-gradient(circle at 1px 1px,#1a1a1f 1px,transparent 0);
#              background-size:24px 24px;padding:30px 30px 20px;border-radius:12px;position:relative;overflow-x:auto;">
#           <h2 style="color:#fff;font-size:1.2rem;margin:0 0 4px;"
#               >📊 Pipeline DAG — marketplace / rideflow</h2>
#           <p style="color:#666;font-size:0.8rem;margin:0 0 24px;">15 contracts • 3 layers</p>
#           <div style="position:relative;width:1640px;height:1310px;">
#             <div style="position:absolute;left:50px;top:4px;font-size:0.65rem;font-weight:700;color:#2dd4bf;letter-spacing:0.1em;opacity:0.6;">EXTERNAL</div><div style="position:absolute;left:460px;top:4px;font-size:0.65rem;font-weight:700;color:#daa520;letter-spacing:0.1em;opacity:0.6;">BRONZE</div><div style="position:absolute;left:870px;top:4px;font-size:0.65rem;font-weight:700;color:#8fa4b8;letter-spacing:0.1em;opacity:0.6;">SILVER</div><div style="position:absolute;left:1280px;top:4px;font-size:0.65rem;font-weight:700;color:#ffd700;letter-spacing:0.1em;opacity:0.6;">GOLD</div>
#             <svg style="position:absolute;top:0;left:0;width:100%;
#                         height:100%;pointer-events:none;"
#                  viewBox="0 0 1640 1310">
#               <defs>
#                 <marker id="dag-arrow" viewBox="0 0 12 10"
#                         refX="11" refY="5" markerWidth="10"
#                         markerHeight="8" orient="auto-start-reverse">
#                   <path d="M 0 0 L 12 5 L 0 10 z" fill="#555"/>
#                 </marker>
#                 <marker id="dag-arrow-dep" viewBox="0 0 12 10"
#                         refX="11" refY="5" markerWidth="10"
#                         markerHeight="8" orient="auto-start-reverse">
#                   <path d="M 0 0 L 12 5 L 0 10 z" fill="#4a9eff"/>
#                 </marker>
#               </defs>
#               <path d="M 1010,150 C 1210,190 1210,190 1010,230" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1010,510 C 1210,550 1210,550 1010,590" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1010,150 C 1210,190 1210,550 1010,590" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,640 C 1230,640 1200,100 1280,100" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,640 C 1230,640 1200,280 1280,280" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,100 C 1230,100 1200,280 1280,280" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,640 C 1230,640 1200,460 1280,460" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 1150,460 C 1230,460 1200,460 1280,460" class="dag-dep" style="" marker-end="url(#dag-arrow-dep)"/>
# <path d="M 740,460 C 820,460 790,100 870,100" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 740,100 C 820,100 790,460 870,460" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,100 460,100" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,280 460,280" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,460 460,460" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,640 460,640" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,820 460,820" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,1000 460,1000" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
# <path d="M 330,290 C 410,290 380,1180 460,1180" class="dag-flow" style="" marker-end="url(#dag-arrow)"/>
#
#             </svg>
#
#             <div class="dag-node"
#                  style="left:460px;top:50px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="background:#22c55e;box-shadow:0 0 6px #22c55e;"
#                    ></div>
#               <div class="dag-hdr">
#                 <div class="dag-icon" style="background:#b8860b22;color:#daa520;">📋</div>
#                 <div class="dag-ttl">Bronze — RideFlow Rider Profiles</div>
#               </div>
#               <div class="dag-sys">RIDEFLOW</div>
#               <div class="dag-badges">
#                 <span class="dag-badge" style="background:#b8860b33;color:#daa520;">BRONZE</span>
#                 <span class="dag-badge dag-badge-ver">📄 V1.0.0</span>
#
#
#               </div>
#             </div>
#             <div class="dag-node"
#                  style="left:460px;top:230px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="background:#22c55e;box-shadow:0 0 6px #22c55e;"
#                    ></div>
#               <div class="dag-hdr">
#                 <div class="dag-icon" style="background:#b8860b22;color:#daa520;">📋</div>
#                 <div class="dag-ttl">Bronze — RideFlow Rider App Events</div>
#               </div>
#               <div class="dag-sys">RIDEFLOW</div>
#               <div class="dag-badges">
#                 <span class="dag-badge" style="background:#b8860b33;color:#daa520;">BRONZE</span>
#                 <span class="dag-badge dag-badge-ver">📄 V1.0.0</span>
#
#
#               </div>
#             </div>
#             <div class="dag-node"
#                  style="left:460px;top:410px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="background:#22c55e;box-shadow:0 0 6px #22c55e;"
#                    ></div>
#               <div class="dag-hdr">
#                 <div class="dag-icon" style="background:#b8860b22;color:#daa520;">📋</div>
#                 <div class="dag-ttl">Bronze — RideFlow Driver Profiles</div>
#               </div>
#               <div class="dag-sys">RIDEFLOW</div>
#               <div class="dag-badges">
#                 <span class="dag-badge" style="background:#b8860b33;color:#daa520;">BRONZE</span>
#                 <span class="dag-badge dag-badge-ver">📄 V1.0.0</span>
#
#
#               </div>
#             </div>
#             <div class="dag-node"
#                  style="left:460px;top:590px;border-color:#b8860b55;opacity:1.0;"
#                  onmouseover="this.style.borderColor='#b8860bcc';this.style.boxShadow='0 8px 32px #b8860b33';this.style.opacity='1.0'"
#                  onmouseout="this.style.borderColor='#b8860b55';this.style.boxShadow='none';this.style.opacity='1.0'">
#               <div class="dag-dot"
#                    style="background:#22c55e;box-shadow:0 0 6px #22c55e;"
#                    ></div>
#               <div class="dag-hdr">
#                 <div class="dag-icon" style="background:#b8860b22;color:#daa520;">📋</div>
#                 <div class="dag-ttl">Bronze — RideFlow Driver Telemetry</div>
#               </div>
#               <div class="dag-sys">RIDEFLOW</div>
#               <div class="dag-badges">
#                 <span class="dag-badge" style="background:#b8860b33;color:#daa520;">BRONZE</span>
#                 <span class="dag-badge dag-badge-ver">📄 V1.0.0</span>

# %% [markdown]
# ---
# ## Step 4 · Generate Streaming Data
#
# The `StreamingSimulator` generates **24 hours** of realistic ride-sharing data:
# - **Dimension entities** (riders, drivers) with stable identity pools
# - **Fact entities** (trip requests → completions → cancellations) following hour-of-day demand curves
# - **Event entities** (telemetry, app events) proportional to active trips
#
# All entities maintain **referential integrity** — every `rider_id` in a trip exists in the rider pool.

# %%
from lakelogic.core.streaming import StreamingSimulator
from datetime import timedelta

sim = StreamingSimulator.rideflow_marketplace(
    landing_root=str(LANDING_ROOT),
    window_minutes=60,
    start_time=datetime.now(timezone.utc) - timedelta(days=1),
    seed=42,
    initial_riders=200,
    initial_drivers=100,
)

print("🚀 Streaming simulator configured")
print(f"   Landing root: {LANDING_ROOT}")
print(f"   Window size:  60 minutes")
print(f"   Entities:     7 (2 dimensions, 3 facts, 2 events)")
# Out:
# 🚀 Streaming simulator configured
#    Landing root: lakehouse\_data\landing_marketplace\rideflow
#    Window size:  60 minutes
#    Entities:     7 (2 dimensions, 3 facts, 2 events)

# %%
# Generate 24 hours of simulated streaming data
NUM_WINDOWS = 24

total_rows = 0
windows = []
for window in sim.run(num_windows=NUM_WINDOWS, micro_batches=10, up_to=datetime.now(timezone.utc), resume=True):
    windows.append(window)
    total_rows += window.total_rows

print(f"\n{'='*60}")
if not windows:
    print("✅ No new windows generated. The simulator has caught up to the current time (up_to constraint reached).")
else:
    print(f"✅ Generated {total_rows:,} total rows across {len(windows)} windows")
    print(f"   Seed window:    {windows[0].total_rows:,} rows (initial pool)")
    print(f"   Avg per window: {total_rows // len(windows):,} rows")

# FK consistency check
fk = sim.validate_fk_consistency()
print(f"\n🔗 FK Consistency:")
print(f"   Riders:    {fk['total_riders']}")
print(f"   Drivers:   {fk['total_drivers']}")
print(f"   Healthy:   {'✅' if fk['fk_pools_healthy'] else '❌'}")
# Out:
# 2026-04-25 08:50:13.128 | INFO     | lakelogic.core.streaming:_rebuild_state_from_landing:808 - Resumed: 403 riders, 153 drivers rebuilt. Next window: 2026-04-23T23:00:00+00:00
# 2026-04-25 08:50:13.172 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   0 | 2026-04-23 23:00 |   403 rows | rider_profiles=12 driver_profiles=3 trip_requests=38 trip_completed=27 trip_cancellations=6 driver_telemetry=242 rider_app_events=75 | 10 micro-batches/entity
# 2026-04-25 08:50:13.219 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   1 | 2026-04-24 00:00 |   380 rows | rider_profiles=12 driver_profiles=3 trip_requests=37 trip_completed=28 trip_cancellations=5 driver_telemetry=228 rider_app_events=67 | 10 micro-batches/entity
# 2026-04-25 08:50:13.259 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   2 | 2026-04-24 01:00 |   339 rows | rider_profiles=12 driver_profiles=3 trip_requests=35 trip_completed=26 trip_cancellations=5 driver_telemetry=183 rider_app_events=75 | 10 micro-batches/entity
# 2026-04-25 08:50:13.294 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   3 | 2026-04-24 02:00 |   314 rows | rider_profiles=13 driver_profiles=3 trip_requests=28 trip_completed=20 trip_cancellations=4 driver_telemetry=176 rider_app_events=70 | 10 micro-batches/entity
# 2026-04-25 08:50:13.327 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   4 | 2026-04-24 03:00 |   288 rows | rider_profiles=13 driver_profiles=3 trip_requests=30 trip_completed=23 trip_cancellations=4 driver_telemetry=153 rider_app_events=62 | 10 micro-batches/entity
# 2026-04-25 08:50:13.360 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   5 | 2026-04-24 04:00 |   274 rows | rider_profiles=13 driver_profiles=3 trip_requests=28 trip_completed=20 trip_cancellations=5 driver_telemetry=142 rider_app_events=63 | 10 micro-batches/entity
# 2026-04-25 08:50:13.393 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   6 | 2026-04-24 05:00 |   332 rows | rider_profiles=14 driver_profiles=3 trip_requests=29 trip_completed=22 trip_cancellations=5 driver_telemetry=181 rider_app_events=78 | 10 micro-batches/entity
# 2026-04-25 08:50:13.428 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   7 | 2026-04-24 06:00 |   400 rows | rider_profiles=14 driver_profiles=3 trip_requests=41 trip_completed=25 trip_cancellations=5 driver_telemetry=231 rider_app_events=81 | 10 micro-batches/entity
# 2026-04-25 08:50:13.475 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   8 | 2026-04-24 07:00 |   621 rows | rider_profiles=15 driver_profiles=3 trip_requests=63 trip_completed=43 trip_cancellations=9 driver_telemetry=371 rider_app_events=117 | 10 micro-batches/entity
# 2026-04-25 08:50:13.525 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window   9 | 2026-04-24 08:00 |   772 rows | rider_profiles=15 driver_profiles=3 trip_requests=94 trip_completed=60 trip_cancellations=11 driver_telemetry=402 rider_app_events=187 | 10 micro-batches/entity
# 2026-04-25 08:50:13.576 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  10 | 2026-04-24 09:00 |   696 rows | rider_profiles=16 driver_profiles=3 trip_requests=83 trip_completed=65 trip_cancellations=9 driver_telemetry=370 rider_app_events=150 | 10 micro-batches/entity
# 2026-04-25 08:50:13.628 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  11 | 2026-04-24 10:00 |   608 rows | rider_profiles=16 driver_profiles=3 trip_requests=77 trip_completed=51 trip_cancellations=8 driver_telemetry=327 rider_app_events=126 | 10 micro-batches/entity
# 2026-04-25 08:50:13.691 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  12 | 2026-04-24 11:00 |   625 rows | rider_profiles=17 driver_profiles=3 trip_requests=66 trip_completed=61 trip_cancellations=8 driver_telemetry=352 rider_app_events=118 | 10 micro-batches/entity
# 2026-04-25 08:50:13.739 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  13 | 2026-04-24 12:00 |   729 rows | rider_profiles=17 driver_profiles=3 trip_requests=85 trip_completed=62 trip_cancellations=10 driver_telemetry=416 rider_app_events=136 | 10 micro-batches/entity
# 2026-04-25 08:50:13.781 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  14 | 2026-04-24 13:00 |   619 rows | rider_profiles=18 driver_profiles=3 trip_requests=59 trip_completed=56 trip_cancellations=9 driver_telemetry=344 rider_app_events=130 | 10 micro-batches/entity
# 2026-04-25 08:50:13.823 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  15 | 2026-04-24 14:00 |   637 rows | rider_profiles=18 driver_profiles=3 trip_requests=58 trip_completed=54 trip_cancellations=7 driver_telemetry=382 rider_app_events=115 | 10 micro-batches/entity
# 2026-04-25 08:50:13.868 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  16 | 2026-04-24 15:00 |   619 rows | rider_profiles=19 driver_profiles=4 trip_requests=78 trip_completed=48 trip_cancellations=9 driver_telemetry=316 rider_app_events=145 | 10 micro-batches/entity
# 2026-04-25 08:50:13.915 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  17 | 2026-04-24 16:00 |   737 rows | rider_profiles=19 driver_profiles=4 trip_requests=80 trip_completed=58 trip_cancellations=9 driver_telemetry=412 rider_app_events=155 | 10 micro-batches/entity
# 2026-04-25 08:50:13.959 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  18 | 2026-04-24 17:00 |   835 rows | rider_profiles=20 driver_profiles=4 trip_requests=92 trip_completed=65 trip_cancellations=12 driver_telemetry=483 rider_app_events=159 | 10 micro-batches/entity
# 2026-04-25 08:50:14.043 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  19 | 2026-04-24 18:00 |   802 rows | rider_profiles=20 driver_profiles=4 trip_requests=84 trip_completed=63 trip_cancellations=9 driver_telemetry=465 rider_app_events=157 | 10 micro-batches/entity
# 2026-04-25 08:50:14.088 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  20 | 2026-04-24 19:00 |   800 rows | rider_profiles=21 driver_profiles=4 trip_requests=84 trip_completed=60 trip_cancellations=11 driver_telemetry=482 rider_app_events=138 | 10 micro-batches/entity
# 2026-04-25 08:50:14.140 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  21 | 2026-04-24 20:00 |   671 rows | rider_profiles=22 driver_profiles=4 trip_requests=78 trip_completed=52 trip_cancellations=9 driver_telemetry=353 rider_app_events=153 | 10 micro-batches/entity
# 2026-04-25 08:50:14.199 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  22 | 2026-04-24 21:00 |   543 rows | rider_profiles=22 driver_profiles=4 trip_requests=59 trip_completed=40 trip_cancellations=8 driver_telemetry=307 rider_app_events=103 | 10 micro-batches/entity
# 2026-04-25 08:50:14.255 | INFO     | lakelogic.core.streaming:run:711 - ⏱ Window  23 | 2026-04-24 22:00 |   530 rows | rider_profiles=23 driver_profiles=4 trip_requests=46 trip_completed=41 trip_cancellations=7 driver_telemetry=305 rider_app_events=104 | 10 micro-batches/entity
# ============================================================
# ✅ Generated 13,574 total rows across 24 windows
#    Seed window:    403 rows (initial pool)
#    Avg per window: 565 rows
#
# 🔗 FK Consistency:
#    Riders:    792
#    Drivers:   232
#    Healthy:   ✅

# %%
# Verify partition structure
import glob

for entity in ["trip_requests", "trip_completed", "rider_profiles"]:
    files = glob.glob(str(LANDING_ROOT / entity / "**/*.csv"), recursive=True)
    print(f"  {entity}: {len(files)} partition files")
    if files:
        # Show first and last partition path
        files.sort()
        print(f"    First: {files[0].split(entity)[-1]}")
        print(f"    Last:  {files[-1].split(entity)[-1]}")
# Out:
#   trip_requests: 490 partition files
#     First: \y_2026\m_04\d_22\h_21\batch_00_b87f87.csv
#     Last:  \y_2026\m_04\d_24\h_22\batch_09_cf568a.csv
#   trip_completed: 468 partition files
#     First: \y_2026\m_04\d_15\h_99\edge_cases.csv
#     Last:  \y_2026\m_04\d_24\h_22\batch_08_eb2603.csv
#   rider_profiles: 386 partition files
#     First: \y_2026\m_04\d_22\h_21\batch_00_527e10.csv
#     Last:  \y_2026\m_04\d_24\h_22\batch_07_d4c279.csv

# %% [markdown]
# ---
# ## Step 4.5 · Inject Deterministic Edge Cases (TC-001 to TC-008)
#
# The StreamingSimulator above generated realistic, time-aware trip data with organic variance.
# Now we surgically inject **exactly 800 edge-case rows** into the `trip_completed` landing directory.
# These represent 8 specific failure modes that the pipeline's quarantine layer must catch:
#
# | TC | Description | Rows | What the pipeline should catch |
# | :-- | :-- | --: | :-- |
# | TC-001 | Negative fare | 120 | Business logic: `fare_amount >= 0` |
# | TC-002 | driver_id = rider_id | 80 | Self-service fraud detection |
# | TC-003 | Dropoff before pickup | 150 | Temporal sanity: `dropoff_at > pickup_at` |
# | TC-004 | Distance > 500km | 100 | Geospatial bounds check |
# | TC-005 | SQL injection in notes | 150 | Security / input sanitization |
# | TC-006 | Surge > 5.0x | 80 | Cap violation: `surge_multiplier <= 5.0` |
# | TC-007 | Unknown city code | 60 | Referential integrity check |
# | TC-008 | Duplicate trip_id | 60 | Idempotency / uniqueness constraint |
#
# After the pipeline runs, we expect:
# ```
# source_count = good_count + bad_count
# "100% reconciliation. Every row accounted for."
# ```

# %%
# ── Deterministic Edge-Case Injection ────────────────────────────────────
# Injects exactly 800 mutated rows into the trip_completed landing zone
# so the pipeline quarantine layer can demonstrate 100% reconciliation.

import polars as pl
import uuid, random
from datetime import datetime, timedelta, timezone

random.seed(42)
NUM_EDGE_CASES = 800

CITY_PROFILES = {
    "LON": {"timezone": "Europe/London",   "base_trips_per_hour": 500},
    "NYC": {"timezone": "US/Eastern",      "base_trips_per_hour": 800},
    "BER": {"timezone": "Europe/Berlin",   "base_trips_per_hour": 200},
    "PAR": {"timezone": "Europe/Paris",    "base_trips_per_hour": 350},
    "TYO": {"timezone": "Asia/Tokyo",      "base_trips_per_hour": 600},
    "SYD": {"timezone": "Australia/Sydney", "base_trips_per_hour": 150},
}

cities = list(CITY_PROFILES.keys())
base_time = datetime(2026, 4, 15, 8, 0, tzinfo=timezone.utc)

# Generate 800 base rows with valid structure
records = []
for i in range(NUM_EDGE_CASES):
    trip_id = str(uuid.uuid4())
    rider_id = f"R-{uuid.uuid4().hex[:8]}"
    driver_id = f"D-{uuid.uuid4().hex[:8]}"
    city = random.choice(cities)
    hr = random.choices(range(24), weights=[1,1,1,1,1,1,1,3,3,1,1,1,1,1,1,1,1,3,4,4,3,1,1,1])[0]
    req_dt = base_time.replace(hour=hr, minute=random.randint(0, 59))
    pickup_dt = req_dt + timedelta(minutes=random.randint(1, 10))
    dropoff_dt = req_dt + timedelta(minutes=random.randint(15, 60))

    records.append({
        "trip_id": trip_id,
        "rider_id": rider_id,
        "driver_id": driver_id,
        "trip_type": random.choice(["ride", "eats_delivery"]),
        "pickup_lat": str(round(random.uniform(51.4, 51.6), 6)),
        "pickup_lng": str(round(random.uniform(-0.2, 0.1), 6)),
        "dropoff_lat": str(round(random.uniform(51.4, 51.6), 6)),
        "dropoff_lng": str(round(random.uniform(-0.2, 0.1), 6)),
        "city_code": city,
        "requested_at": req_dt.strftime("%Y-%m-%dT%H:%M:%SZ"),
        "pickup_at": pickup_dt.strftime("%Y-%m-%dT%H:%M:%SZ"),
        "dropoff_at": dropoff_dt.strftime("%Y-%m-%dT%H:%M:%SZ"),
        "distance_km": str(round(random.uniform(1, 25), 1)),
        "duration_minutes": str(random.randint(5, 45)),
        "fare_amount": str(round(random.uniform(5, 80), 2)),
        "surge_multiplier": str(round(random.uniform(1.0, 3.5), 2)),
        "tip_amount": str(round(random.uniform(0, 10), 2)),
        "payment_method": random.choice(["card", "apple_pay", "google_pay", "cash"]),
        "rider_rating": str(random.randint(1, 5)),
        "driver_rating": str(random.randint(1, 5)),
        "notes": "",
    })

# ── Apply TC-001 to TC-008 mutations ──────────────────────────────────────
for i in range(0, 120):   records[i]["fare_amount"] = "-15.50"               # TC-001: Negative fare
for i in range(120, 200): records[i]["driver_id"] = records[i]["rider_id"]    # TC-002: Self-service fraud
for i in range(200, 350):                                                      # TC-003: Time travel
    records[i]["pickup_at"]  = "2026-04-15T12:00:00Z"
    records[i]["dropoff_at"] = "2026-04-15T11:00:00Z"
for i in range(350, 450): records[i]["distance_km"] = "650.5"                 # TC-004: Impossible trip
for i in range(450, 600): records[i]["notes"] = "DROP TABLE trips; SELECT * FROM users;"  # TC-005
for i in range(600, 680): records[i]["surge_multiplier"] = "5.8"              # TC-006: Cap violation
for i in range(680, 740): records[i]["city_code"] = "XYZ"                     # TC-007: Unknown market
dup_id = records[0]["trip_id"]  # Reuse first trip's ID
for i in range(740, 800): records[i]["trip_id"] = dup_id                      # TC-008: Duplicate ID

random.shuffle(records)
edge_df = pl.DataFrame(records)

# Write to the trip_completed landing directory as a separate partition file
edge_dir = LANDING_ROOT / "trip_completed" / "y_2026" / "m_04" / "d_15" / "h_99"
edge_dir.mkdir(parents=True, exist_ok=True)
edge_file = edge_dir / "edge_cases.csv"
edge_df.write_csv(str(edge_file))

print(f"\u2705 Injected {NUM_EDGE_CASES} deterministic edge cases into landing zone")
print(f"   File: {edge_file}")
print()
print(f"   TC-001  Negative fare:         120 rows")
print(f"   TC-002  driver_id=rider_id:      80 rows")
print(f"   TC-003  Dropoff before pickup:  150 rows")
print(f"   TC-004  Distance > 500km:       100 rows")
print(f"   TC-005  SQL injection in notes: 150 rows")
print(f"   TC-006  Surge > 5.0x:            80 rows")
print(f"   TC-007  Unknown city code:        60 rows")
print(f"   TC-008  Duplicate trip_id:        60 rows")
print(f"   {'='*45}")
print(f"   TOTAL edge cases:               {NUM_EDGE_CASES} rows")
# Out:
# ✅ Injected 800 deterministic edge cases into landing zone
#    File: lakehouse\_data\landing_marketplace\rideflow\trip_completed\y_2026\m_04\d_15\h_99\edge_cases.csv
#
#    TC-001  Negative fare:         120 rows
#    TC-002  driver_id=rider_id:      80 rows
#    TC-003  Dropoff before pickup:  150 rows
#    TC-004  Distance > 500km:       100 rows
#    TC-005  SQL injection in notes: 150 rows
#    TC-006  Surge > 5.0x:            80 rows
#    TC-007  Unknown city code:        60 rows
#    TC-008  Duplicate trip_id:        60 rows
#    =============================================
#    TOTAL edge cases:               800 rows

# %% [markdown]
# ---
# ## Pipeline Config
#
# - **retry_attempts**: Max retries if a dataset fails due to temporary network or storage glitches.
# - **retry_base_wait_seconds**: Initial wait time before retrying. Automatically scales up (e.g., 5s, 10s, 20s) to avoid overwhelming the system.
# - **parallel**: Processes independent datasets simultaneously across multiple CPU threads for much faster ingestion.
# - **engine**: Defines the compute backend (`polars` for local speed, `spark` for distributed clusters).
# - **reload_layers**: Forces a complete historical wipe and reload of specific layers (e.g., `"silver,gold"`).

# %%
retry_attempts = 1
parallel = True
retry_base_wait_seconds = 5
engine = "duckdb"
reload_layers = ""
enable_incremental_streaming = False

# %% [markdown]
# ---
# ## Step 5 · Bronze Ingestion
#
# Ingest the streaming landing data into Bronze Delta tables. Every row gets lineage columns (`_lakelogic_source`, `_lakelogic_processed_at`, `_lakelogic_run_id`) automatically injected.

# %%
from lakelogic.pipeline.runner import LakehousePipeline
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)

print("Starting Bronze Ingestion via LakeLogic Pipeline Driver...")
runner = LakehousePipeline(registry, engine=engine)

summary = runner.run(
    target_layers="bronze", 
    reload_layers = reload_layers,
    dry_run=False,
    environment=ENV,
    retry_attempts=retry_attempts,
    retry_base_wait_seconds=retry_base_wait_seconds,
    parallel=False
)

print(summary)
# Out:
# 2026-04-25 08:50:14.457 | INFO     | lakelogic.pipeline.runner:run:1479 - Pipeline storage mode: direct
# 2026-04-25 08:50:14.459 | INFO     | lakelogic.pipeline.runner:run:1580 - ── Processing Layer: BRONZE (7 contracts) ──
# 2026-04-25 08:50:14.461 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:14.461 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [bronze] rider_profiles | Contract: Bronze — RideFlow Rider Profiles v1.0.0
# Starting Bronze Ingestion via LakeLogic Pipeline Driver...
# 2026-04-25 08:50:14.729 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\rider_profiles via duckdb
# 2026-04-25 08:50:14.995 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2880 - Date-partitioned scan: 12 files found across 3 partitions (2026-04-23 to 2026-04-25)
# 2026-04-25 08:50:15.208 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=bronze] | Source: 12 | Total: 12 | Good: 12 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:15.250 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 391 rows in lakehouse\marketplace\bronze\bronze_rideflow_rider_profiles (appending 12 new rows)
# 2026-04-25 08:50:15.315 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 12 rows to Delta table: lakehouse\marketplace\bronze\bronze_rideflow_rider_profiles (strategy=append, mode=append)
# 2026-04-25 08:50:15.316 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:15.564 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:15.566 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:15.566 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:15.787 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Bronze — RideFlow Rider Profiles)
# 2026-04-25 08:50:15.839 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:15.839 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"7fed7bf4-58b5-4cdb-bcda-a10fb21918b0","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:15.843 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:15.843 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [bronze] rider_app_events | Contract: Bronze — RideFlow Rider App Events v1.0.0
# 2026-04-25 08:50:15.857 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\rider_app_events via duckdb
# 2026-04-25 08:50:15.928 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2880 - Date-partitioned scan: 20 files found across 3 partitions (2026-04-23 to 2026-04-25)
# 2026-04-25 08:50:16.025 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=bronze] | Source: 67 | Total: 67 | Good: 67 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:16.054 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 2831 rows in lakehouse\marketplace\bronze\bronze_rideflow_rider_app_events (appending 67 new rows)
# 2026-04-25 08:50:16.073 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 67 rows to Delta table: lakehouse\marketplace\bronze\bronze_rideflow_rider_app_events (strategy=append, mode=append)
# 2026-04-25 08:50:16.074 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:16.196 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:16.196 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:16.197 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:16.198 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Bronze — RideFlow Rider App Events)
# 2026-04-25 08:50:16.240 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:16.241 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"51c72911-e7da-4bcc-a893-5660b6f80b74","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:16.245 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:16.245 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [bronze] driver_profiles | Contract: Bronze — RideFlow Driver Profiles v1.0.0
# 2026-04-25 08:50:16.260 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\driver_profiles via duckdb
# 2026-04-25 08:50:16.326 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2880 - Date-partitioned scan: 5 files found across 3 partitions (2026-04-23 to 2026-04-25)
# 2026-04-25 08:50:16.433 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=bronze] | Source: 3 | Total: 3 | Good: 3 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:16.463 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 148 rows in lakehouse\marketplace\bronze\bronze_rideflow_driver_profiles (appending 3 new rows)
# 2026-04-25 08:50:16.483 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 3 rows to Delta table: lakehouse\marketplace\bronze\bronze_rideflow_driver_profiles (strategy=append, mode=append)
# 2026-04-25 08:50:16.485 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:16.608 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:16.609 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:16.609 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:16.611 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Bronze — RideFlow Driver Profiles)
# 2026-04-25 08:50:16.644 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:16.644 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"8c9b6bda-b2aa-494b-a955-3ea473573b53","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:16.649 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:16.649 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [bronze] driver_telemetry | Contract: Bronze — RideFlow Driver Telemetry v1.0.0
# 2026-04-25 08:50:16.663 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\driver_telemetry via duckdb
# 2026-04-25 08:50:16.734 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2880 - Date-partitioned scan: 20 files found across 3 partitions (2026-04-23 to 2026-04-25)
# 2026-04-25 08:50:16.853 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=bronze] | Source: 228 | Total: 228 | Good: 228 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:16.878 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 8017 rows in lakehouse\marketplace\bronze\bronze_rideflow_driver_telemetry (appending 228 new rows)
# 2026-04-25 08:50:16.896 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 228 rows to Delta table: lakehouse\marketplace\bronze\bronze_rideflow_driver_telemetry (strategy=append, mode=append)
# 2026-04-25 08:50:16.897 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:17.033 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:17.034 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:17.035 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:17.035 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Bronze — RideFlow Driver Telemetry)
# 2026-04-25 08:50:17.083 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:17.083 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"e1b9e84a-6cdd-427b-879f-bf8ce9447428","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:17.088 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:17.089 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [bronze] trip_requests | Contract: Bronze — RideFlow Trip Requests v1.0.0
# 2026-04-25 08:50:17.103 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\trip_requests via duckdb
# 2026-04-25 08:50:17.171 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2880 - Date-partitioned scan: 20 files found across 3 partitions (2026-04-23 to 2026-04-25)
# 2026-04-25 08:50:17.272 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=bronze] | Source: 37 | Total: 37 | Good: 37 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:17.303 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 1445 rows in lakehouse\marketplace\bronze\bronze_rideflow_trip_requests (appending 37 new rows)
# 2026-04-25 08:50:17.321 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 37 rows to Delta table: lakehouse\marketplace\bronze\bronze_rideflow_trip_requests (strategy=append, mode=append)
# 2026-04-25 08:50:17.322 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:17.450 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:17.450 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:17.450 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:17.450 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Bronze — RideFlow Trip Requests)
# 2026-04-25 08:50:17.483 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:17.483 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"979c64ba-7719-41a7-99b0-511efb1691d1","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:17.488 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:17.488 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [bronze] trip_completed | Contract: Bronze — RideFlow Trip Completed v1.0.0
# 2026-04-25 08:50:17.501 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\trip_completed via duckdb
# 2026-04-25 08:50:17.573 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2880 - Date-partitioned scan: 19 files found across 3 partitions (2026-04-23 to 2026-04-25)
# 2026-04-25 08:50:17.686 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=bronze] | Source: 28 | Total: 28 | Good: 28 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:17.719 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 1880 rows in lakehouse\marketplace\bronze\bronze_rideflow_trip_completed (appending 28 new rows)
# 2026-04-25 08:50:17.741 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 28 rows to Delta table: lakehouse\marketplace\bronze\bronze_rideflow_trip_completed (strategy=append, mode=append)
# 2026-04-25 08:50:17.741 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:17.923 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:17.924 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:17.925 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:17.925 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Bronze — RideFlow Trip Completed)
# 2026-04-25 08:50:17.955 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:17.956 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"3977b283-9186-43a7-8bd6-c991a2bfcf09","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:17.959 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:17.959 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [bronze] trip_cancellations | Contract: Bronze — RideFlow Trip Cancellations v1.0.0
# 2026-04-25 08:50:17.974 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\_data\landing_marketplace\rideflow\trip_cancellations via duckdb
# 2026-04-25 08:50:18.057 | INFO     | lakelogic.core.processor:_expand_partitioned_paths:2880 - Date-partitioned scan: 10 files found across 3 partitions (2026-04-23 to 2026-04-25)
# 2026-04-25 08:50:18.171 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=bronze] | Source: 5 | Total: 5 | Good: 5 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:18.202 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 172 rows in lakehouse\marketplace\bronze\bronze_rideflow_trip_cancellations (appending 5 new rows)
# 2026-04-25 08:50:18.220 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 5 rows to Delta table: lakehouse\marketplace\bronze\bronze_rideflow_trip_cancellations (strategy=append, mode=append)
# 2026-04-25 08:50:18.221 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:18.353 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:18.353 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:18.355 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:18.356 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Bronze — RideFlow Trip Cancellations)
# 2026-04-25 08:50:18.387 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:18.388 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"fc96f1e4-f4a9-4915-8c51-937f0b5b3842","quarantine_records":0,"status":"ingested"}
# ================================================================================
#  PIPELINE RUN SUMMARY
# ================================================================================
#   Pipeline run    : c1a9f5c4-f377-4a67-bc6c-706243a543a9
#   Environment     : local
#   Dry run         : False
#
#   Table Name                             Layer    Status     Rows     Good/Qrtn
#   ------------------------------------------------------------------------------
#   bronze_rideflow_rider_profiles         bronze   success    12       12/0
#   bronze_rideflow_rider_app_events       bronze   success    67       67/0
#   bronze_rideflow_driver_profiles        bronze   success    3        3/0
#   bronze_rideflow_driver_telemetry       bronze   success    228      228/0
#   bronze_rideflow_trip_requests          bronze   success    37       37/0
#   bronze_rideflow_trip_completed         bronze   success    28       28/0
#   bronze_rideflow_trip_cancellations     bronze   success    5        5/0
# ================================================================================

# %% [markdown]
# ---
# ## Step 6 · Silver Processing
#
# Silver layer: type casting, deduplication, and merge. Schema enforcement quarantines rows that don't match the contract — no silent data corruption.

# %%
print("Starting Silver Processing via LakeLogic Pipeline Driver...")

summary = runner.run(
    target_layers="silver", 
    reload_layers = reload_layers,
    dry_run=False,
    environment=ENV,
    retry_attempts=retry_attempts,
    retry_base_wait_seconds=retry_base_wait_seconds,
    parallel=parallel
)

print(summary)
# Out:
# 2026-04-25 08:50:18.406 | INFO     | lakelogic.pipeline.runner:run:1479 - Pipeline storage mode: direct
# 2026-04-25 08:50:18.408 | INFO     | lakelogic.pipeline.runner:run:1580 - ── Processing Layer: SILVER (4 contracts) ──
# 2026-04-25 08:50:18.408 | INFO     | lakelogic.pipeline.runner:run:1599 -   Wave 0: [silver_rideflow_driver_profiles, silver_rideflow_rider_profiles] (parallel)
# 2026-04-25 08:50:18.410 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 - [silver_rideflow_driver_profiles]   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:18.413 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 - [silver_rideflow_rider_profiles]   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:18.413 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 - [silver_rideflow_driver_profiles]   📄 [silver] silver_rideflow_driver_profiles | Contract: Silver — Rideflow Driver Profiles v1.0.0
# 2026-04-25 08:50:18.416 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 - [silver_rideflow_rider_profiles]   📄 [silver] silver_rideflow_rider_profiles | Contract: Silver — Rideflow Rider Profiles v1.0.0
# 2026-04-25 08:50:18.432 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_rider_profiles via duckdb
# 2026-04-25 08:50:18.432 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_rider_profiles via duckdb
# 2026-04-25 08:50:18.433 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_driver_profiles via duckdb
# 2026-04-25 08:50:18.433 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_driver_profiles via duckdb
# Starting Silver Processing via LakeLogic Pipeline Driver...
# 2026-04-25 08:50:18.582 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: rider_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-25 08:50:18.582 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: rider_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-25 08:50:18.582 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: driver_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-25 08:50:18.582 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: driver_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-25 08:50:18.627 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 403 | Total: 403 | Good: 403 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:18.627 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 403 | Total: 403 | Good: 403 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:18.627 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 151 | Total: 151 | Good: 151 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:18.627 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 151 | Total: 151 | Good: 151 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:18.667 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 391 rows in lakehouse\marketplace\silver\silver_rideflow_rider_profiles (appending 403 new rows)
# 2026-04-25 08:50:18.667 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 391 rows in lakehouse\marketplace\silver\silver_rideflow_rider_profiles (appending 403 new rows)
# 2026-04-25 08:50:18.667 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 1 column(s) to match existing Delta table schema
# 2026-04-25 08:50:18.667 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 1 column(s) to match existing Delta table schema
# 2026-04-25 08:50:18.674 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 148 rows in lakehouse\marketplace\silver\silver_rideflow_driver_profiles (appending 151 new rows)
# 2026-04-25 08:50:18.674 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 148 rows in lakehouse\marketplace\silver\silver_rideflow_driver_profiles (appending 151 new rows)
# 2026-04-25 08:50:18.723 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 403 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_rider_profiles (strategy=merge, mode=append)
# 2026-04-25 08:50:18.723 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 403 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_rider_profiles (strategy=merge, mode=append)
# 2026-04-25 08:50:18.723 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 151 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_driver_profiles (strategy=merge, mode=append)
# 2026-04-25 08:50:18.723 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 151 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_driver_profiles (strategy=merge, mode=append)
# 2026-04-25 08:50:18.725 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:18.725 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:18.725 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:18.725 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:18.915 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:18.915 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:18.919 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:18.919 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:18.920 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:18.920 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:18.920 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Rider Profiles)
# 2026-04-25 08:50:18.920 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Rider Profiles)
# 2026-04-25 08:50:18.957 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:18.957 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:18.957 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"a6e32d77-bbfa-4166-828e-f4948bea3ee5","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:18.957 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"a6e32d77-bbfa-4166-828e-f4948bea3ee5","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:19.318 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:19.318 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:19.319 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:19.319 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:19.320 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:19.320 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:19.320 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Driver Profiles)
# 2026-04-25 08:50:19.320 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Driver Profiles)
# 2026-04-25 08:50:19.360 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:19.360 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:19.361 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"d790b069-d8ea-45aa-932b-9d256eba0362","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:19.361 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"d790b069-d8ea-45aa-932b-9d256eba0362","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:19.362 | INFO     | lakelogic.pipeline.runner:run:1599 -   Wave 1: [silver_rideflow_driver_telemetry, silver_rideflow_trips] (parallel)
# 2026-04-25 08:50:19.362 | INFO     | lakelogic.pipeline.runner:run:1599 -   Wave 1: [silver_rideflow_driver_telemetry, silver_rideflow_trips] (parallel)
# 2026-04-25 08:50:19.364 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:19.364 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:19.367 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:19.367 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:19.370 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [silver] silver_rideflow_driver_telemetry | Contract: Silver — Rideflow Driver Telemetry v1.0.0
# 2026-04-25 08:50:19.370 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [silver] silver_rideflow_driver_telemetry | Contract: Silver — Rideflow Driver Telemetry v1.0.0
# 2026-04-25 08:50:19.370 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [silver] silver_rideflow_trips | Contract: Silver — Rideflow Trips v1.0.0
# 2026-04-25 08:50:19.370 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [silver] silver_rideflow_trips | Contract: Silver — Rideflow Trips v1.0.0
# 2026-04-25 08:50:19.387 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_trip_completed via duckdb
# 2026-04-25 08:50:19.387 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_trip_completed via duckdb
# 2026-04-25 08:50:19.393 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_driver_telemetry via duckdb
# 2026-04-25 08:50:19.393 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\bronze\bronze_rideflow_driver_telemetry via duckdb
# 2026-04-25 08:50:19.945 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: telemetry_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-25 08:50:19.945 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: telemetry_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-25 08:50:19.987 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: trip_id_unique | Result: 60 (expected < 1.0) | Status: FAIL
# 2026-04-25 08:50:19.987 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: trip_id_unique | Result: 60 (expected < 1.0) | Status: FAIL
# 2026-04-25 08:50:20.083 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 8245 | Total: 8245 | Good: 8245 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:20.083 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 8245 | Total: 8245 | Good: 8245 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:20.094 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 1908 | Total: 1908 | Good: 1908 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:20.094 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=silver] | Source: 1908 | Total: 1908 | Good: 1908 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:20.138 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 1 column(s) to match existing Delta table schema
# 2026-04-25 08:50:20.138 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 1 column(s) to match existing Delta table schema
# 2026-04-25 08:50:20.145 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 8017 rows in lakehouse\marketplace\silver\silver_rideflow_driver_telemetry (appending 8245 new rows)
# 2026-04-25 08:50:20.145 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 8017 rows in lakehouse\marketplace\silver\silver_rideflow_driver_telemetry (appending 8245 new rows)
# 2026-04-25 08:50:20.155 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 7 column(s) to match existing Delta table schema
# 2026-04-25 08:50:20.155 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 7 column(s) to match existing Delta table schema
# 2026-04-25 08:50:20.159 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 1880 rows in lakehouse\marketplace\silver\silver_rideflow_trips (appending 1908 new rows)
# 2026-04-25 08:50:20.159 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 1880 rows in lakehouse\marketplace\silver\silver_rideflow_trips (appending 1908 new rows)
# 2026-04-25 08:50:20.199 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 8245 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_driver_telemetry (strategy=merge, mode=append)
# 2026-04-25 08:50:20.199 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 8245 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_driver_telemetry (strategy=merge, mode=append)
# 2026-04-25 08:50:20.201 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:20.201 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:20.201 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 1908 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_trips (strategy=merge, mode=append)
# 2026-04-25 08:50:20.201 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 1908 rows to Delta table: lakehouse\marketplace\silver\silver_rideflow_trips (strategy=merge, mode=append)
# 2026-04-25 08:50:20.229 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:20.229 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:20.385 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:20.385 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:20.388 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:20.388 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:20.389 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:20.389 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:20.390 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Trips)
# 2026-04-25 08:50:20.390 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Trips)
# 2026-04-25 08:50:20.429 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:20.429 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:20.429 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"a6e9098b-1936-469b-b670-b08a7b8cc5cb","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:20.429 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"a6e9098b-1936-469b-b670-b08a7b8cc5cb","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:20.702 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:20.702 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:20.703 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:20.703 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:20.703 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:20.703 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:20.705 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Driver Telemetry)
# 2026-04-25 08:50:20.705 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Silver — Rideflow Driver Telemetry)
# 2026-04-25 08:50:20.745 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:20.745 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:20.745 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"57c9a82e-98a3-4eba-9945-01cf68336666","quarantine_records":0,"status":"ingested"}
# 2026-04-25 08:50:20.745 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"57c9a82e-98a3-4eba-9945-01cf68336666","quarantine_records":0,"status":"ingested"}
# ================================================================================
#  PIPELINE RUN SUMMARY
# ================================================================================
#   Pipeline run    : c1a9f5c4-f377-4a67-bc6c-706243a543a9
#   Environment     : local
#   Dry run         : False
#
#   Table Name                             Layer    Status     Rows     Good/Qrtn
#   ------------------------------------------------------------------------------
#   silver_rideflow_rider_profiles         silver   success    403      403/0
#   silver_rideflow_driver_profiles        silver   success    151      151/0
#   silver_rideflow_driver_telemetry       silver   success    8245     8245/0
#   silver_rideflow_trips                  silver   success    1908     1908/0
# ================================================================================

# %% [markdown]
# ---
# ## Step 6.5 · Gold Processing (Business KPIs & ML Models)
#
# Gold layer: where the business value is unlocked! Generates Trip KPIs, Rider LTV (Lifetime Value), and the AI-driven Surge Pricing data feeds.

# %%
# Generate surge inference landing data for the Surge Pricing ML Model contract
import polars as pl
import random, uuid
from datetime import datetime, timezone, timedelta

SURGE_LANDING = LAKEHOUSE / "marketplace" / "surge_inference_landing"
SURGE_LANDING.mkdir(parents=True, exist_ok=True)

random.seed(42)
cities = ["LON", "MAN", "BIR", "LDS", "BRS", "EDI", "GLA"]
n = 200

surge_df = pl.DataFrame({
    "inference_id": [str(uuid.uuid4()) for _ in range(n)],
    "model_version": [random.choice(["v2.1.0", "v2.2.0", "v2.3.0-beta"]) for _ in range(n)],
    "city_code": [random.choice(cities) for _ in range(n)],
    "demand_index": [round(random.uniform(0.5, 8.5), 2) for _ in range(n)],
    "surge_multiplier": [round(random.uniform(1.0, 4.2), 2) for _ in range(n)],
    "timestamp": [
        datetime.now(timezone.utc) - timedelta(minutes=random.randint(0, 1440))
        for _ in range(n)
    ],
})

surge_df.write_parquet(SURGE_LANDING / "inferences.parquet")
print(f"✅ Generated {n} surge inference records → {SURGE_LANDING}")
surge_df.head(3)
# Out:
# ✅ Generated 200 surge inference records → lakehouse\marketplace\surge_inference_landing
# shape: (3, 6)
# ┌──────────────────┬───────────────┬───────────┬──────────────┬──────────────────┬─────────────────┐
# │ inference_id     ┆ model_version ┆ city_code ┆ demand_index ┆ surge_multiplier ┆ timestamp       │
# │ ---              ┆ ---           ┆ ---       ┆ ---          ┆ ---              ┆ ---             │
# │ str              ┆ str           ┆ str       ┆ f64          ┆ f64              ┆ datetime[μs,    │
# │                  ┆               ┆           ┆              ┆                  ┆ UTC]            │
# ╞══════════════════╪═══════════════╪═══════════╪══════════════╪══════════════════╪═════════════════╡
# │ 8d44c197-711c-4a ┆ v2.3.0-beta   ┆ LON       ┆ 5.86         ┆ 2.42             ┆ 2026-04-24      │
# │ d3-94a2-c574c9dd ┆               ┆           ┆              ┆                  ┆ 15:05:20.776561 │
# │ 2f5d             ┆               ┆           ┆              ┆                  ┆ UTC             │
# │ ecbde160-32f0-43 ┆ v2.1.0        ┆ MAN       ┆ 3.01         ┆ 3.61             ┆ 2026-04-25      │
# │ 07-b6b8-e290937b ┆               ┆           ┆              ┆                  ┆ 04:20:20.776561 │
# │ 7f55             ┆               ┆           ┆              ┆                  ┆ UTC             │
# │ 549f3c22-c7d0-42 ┆ v2.1.0        ┆ BRS       ┆ 2.62         ┆ 3.85             ┆ 2026-04-25      │
# │ 43-9cdd-66718fc3 ┆               ┆           ┆              ┆                  ┆ 07:25:20.776561 │
# │ 7953             ┆               ┆           ┆              ┆                  ┆ UTC             │
# └──────────────────┴───────────────┴───────────┴──────────────┴──────────────────┴─────────────────┘

# %%
print("Starting Gold Processing via LakeLogic Pipeline Driver...\n")

summary = runner.run(
    target_layers="gold", 
    reload_layers=reload_layers,
    dry_run=False,
    environment=ENV,
    retry_attempts=retry_attempts,
    retry_base_wait_seconds=retry_base_wait_seconds,
    parallel=parallel
)

print(summary)
# Out:
# 2026-04-25 08:50:20.870 | INFO     | lakelogic.pipeline.runner:run:1479 - Pipeline storage mode: direct
# 2026-04-25 08:50:20.872 | INFO     | lakelogic.pipeline.runner:run:1580 - ── Processing Layer: GOLD (4 contracts) ──
# 2026-04-25 08:50:20.873 | INFO     | lakelogic.pipeline.runner:run:1599 -   Wave 0: [gold_rideflow_trip_kpis, gold_rideflow_driver_scorecard, gold_rideflow_rider_lifetime_value, gold_rideflow_surge_pricing_model] (parallel)
# 2026-04-25 08:50:20.884 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 - [gold_rideflow_trip_kpis]   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:20.888 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 - [gold_rideflow_trip_kpis]   📄 [gold] gold_rideflow_trip_kpis | Contract: Gold — Trip KPIs v1.0.0
# 2026-04-25 08:50:20.912 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:20.917 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\silver\silver_rideflow_trips via duckdb
# 2026-04-25 08:50:20.917 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [gold] gold_rideflow_driver_scorecard | Contract: Gold — Driver Scorecard v1.0.0
# Starting Gold Processing via LakeLogic Pipeline Driver...
# 2026-04-25 08:50:20.955 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\silver\silver_rideflow_trips via duckdb
# 2026-04-25 08:50:20.967 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:20.975 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [gold] gold_rideflow_rider_lifetime_value | Contract: Gold — Rider Lifetime Value v1.0.0
# 2026-04-25 08:50:21.011 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1834 -   ─────────────────────────────────────────────────────────
# 2026-04-25 08:50:21.071 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\silver\silver_rideflow_trips via duckdb
# 2026-04-25 08:50:21.071 | INFO     | lakelogic.pipeline.runner:_process_single_contract:1835 -   📄 [gold] gold_rideflow_surge_pricing_model | Contract: Gold — Surge Pricing ML Model Log v1.0.0
# 2026-04-25 08:50:21.111 | INFO     | lakelogic.core.processor:run_source:1342 - Loading source: C:\_Personal\_SaaS\lakelogic\examples\colab\lakehouse\marketplace\surge_inference_landing via duckdb
# 2026-04-25 08:50:21.543 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: inference_id_unique | Result: 0 (expected < 1.0) | Status: PASS
# 2026-04-25 08:50:21.681 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 200 | Total: 200 | Good: 200 | Quarantine: 0 | Pre-Transform Dropped: 0 | Ratio: 0.00%
# 2026-04-25 08:50:21.686 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 3788 | Total: 25 | Good: 0 | Quarantine: 25 | Pre-Transform Dropped: 3763 | Ratio: 100.00%
# 2026-04-25 08:50:21.700 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: driver_id_unique | Result: 2842 (expected < 1.0) | Status: FAIL
# 2026-04-25 08:50:21.817 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 3788 | Total: 946 | Good: 0 | Quarantine: 946 | Pre-Transform Dropped: 2842 | Ratio: 100.00%
# 2026-04-25 08:50:21.822 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\gold\gold_rideflow_trip_kpis\data.delta
# 2026-04-25 08:50:21.844 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 2 column(s) to match existing Delta table schema
# 2026-04-25 08:50:21.854 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 6 column(s) to match existing Delta table schema
# 2026-04-25 08:50:21.854 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 200 rows in lakehouse\marketplace\gold\gold_rideflow_surge_pricing_model (appending 200 new rows)
# 2026-04-25 08:50:21.867 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 0 rows in lakehouse\marketplace\gold\gold_rideflow_trip_kpis (appending 0 new rows)
# 2026-04-25 08:50:21.902 | INFO     | lakelogic.engines.duckdb:_run_dataset_rules:743 - Quality Check: rider_id_unique | Result: 2667 (expected < 1.0) | Status: FAIL
# 2026-04-25 08:50:21.904 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\gold\gold_rideflow_driver_scorecard\data.delta
# 2026-04-25 08:50:21.904 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 0 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_trip_kpis (strategy=merge, mode=append)
# 2026-04-25 08:50:21.935 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 5 column(s) to match existing Delta table schema
# 2026-04-25 08:50:21.953 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 0 rows in lakehouse\marketplace\gold\gold_rideflow_driver_scorecard (appending 0 new rows)
# 2026-04-25 08:50:21.963 | INFO     | lakelogic.core.quarantine:materialize_quarantine:894 - Aligned 8 quarantine column(s) to match existing Delta table schema
# 2026-04-25 08:50:21.985 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 0 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_driver_scorecard (strategy=merge, mode=append)
# 2026-04-25 08:50:21.987 | INFO     | lakelogic.core.processor:run:786 - Run complete [domain=marketplace, system=rideflow, layer=gold] | Source: 3788 | Total: 1121 | Good: 0 | Quarantine: 1121 | Pre-Transform Dropped: 2667 | Ratio: 100.00%
# 2026-04-25 08:50:21.997 | INFO     | lakelogic.core.quarantine:materialize_quarantine:910 - Wrote 25 quarantined rows to lakehouse\marketplace\_quarantine\gold_rideflow_trip_kpis (mode=append)
# 2026-04-25 08:50:22.031 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 200 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_surge_pricing_model (strategy=merge, mode=append)
# 2026-04-25 08:50:22.033 | INFO     | lakelogic.core.quarantine:materialize_quarantine:626 - Quarantine materialization skipped: 0 bad rows.
# 2026-04-25 08:50:22.036 | INFO     | lakelogic.core.quarantine:materialize_quarantine:894 - Aligned 8 quarantine column(s) to match existing Delta table schema
# 2026-04-25 08:50:22.071 | INFO     | lakelogic.core.materialization:materialize_dataframe:3211 - materialize: empty DataFrame, but falling through to initialize empty Delta table schema at lakehouse\marketplace\gold\gold_rideflow_rider_lifetime_value\data.delta
# 2026-04-25 08:50:22.080 | INFO     | lakelogic.core.materialization:materialize_dataframe:3325 - Cast 4 column(s) to match existing Delta table schema
# 2026-04-25 08:50:22.087 | INFO     | lakelogic.core.quarantine:materialize_quarantine:910 - Wrote 946 quarantined rows to lakehouse\marketplace\_quarantine\gold_rideflow_driver_scorecard (mode=append)
# 2026-04-25 08:50:22.107 | INFO     | lakelogic.core.materialization:materialize_dataframe:3484 - Delta pre-write state: 0 rows in lakehouse\marketplace\gold\gold_rideflow_rider_lifetime_value (appending 0 new rows)
# 2026-04-25 08:50:22.136 | INFO     | lakelogic.core.materialization:materialize_dataframe:3550 - Materialized 0 rows to Delta table: lakehouse\marketplace\gold\gold_rideflow_rider_lifetime_value (strategy=merge, mode=append)
# 2026-04-25 08:50:22.141 | INFO     | lakelogic.core.quarantine:materialize_quarantine:894 - Aligned 8 quarantine column(s) to match existing Delta table schema
# 2026-04-25 08:50:22.155 | INFO     | lakelogic.core.quarantine:materialize_quarantine:910 - Wrote 1121 quarantined rows to lakehouse\marketplace\_quarantine\gold_rideflow_rider_lifetime_value (mode=append)
# 2026-04-25 08:50:22.260 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:22.261 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:22.261 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:22.261 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Gold — Trip KPIs)
# 2026-04-25 08:50:22.309 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:22.310 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"ac52377a-07f8-4a35-b085-e4962a54edb7","quarantine_records":2,"status":"ingested"}
# 2026-04-25 08:50:22.765 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:22.766 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:22.766 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:22.767 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Gold — Rider Lifetime Value)
# 2026-04-25 08:50:22.824 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:22.825 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"36dd0d50-b0b8-4790-8549-e0e2ed066633","quarantine_records":3,"status":"ingested"}
# 2026-04-25 08:50:23.267 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:23.269 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:23.270 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:23.270 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Gold — Driver Scorecard)
# 2026-04-25 08:50:23.324 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:23.325 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"1c1e885a-9788-452c-ac61-e6c03ba8f30e","quarantine_records":2,"status":"ingested"}
# 2026-04-25 08:50:24.085 | INFO     | lakelogic.core.run_log:_write_run_log_table:870 - Wrote run log to Delta table ./lakehouse/marketplace/_logs
# 2026-04-25 08:50:24.086 | INFO     | lakelogic.core.run_log:write_run_log:1066 - 📡 [1/5] Observatory config resolved: True
# 2026-04-25 08:50:24.086 | INFO     | lakelogic.core.run_log:write_run_log:1083 - 📡 [2/5] Filters: env=local in ['dev', 'prod', 'staging', 'local'] → True | status=success in ['success', 'partial', 'failed'] → True
# 2026-04-25 08:50:24.086 | INFO     | lakelogic.core.run_log:write_run_log:1141 - 📡 [3/5] Posting to http://127.0.0.1:3007/api/v1/operations/run-logs/ingest (contract=Gold — Surge Pricing ML Model Log)
# 2026-04-25 08:50:24.137 | INFO     | lakelogic.core.run_log:write_run_log:1145 - 📡 [4/5] Response: HTTP 200
# 2026-04-25 08:50:24.138 | INFO     | lakelogic.core.run_log:write_run_log:1147 - 📡 [5/5] ✅ Ingested: {"run_id":"87379daa-8ccc-49fc-8c5f-159d8106a22d","quarantine_records":0,"status":"ingested"}
# ================================================================================
#  PIPELINE RUN SUMMARY
# ================================================================================
#   Pipeline run    : c1a9f5c4-f377-4a67-bc6c-706243a543a9
#   Environment     : local
#   Dry run         : False
#
#   Table Name                             Layer    Status     Rows     Good/Qrtn
#   ------------------------------------------------------------------------------
#   gold_rideflow_trip_kpis                gold     success    0        0/25
#   gold_rideflow_surge_pricing_model      gold     success    200      200/0
#   gold_rideflow_driver_scorecard         gold     success    0        0/946
#   gold_rideflow_rider_lifetime_value     gold     success    0        0/1121
# ================================================================================

# %% [markdown]
# ---
# ## Step 7 · Quick Data Preview
#
# Inspect the Silver trips table — the main fact table driving the dashboard.

# %%
trips_path = LAKEHOUSE / registry.domain / registry.silver_layer / "silver_rideflow_trips"

if trips_path.exists():
    try:
        trips_df = pl.read_delta(str(trips_path))
    except Exception:
        parquets = list(trips_path.rglob("*.parquet"))
        trips_df = pl.read_parquet(parquets[0]) if parquets else pl.DataFrame()

    print(f"Silver trips: {len(trips_df):,} rows, {len(trips_df.columns)} columns")
    print(f"\nColumns: {trips_df.columns}")
    print(f"\nSample (5 rows):")
    display(trips_df.head(5))

    # Quick stats
    if "fare_amount" in trips_df.columns:
        fare_col = trips_df["fare_amount"].cast(pl.Float64, strict=False)
        print(f"\n📊 Fare stats:  min=£{fare_col.min():.2f}  avg=£{fare_col.mean():.2f}  max=£{fare_col.max():.2f}")
    if "city_code" in trips_df.columns:
        print(f"🏙️ Cities: {trips_df['city_code'].unique().sort().to_list()}")
else:
    print("⚠️ Silver trips table not found — check the pipeline cells above.")
# Out:
# Silver trips: 1,880 rows, 26 columns
#
# Columns: ['trip_id', 'rider_id', 'driver_id', 'trip_type', 'pickup_lat', 'pickup_lng', 'dropoff_lat', 'dropoff_lng', 'city_code', 'requested_at', 'pickup_at', 'dropoff_at', 'distance_km', 'duration_minutes', 'fare_amount', 'surge_multiplier', 'tip_amount', 'payment_method', 'rider_rating', 'driver_rating', 'notes', '_lakelogic_source', '_lakelogic_processed_at', '_lakelogic_run_id', '_lakelogic_created_at', '_lakelogic_created_by']
#
# Sample (5 rows):
# shape: (5, 26)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ tri ┆ rid ┆ dri ┆ tri ┆ pic ┆ pic ┆ dro ┆ dro ┆ cit ┆ req ┆ pic ┆ dro ┆ dis ┆ dur ┆ far ┆ sur ┆ tip ┆ pay ┆ rid ┆ dri ┆ not ┆ _la ┆ _la ┆ _la ┆ _la ┆ _la │
# │ p_i ┆ er_ ┆ ver ┆ p_t ┆ kup ┆ kup ┆ pof ┆ pof ┆ y_c ┆ ues ┆ kup ┆ pof ┆ tan ┆ ati ┆ e_a ┆ ge_ ┆ _am ┆ men ┆ er_ ┆ ver ┆ es  ┆ kel ┆ kel ┆ kel ┆ kel ┆ kel │
# │ d   ┆ id  ┆ _id ┆ ype ┆ _la ┆ _ln ┆ f_l ┆ f_l ┆ ode ┆ ted ┆ _at ┆ f_a ┆ ce_ ┆ on_ ┆ mou ┆ mul ┆ oun ┆ t_m ┆ rat ┆ _ra ┆ --- ┆ ogi ┆ ogi ┆ ogi ┆ ogi ┆ ogi │
# │ --- ┆ --- ┆ --- ┆ --- ┆ t   ┆ g   ┆ at  ┆ ng  ┆ --- ┆ _at ┆ --- ┆ t   ┆ km  ┆ min ┆ nt  ┆ tip ┆ t   ┆ eth ┆ ing ┆ tin ┆ str ┆ c_s ┆ c_p ┆ c_r ┆ c_c ┆ c_c │
# │ str ┆ str ┆ str ┆ str ┆ --- ┆ --- ┆ --- ┆ --- ┆ str ┆ --- ┆ dat ┆ --- ┆ --- ┆ ute ┆ --- ┆ lie ┆ --- ┆ od  ┆ --- ┆ g   ┆     ┆ our ┆ roc ┆ un_ ┆ rea ┆ rea │
# │     ┆     ┆     ┆     ┆ str ┆ str ┆ str ┆ str ┆     ┆ dat ┆ eti ┆ dat ┆ f32 ┆ s   ┆ f32 ┆ r   ┆ f32 ┆ --- ┆ f32 ┆ --- ┆     ┆ ce  ┆ ess ┆ id  ┆ ted ┆ ted │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eti ┆ me[ ┆ eti ┆     ┆ --- ┆     ┆ --- ┆     ┆ str ┆     ┆ f32 ┆     ┆ --- ┆ ed_ ┆ --- ┆ _at ┆ _by │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ me[ ┆ μs] ┆ me[ ┆     ┆ i32 ┆     ┆ f32 ┆     ┆     ┆     ┆     ┆     ┆ str ┆ at  ┆ str ┆ --- ┆ --- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ μs] ┆     ┆ μs] ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ --- ┆     ┆ str ┆ str │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆     ┆     │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ 25a ┆ R-6 ┆ D-b ┆ eat ┆ 51. ┆ 0.0 ┆ 51. ┆ -0. ┆ XYZ ┆ 202 ┆ 202 ┆ 202 ┆ 9.4 ┆ 19  ┆ 11. ┆ 3.4 ┆ 1.1 ┆ cas ┆ 4.0 ┆ 4.0 ┆     ┆ C:\ ┆ 202 ┆ 9c8 ┆ 202 ┆ col │
# │ f93 ┆ 131 ┆ ecc ┆ s_d ┆ 552 ┆ 167 ┆ 433 ┆ 169 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆     ┆     ┆ 91  ┆ 7   ┆ 2   ┆ h   ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ bda ┆ 6-0 ┆ li  │
# │ 70- ┆ 408 ┆ 53f ┆ eli ┆ 5   ┆ 57  ┆ 948 ┆ 965 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ c9- ┆ 4-2 ┆     │
# │ c65 ┆ 6   ┆ e   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 3T2 ┆ cd3 ┆ 3T2 ┆     │
# │ a-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 20: ┆ 21: ┆ 21: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 1:4 ┆ 7-4 ┆ 1:4 ┆     │
# │ 451 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 58: ┆ 05: ┆ 15: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 1:0 ┆ 555 ┆ 1:0 ┆     │
# │ -95 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 0+0 ┆ -bf ┆ 0+0 ┆     │
# │ fa- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 75- ┆ 0:0 ┆     │
# │ a6c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 843 ┆ 0   ┆     │
# │ a8f ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ 2bc ┆     ┆     │
# │ 807 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ c45 ┆     ┆     │
# │ 79c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ fa9 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ da1 ┆ R-e ┆ D-0 ┆ eat ┆ 51. ┆ -0. ┆ 51. ┆ -0. ┆ XYZ ┆ 202 ┆ 202 ┆ 202 ┆ 15. ┆ 42  ┆ 48. ┆ 2.0 ┆ 3.9 ┆ app ┆ 3.0 ┆ 3.0 ┆     ┆ C:\ ┆ 202 ┆ 9c8 ┆ 202 ┆ col │
# │ 59b ┆ b75 ┆ bf9 ┆ s_d ┆ 432 ┆ 035 ┆ 550 ┆ 068 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 8   ┆     ┆ 200 ┆ 9   ┆ 9   ┆ le_ ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ bda ┆ 6-0 ┆ li  │
# │ 24- ┆ 5d1 ┆ 648 ┆ eli ┆ 549 ┆ 967 ┆ 409 ┆ 297 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆ 001 ┆     ┆     ┆ pay ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ c9- ┆ 4-2 ┆     │
# │ b38 ┆ f   ┆ 0   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 3T2 ┆ cd3 ┆ 3T2 ┆     │
# │ e-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 18: ┆ 18: ┆ 18: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 1:4 ┆ 7-4 ┆ 1:4 ┆     │
# │ a03 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 06: ┆ 09: ┆ 43: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 1:0 ┆ 555 ┆ 1:0 ┆     │
# │ -95 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 0+0 ┆ -bf ┆ 0+0 ┆     │
# │ c7- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 75- ┆ 0:0 ┆     │
# │ 885 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 843 ┆ 0   ┆     │
# │ 512 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ 2bc ┆     ┆     │
# │ 0fc ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ c45 ┆     ┆     │
# │ a02 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ fa9 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ f23 ┆ R-1 ┆ D-7 ┆ eat ┆ 51. ┆ -0. ┆ 51. ┆ -0. ┆ LON ┆ 202 ┆ 202 ┆ 202 ┆ 18. ┆ 22  ┆ 75. ┆ 5.8 ┆ 2.9 ┆ goo ┆ 1.0 ┆ 5.0 ┆     ┆ C:\ ┆ 202 ┆ 9c8 ┆ 202 ┆ col │
# │ 61d ┆ e41 ┆ 3d2 ┆ s_d ┆ 534 ┆ 063 ┆ 464 ┆ 146 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 299 ┆     ┆ 860 ┆     ┆ 7   ┆ gle ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ bda ┆ 6-0 ┆ li  │
# │ a2- ┆ 2e6 ┆ 52d ┆ eli ┆ 781 ┆ 942 ┆ 087 ┆ 983 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆ 999 ┆     ┆ 001 ┆     ┆     ┆ _pa ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ c9- ┆ 4-2 ┆     │
# │ b6d ┆ 9   ┆ 8   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆ y   ┆     ┆     ┆     ┆ nal ┆ 3T2 ┆ cd3 ┆ 3T2 ┆     │
# │ a-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 05: ┆ 05: ┆ 05: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 1:4 ┆ 7-4 ┆ 1:4 ┆     │
# │ 286 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00: ┆ 10: ┆ 52: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 1:0 ┆ 555 ┆ 1:0 ┆     │
# │ -9c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 0+0 ┆ -bf ┆ 0+0 ┆     │
# │ cc- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 75- ┆ 0:0 ┆     │
# │ be4 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 843 ┆ 0   ┆     │
# │ 805 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ 2bc ┆     ┆     │
# │ 514 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ c45 ┆     ┆     │
# │ efb ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ fa9 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ 26c ┆ R-2 ┆ D-7 ┆ eat ┆ 51. ┆ 0.0 ┆ 51. ┆ -0. ┆ LON ┆ 202 ┆ 202 ┆ 202 ┆ 21. ┆ 16  ┆ 15. ┆ 1.2 ┆ 4.5 ┆ cas ┆ 3.0 ┆ 5.0 ┆     ┆ C:\ ┆ 202 ┆ 9c8 ┆ 202 ┆ col │
# │ 1bb ┆ 904 ┆ 8a1 ┆ s_d ┆ 456 ┆ 228 ┆ 561 ┆ 076 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 5   ┆     ┆ 25  ┆ 8   ┆ 5   ┆ h   ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ bda ┆ 6-0 ┆ li  │
# │ 21- ┆ 624 ┆ 8b3 ┆ eli ┆ 935 ┆ 78  ┆ 762 ┆ 129 ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ c9- ┆ 4-2 ┆     │
# │ e41 ┆ 6   ┆ f   ┆ ver ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 3T2 ┆ cd3 ┆ 3T2 ┆     │
# │ d-4 ┆     ┆     ┆ y   ┆     ┆     ┆     ┆     ┆     ┆ 12: ┆ 12: ┆ 11: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 1:4 ┆ 7-4 ┆ 1:4 ┆     │
# │ e79 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 15: ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 1:0 ┆ 555 ┆ 1:0 ┆     │
# │ -99 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 0+0 ┆ -bf ┆ 0+0 ┆     │
# │ d7- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 75- ┆ 0:0 ┆     │
# │ 636 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 843 ┆ 0   ┆     │
# │ b90 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ 2bc ┆     ┆     │
# │ 538 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ c45 ┆     ┆     │
# │ d21 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ fa9 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# │ 86e ┆ R-d ┆ D-9 ┆ rid ┆ 51. ┆ -0. ┆ 51. ┆ 0.0 ┆ PAR ┆ 202 ┆ 202 ┆ 202 ┆ 18. ┆ 19  ┆ 11. ┆ 1.0 ┆ 2.1 ┆ cas ┆ 3.0 ┆ 4.0 ┆     ┆ C:\ ┆ 202 ┆ 9c8 ┆ 202 ┆ col │
# │ 752 ┆ 181 ┆ 00c ┆ e   ┆ 437 ┆ 169 ┆ 453 ┆ 145 ┆     ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 5   ┆     ┆ 76  ┆ 4   ┆ 7   ┆ h   ┆     ┆     ┆     ┆ _Pe ┆ 6-0 ┆ bda ┆ 6-0 ┆ li  │
# │ 39- ┆ 175 ┆ 9e4 ┆     ┆ 188 ┆ 318 ┆ 839 ┆ 59  ┆     ┆ 4-1 ┆ 4-1 ┆ 4-1 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rso ┆ 4-2 ┆ c9- ┆ 4-2 ┆     │
# │ 3e8 ┆ 3   ┆ a   ┆     ┆     ┆     ┆     ┆     ┆     ┆ 5   ┆ 5   ┆ 5   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nal ┆ 3T2 ┆ cd3 ┆ 3T2 ┆     │
# │ 8-4 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 07: ┆ 12: ┆ 11: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆ 1:4 ┆ 7-4 ┆ 1:4 ┆     │
# │ 5fd ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 01: ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆ 1:0 ┆ 555 ┆ 1:0 ┆     │
# │ -80 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ 00  ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆ 0+0 ┆ -bf ┆ 0+0 ┆     │
# │ 8d- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆ 0:0 ┆ 75- ┆ 0:0 ┆     │
# │ fd8 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆ 0   ┆ 843 ┆ 0   ┆     │
# │ 416 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆ 2bc ┆     ┆     │
# │ 466 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆ c45 ┆     ┆     │
# │ bdd ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆ fa9 ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ bro ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nze ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \br ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ onz ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_r ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _co ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mpl ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ete ┆     ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d   ┆     ┆     ┆     ┆     │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘
# 📊 Fare stats:  min=£-15.50  avg=£36.91  max=£214.76
# 🏙️ Cities: ['BER', 'LON', 'NYC', 'PAR', 'SYD', 'TYO', 'XYZ']

# %% [markdown]
# ---
# ## Step 8 · Pipeline Audit Trail
#
# Every pipeline run is logged with row counts, durations, quarantine ratios, and estimated costs.

# %%
logs_df.to_dicts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 logs_df.to_dicts()
#
# NameError: name 'logs_df' is not defined

# %%
log_path = LAKEHOUSE / registry.domain / "_logs" 

column_list = ["run_id", "contract", "dataset", "status", "timestamp", "run_duration_seconds", 
"engine",  "counts_source",	"counts_total",	"counts_good",	"counts_quarantined",
"quarantine_ratio",	"estimated_cost",	"cost_currency",]
if log_path.exists():
    try:
        from deltalake import DeltaTable
        logs_df = pl.from_arrow(DeltaTable(str(log_path)).to_pyarrow_table())
        print(f"Run logs: {len(logs_df)} entries")
        display(logs_df.select("*").head(15))
    except ImportError:
        logs_df = pl.read_delta(str(log_path))
        print(f"Run logs: {len(logs_df)} entries")
        display(logs_df.select(column_list).head(10))
    except Exception as e:
        print(f"Run log read error: {e}")
else:
    print("No run log yet — this is expected for the first pipeline run.")
# Out:
# Run logs: 15 entries
# shape: (15, 30)
# ┌─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┬─────┐
# │ pip ┆ run ┆ tim ┆ sta ┆ end ┆ run ┆ eng ┆ con ┆ sta ┆ dat ┆ dom ┆ sys ┆ env ┆ dat ┆ sta ┆ err ┆ sou ┆ cou ┆ cou ┆ cou ┆ cou ┆ qua ┆ est ┆ cos ┆ cos ┆ max ┆ max ┆ dlt ┆ slo ┆ rep │
# │ eli ┆ _id ┆ est ┆ rt_ ┆ _ti ┆ _du ┆ ine ┆ tra ┆ ge  ┆ ase ┆ ain ┆ tem ┆ iro ┆ a_l ┆ tus ┆ or_ ┆ rce ┆ nts ┆ nts ┆ nts ┆ nts ┆ ran ┆ ima ┆ t_c ┆ t_c ┆ _so ┆ _wa ┆ _st ┆ _js ┆ ort │
# │ ne_ ┆ --- ┆ amp ┆ tim ┆ me  ┆ rat ┆ --- ┆ ct  ┆ --- ┆ t   ┆ --- ┆ --- ┆ nme ┆ aye ┆ --- ┆ mes ┆ _pa ┆ _so ┆ _to ┆ _go ┆ _qu ┆ tin ┆ ted ┆ urr ┆ onf ┆ urc ┆ ter ┆ ate ┆ on  ┆ _js │
# │ run ┆ str ┆ --- ┆ e   ┆ --- ┆ ion ┆ str ┆ --- ┆ str ┆ --- ┆ str ┆ str ┆ nt  ┆ r   ┆ str ┆ sag ┆ th  ┆ urc ┆ tal ┆ od  ┆ ara ┆ e_r ┆ _co ┆ enc ┆ ide ┆ e_m ┆ mar ┆ _js ┆ --- ┆ on  │
# │ _id ┆     ┆ str ┆ --- ┆ str ┆ _se ┆     ┆ str ┆     ┆ str ┆     ┆     ┆ --- ┆ --- ┆     ┆ e   ┆ --- ┆ e   ┆ --- ┆ --- ┆ nti ┆ ati ┆ st  ┆ y   ┆ nce ┆ tim ┆ k_v ┆ on  ┆ str ┆ --- │
# │ --- ┆     ┆     ┆ str ┆     ┆ con ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆ str ┆     ┆ --- ┆ str ┆ --- ┆ i64 ┆ i64 ┆ ned ┆ o   ┆ --- ┆ --- ┆ --- ┆ e   ┆ alu ┆ --- ┆     ┆ str │
# │ str ┆     ┆     ┆     ┆     ┆ ds  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆ i64 ┆     ┆     ┆ --- ┆ --- ┆ f64 ┆ str ┆ str ┆ --- ┆ e   ┆ str ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆ --- ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ i64 ┆ f64 ┆     ┆     ┆     ┆ f64 ┆ --- ┆     ┆     ┆     │
# │     ┆     ┆     ┆     ┆     ┆ f64 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ str ┆     ┆     ┆     │
# ╞═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╪═════╡
# │ b29 ┆ e05 ┆ 202 ┆ 202 ┆ 202 ┆ 0.9 ┆ duc ┆ Gol ┆ def ┆ gol ┆ mar ┆ rid ┆ loc ┆ gol ┆ suc ┆ nul ┆ C:\ ┆ 188 ┆ 945 ┆ 0   ┆ 945 ┆ 1.0 ┆ 0.0 ┆ USD ┆ non ┆ nul ┆ nul ┆ nul ┆ {"f ┆ {"r │
# │ 691 ┆ af2 ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 766 ┆ kdb ┆ d — ┆ aul ┆ d_r ┆ ket ┆ efl ┆ al  ┆ d   ┆ cee ┆ l   ┆ _Pe ┆ 0   ┆     ┆     ┆     ┆     ┆     ┆     ┆ e   ┆ l   ┆ l   ┆ l   ┆ res ┆ un_ │
# │ 82- ┆ aa- ┆ 4-2 ┆ 4-2 ┆ 4-2 ┆ 39  ┆     ┆ Dri ┆ t   ┆ ide ┆ pla ┆ ow  ┆     ┆     ┆ ded ┆     ┆ rso ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hne ┆ id" │
# │ 5c4 ┆ bee ┆ 3T2 ┆ 3T2 ┆ 3T2 ┆     ┆     ┆ ver ┆     ┆ flo ┆ ce  ┆     ┆     ┆     ┆     ┆     ┆ nal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ :   │
# │ 5-4 ┆ 5-4 ┆ 1:4 ┆ 1:4 ┆ 1:4 ┆     ┆     ┆ Sco ┆     ┆ w_d ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ "e0 │
# │ 94b ┆ 329 ┆ 1:0 ┆ 1:0 ┆ 1:0 ┆     ┆     ┆ rec ┆     ┆ riv ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"s ┆ 5af │
# │ -8f ┆ -b8 ┆ 1+0 ┆ 0.9 ┆ 1.8 ┆     ┆     ┆ ard ┆     ┆ er_ ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 2aa │
# │ 83- ┆ 97- ┆ 0:0 ┆ 183 ┆ 944 ┆     ┆     ┆     ┆     ┆ sco ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ -be │
# │ d34 ┆ 9a4 ┆ 0   ┆ 13+ ┆ 95+ ┆     ┆     ┆     ┆     ┆ rec ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ e5- │
# │ dc5 ┆ d39 ┆     ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆ ard ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 432 │
# │ 002 ┆ 2a2 ┆     ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 9-b │
# │ 7d8 ┆ 637 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ 897 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ -9a │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ 4d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 92a │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 263 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ 7", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "pi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ pel │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d_s ┆ ine │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ _ru │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ n_i │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ sil ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ d": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ver ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ "b2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \si ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 969 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lve ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 182 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ r_r ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ -5c │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_s ┆ 45- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 494 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ b-8 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ f83 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ -d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 4dc │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 500 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ 27d │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_p ┆ 8", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ass ┆ "en │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ gin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "du │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "av ┆ ckd │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ail ┆ b", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ abi ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lit ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ y": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"r ┆ ":  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Go │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ ld  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ Dri │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ ver │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ Sco │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ rec │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ ard │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ ",  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ _ve │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ rsi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "ro ┆ on" │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_c ┆ :   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oun ┆ "1. │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t": ┆ 0.0 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"… ┆ …   │
# │ b29 ┆ 323 ┆ 202 ┆ 202 ┆ 202 ┆ 0.9 ┆ duc ┆ Gol ┆ def ┆ gol ┆ mar ┆ rid ┆ loc ┆ gol ┆ suc ┆ nul ┆ C:\ ┆ 188 ┆ 19  ┆ 0   ┆ 19  ┆ 1.0 ┆ 0.0 ┆ USD ┆ non ┆ nul ┆ nul ┆ nul ┆ {"f ┆ {"r │
# │ 691 ┆ 4fa ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 790 ┆ kdb ┆ d — ┆ aul ┆ d_r ┆ ket ┆ efl ┆ al  ┆ d   ┆ cee ┆ l   ┆ _Pe ┆ 0   ┆     ┆     ┆     ┆     ┆     ┆     ┆ e   ┆ l   ┆ l   ┆ l   ┆ res ┆ un_ │
# │ 82- ┆ 0b- ┆ 4-2 ┆ 4-2 ┆ 4-2 ┆ 14  ┆     ┆ Tri ┆ t   ┆ ide ┆ pla ┆ ow  ┆     ┆     ┆ ded ┆     ┆ rso ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hne ┆ id" │
# │ 5c4 ┆ ec6 ┆ 3T2 ┆ 3T2 ┆ 3T2 ┆     ┆     ┆ p   ┆     ┆ flo ┆ ce  ┆     ┆     ┆     ┆     ┆     ┆ nal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ :   │
# │ 5-4 ┆ 2-4 ┆ 1:4 ┆ 1:4 ┆ 1:4 ┆     ┆     ┆ KPI ┆     ┆ w_t ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ "32 │
# │ 94b ┆ dd7 ┆ 1:0 ┆ 1:0 ┆ 1:0 ┆     ┆     ┆ s   ┆     ┆ rip ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"s ┆ 34f │
# │ -8f ┆ -be ┆ 1+0 ┆ 0.9 ┆ 1.8 ┆     ┆     ┆     ┆     ┆ _kp ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ a0b │
# │ 83- ┆ 7a- ┆ 0:0 ┆ 143 ┆ 934 ┆     ┆     ┆     ┆     ┆ is  ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ -ec │
# │ d34 ┆ f8c ┆ 0   ┆ 09+ ┆ 96+ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ 62- │
# │ dc5 ┆ 5a1 ┆     ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 4dd │
# │ 002 ┆ 85e ┆     ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 7-b │
# │ 7d8 ┆ 726 ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ e7a │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ -f8 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ c5a │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 185 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ e72 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ 6", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "pi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ pel │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d_s ┆ ine │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ _ru │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ n_i │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ sil ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ d": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ver ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ "b2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \si ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 969 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lve ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 182 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ r_r ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ -5c │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_s ┆ 45- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 494 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ b-8 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ f83 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ -d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 4dc │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 500 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ 27d │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_p ┆ 8", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ass ┆ "en │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ gin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "du │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "av ┆ ckd │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ail ┆ b", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ abi ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lit ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ y": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"r ┆ ":  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Go │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ ld  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ Tri │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ p   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ KPI │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ s", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ _ve │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d": ┆ rsi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ on" │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ :   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "ro ┆ "1. │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_c ┆ 0.0 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oun ┆ ",  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t": ┆ "st │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"… ┆ a…  │
# │ b29 ┆ 3e5 ┆ 202 ┆ 202 ┆ 202 ┆ 0.9 ┆ duc ┆ Gol ┆ def ┆ gol ┆ mar ┆ rid ┆ loc ┆ gol ┆ suc ┆ nul ┆ C:\ ┆ 188 ┆ 111 ┆ 0   ┆ 111 ┆ 1.0 ┆ 0.0 ┆ USD ┆ non ┆ nul ┆ nul ┆ nul ┆ {"f ┆ {"r │
# │ 691 ┆ 024 ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 747 ┆ kdb ┆ d — ┆ aul ┆ d_r ┆ ket ┆ efl ┆ al  ┆ d   ┆ cee ┆ l   ┆ _Pe ┆ 0   ┆ 5   ┆     ┆ 5   ┆     ┆     ┆     ┆ e   ┆ l   ┆ l   ┆ l   ┆ res ┆ un_ │
# │ 82- ┆ fd- ┆ 4-2 ┆ 4-2 ┆ 4-2 ┆ 45  ┆     ┆ Rid ┆ t   ┆ ide ┆ pla ┆ ow  ┆     ┆     ┆ ded ┆     ┆ rso ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hne ┆ id" │
# │ 5c4 ┆ 83f ┆ 3T2 ┆ 3T2 ┆ 3T2 ┆     ┆     ┆ er  ┆     ┆ flo ┆ ce  ┆     ┆     ┆     ┆     ┆     ┆ nal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ :   │
# │ 5-4 ┆ b-4 ┆ 1:4 ┆ 1:4 ┆ 1:4 ┆     ┆     ┆ Lif ┆     ┆ w_r ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ "3e │
# │ 94b ┆ 8d9 ┆ 1:0 ┆ 1:0 ┆ 1:0 ┆     ┆     ┆ eti ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"s ┆ 502 │
# │ -8f ┆ -ad ┆ 1+0 ┆ 0.9 ┆ 1.9 ┆     ┆     ┆ me  ┆     ┆ r_l ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 4fd │
# │ 83- ┆ e4- ┆ 0:0 ┆ 584 ┆ 325 ┆     ┆     ┆ Val ┆     ┆ ife ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ -83 │
# │ d34 ┆ a39 ┆ 0   ┆ 66+ ┆ 53+ ┆     ┆     ┆ ue  ┆     ┆ tim ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ fb- │
# │ dc5 ┆ eb8 ┆     ┆ 00: ┆ 00: ┆     ┆     ┆     ┆     ┆ e_v ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 48d │
# │ 002 ┆ 6f1 ┆     ┆ 00  ┆ 00  ┆     ┆     ┆     ┆     ┆ alu ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 9-a │
# │ 7d8 ┆ 71c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e   ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ de4 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ -a3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ 9eb │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 86f │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 171 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ c", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "pi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ pel │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d_s ┆ ine │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ _ru │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ n_i │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ sil ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ d": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ver ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ "b2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ \si ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 969 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lve ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 182 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ r_r ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ -5c │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_s ┆ 45- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 494 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_t ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ b-8 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rip ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ f83 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ -d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 4dc │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 500 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ 27d │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_p ┆ 8", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ass ┆ "en │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ gin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "du │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "av ┆ ckd │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ail ┆ b", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ abi ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lit ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ y": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"r ┆ ":  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Go │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ ld  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ Rid │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ er  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ Lif │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ eti │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ me  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ Val │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ ue" │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ ,   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d": ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "ro ┆ _ve │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_c ┆ rsi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oun ┆ on" │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t": ┆ :   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"… ┆ "1… │
# │ b29 ┆ 745 ┆ 202 ┆ 202 ┆ 202 ┆ 0.7 ┆ duc ┆ Gol ┆ def ┆ gol ┆ mar ┆ rid ┆ loc ┆ gol ┆ suc ┆ nul ┆ C:\ ┆ 200 ┆ 200 ┆ 200 ┆ 0   ┆ 0.0 ┆ 0.0 ┆ USD ┆ non ┆ 1.7 ┆ nul ┆ nul ┆ {"f ┆ {"r │
# │ 691 ┆ 7bd ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 501 ┆ kdb ┆ d — ┆ aul ┆ d_r ┆ ket ┆ efl ┆ al  ┆ d   ┆ cee ┆ l   ┆ _Pe ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e   ┆ 770 ┆ l   ┆ l   ┆ res ┆ un_ │
# │ 82- ┆ ce- ┆ 4-2 ┆ 4-2 ┆ 4-2 ┆ 51  ┆     ┆ Sur ┆ t   ┆ ide ┆ pla ┆ ow  ┆     ┆     ┆ ded ┆     ┆ rso ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e9  ┆     ┆     ┆ hne ┆ id" │
# │ 5c4 ┆ e64 ┆ 3T2 ┆ 3T2 ┆ 3T2 ┆     ┆     ┆ ge  ┆     ┆ flo ┆ ce  ┆     ┆     ┆     ┆     ┆     ┆ nal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ :   │
# │ 5-4 ┆ e-4 ┆ 1:4 ┆ 1:4 ┆ 1:4 ┆     ┆     ┆ Pri ┆     ┆ w_s ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ "74 │
# │ 94b ┆ dc6 ┆ 1:0 ┆ 1:0 ┆ 1:0 ┆     ┆     ┆ cin ┆     ┆ urg ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"s ┆ 57b │
# │ -8f ┆ -bd ┆ 1+0 ┆ 0.9 ┆ 1.6 ┆     ┆     ┆ g   ┆     ┆ e_p ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ dce │
# │ 83- ┆ c4- ┆ 0:0 ┆ 050 ┆ 553 ┆     ┆     ┆ ML  ┆     ┆ ric ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ -e6 │
# │ d34 ┆ 2b4 ┆ 0   ┆ 58+ ┆ 32+ ┆     ┆     ┆ Mod ┆     ┆ ing ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ 4e- │
# │ dc5 ┆ fe0 ┆     ┆ 00: ┆ 00: ┆     ┆     ┆ el  ┆     ┆ _mo ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 4dc │
# │ 002 ┆ 2e9 ┆     ┆ 00  ┆ 00  ┆     ┆     ┆ Log ┆     ┆ del ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 6-b │
# │ 7d8 ┆ 05f ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ dc4 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ -2b │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ 4fe │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 02e │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 905 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ f", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "pi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ mar ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ pel │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ket ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d_s ┆ ine │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ pla ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ _ru │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ce\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ n_i │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ sur ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ d": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ge_ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ "b2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ inf ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 969 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ere ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 182 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nce ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ -5c │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_s ┆ 45- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ndi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 494 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ng  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ b-8 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ f83 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ -d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 4dc │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 500 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ 27d │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_p ┆ 8", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ass ┆ "en │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ gin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "du │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "av ┆ ckd │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ail ┆ b", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ abi ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lit ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ y": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"r ┆ ":  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Go │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ ld  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ Sur │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ ge  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ Pri │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ cin │
# ...
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Br │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ onz │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ Rid │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ eFl │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ ow  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ Rid │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ er  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ App │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ Eve │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d": ┆ nts │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ ",  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "ro ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_c ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oun ┆ _ve │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t": ┆ rsi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"… ┆ …   │
# │ b29 ┆ 8e4 ┆ 202 ┆ 202 ┆ 202 ┆ 0.0 ┆ duc ┆ Bro ┆ def ┆ bro ┆ mar ┆ rid ┆ loc ┆ bro ┆ suc ┆ nul ┆ C:\ ┆ 391 ┆ 391 ┆ 391 ┆ 0   ┆ 0.0 ┆ 0.0 ┆ USD ┆ non ┆ 1.7 ┆ nul ┆ nul ┆ {"f ┆ {"r │
# │ 691 ┆ 2da ┆ 6-0 ┆ 6-0 ┆ 6-0 ┆ 978 ┆ kdb ┆ nze ┆ aul ┆ nze ┆ ket ┆ efl ┆ al  ┆ nze ┆ cee ┆ l   ┆ _Pe ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e   ┆ 770 ┆ l   ┆ l   ┆ res ┆ un_ │
# │ 82- ┆ 90- ┆ 4-2 ┆ 4-2 ┆ 4-2 ┆ 47  ┆     ┆ —   ┆ t   ┆ _ri ┆ pla ┆ ow  ┆     ┆     ┆ ded ┆     ┆ rso ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e9  ┆     ┆     ┆ hne ┆ id" │
# │ 5c4 ┆ 797 ┆ 3T2 ┆ 3T2 ┆ 3T2 ┆     ┆     ┆ Rid ┆     ┆ def ┆ ce  ┆     ┆     ┆     ┆     ┆     ┆ nal ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ :   │
# │ 5-4 ┆ 8-4 ┆ 1:4 ┆ 1:4 ┆ 1:4 ┆     ┆     ┆ eFl ┆     ┆ low ┆     ┆     ┆     ┆     ┆     ┆     ┆ \_S ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ "8e │
# │ 94b ┆ 5f3 ┆ 0:5 ┆ 0:5 ┆ 0:5 ┆     ┆     ┆ ow  ┆     ┆ _ri ┆     ┆     ┆     ┆     ┆     ┆     ┆ aaS ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"s ┆ 42d │
# │ -8f ┆ -80 ┆ 5+0 ┆ 5.2 ┆ 5.3 ┆     ┆     ┆ Rid ┆     ┆ der ┆     ┆     ┆     ┆     ┆     ┆     ┆ \la ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ a90 │
# │ 83- ┆ 88- ┆ 0:0 ┆ 597 ┆ 574 ┆     ┆     ┆ er  ┆     ┆ _pr ┆     ┆     ┆     ┆     ┆     ┆     ┆ kel ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ -79 │
# │ d34 ┆ 879 ┆ 0   ┆ 94+ ┆ 44+ ┆     ┆     ┆ Pro ┆     ┆ ofi ┆     ┆     ┆     ┆     ┆     ┆     ┆ ogi ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ 78- │
# │ dc5 ┆ 208 ┆     ┆ 00: ┆ 00: ┆     ┆     ┆ fil ┆     ┆ les ┆     ┆     ┆     ┆     ┆     ┆     ┆ c\e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 45f │
# │ 002 ┆ 53b ┆     ┆ 00  ┆ 00  ┆     ┆     ┆ es  ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ xam ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 3-8 │
# │ 7d8 ┆ 80e ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ple ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ 088 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s\c ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ -87 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ola ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ 920 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ b\l ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ 853 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ake ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ b80 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hou ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ e", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ se\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ "pi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ _da ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ pel │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ta\ ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d_s ┆ ine │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lan ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ _ru │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ din ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ n_i │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ g_m ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ d": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ark ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ "b2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ etp ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 969 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lac ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 182 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e\r ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ -5c │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_s ┆ 45- │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ flo ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ eco ┆ 494 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w\r ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nds ┆ b-8 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ide ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ f83 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ r_p ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ -d3 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ rof ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ 4dc │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ile ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "so ┆ 500 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ s   ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ urc ┆ 27d │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ e_p ┆ 8", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ass ┆ "en │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ":  ┆ gin │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e": │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "du │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "av ┆ ckd │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ail ┆ b", │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ abi ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ lit ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ y": ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"r ┆ ":  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ati ┆ "Br │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ o": ┆ onz │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ e   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ \u2 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "pa ┆ 014 │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ ss" ┆ Rid │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ :   ┆ eFl │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ ow  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l,  ┆ Rid │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "th ┆ er  │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ res ┆ Pro │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ hol ┆ fil │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ d": ┆ es" │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ nul ┆ ,   │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ l}, ┆ "co │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ "ro ┆ ntr │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ w_c ┆ act │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ oun ┆ _ve │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ t": ┆ rsi │
# │     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆     ┆ {"… ┆ on… │
# └─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┴─────┘

# %% [markdown]
# ---
# ## Step 9 · 🚗 Launch Live Dashboard
#
# The payoff! A real-time Panel dashboard that auto-refreshes from the Silver Delta tables every 3 seconds.
#
# **5 Analytical Views:**
# - 📈 Trip Volume Timeline (with Hour / Day / Week / Month aggregation)
# - ⭐ Top 10 Drivers by Revenue (cross-table join with driver profiles)
# - 🏙️ Revenue by City
# - 👍 Driver Quality Distribution
# - ⚡ Surge Multiplier Profile
#
# > **Tip:** Use `dashboard.show()` to pop the dashboard out into a full browser tab for the best experience.

# %%
import importlib
import assets.dashboards.shared.streaming_dashboard
importlib.reload(assets.dashboards.shared.streaming_dashboard)
# Out:
# <module 'assets.dashboards.shared.streaming_dashboard' from 'c:\\_Personal\\_SaaS\\lakelogic\\examples\\colab\\assets\\dashboards\\shared\\streaming_dashboard.py'>

# %%
sys.path.insert(0, ".")
from assets.dashboards.shared.streaming_dashboard import create_streaming_dashboard_inline

dashboard = create_streaming_dashboard_inline(
    lakehouse_root=str(LAKEHOUSE),
    domain=registry.domain,
    system=registry.system,
    refresh_ms=3000,
)
dashboard
# Out:
# %opts magic unavailable (pyparsing cannot be imported)
# %compositor magic unavailable (pyparsing cannot be imported)
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='3dbdbc3e-0577-4766-9a10-8f5cdb9d8f2c'>
#   <div id="a871c752-7fe0-4e00-9f5c-3c6159029ed5" data-root-id="3dbdbc3e-0577-4766-9a10-8f5cdb9d8f2c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"d67399f1-4483-419e-bdbb-4ad5d1c5175a":{"version":"3.9.0","title":"Bokeh Application","config":{"type":"object","name":"DocumentConfig","id":"be9462e5-c8cd-44d2-8f85-932392fa9a1f","attributes":{"notifications":{"type":"object","name":"Notifications","id":"7c7a791a-73cb-40e9-b6de-5fdd4b10947c"}}},"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"3dbdbc3e-0577-4766-9a10-8f5cdb9d8f2c"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"615fef02-1667-471d-bb10-3f2c0d92e4cd","attributes":{"plot_id":"3dbdbc3e-0577-4766-9a10-8f5cdb9d8f2c","comm_id":"43a5bdab042f4fbebda2e12bf12be7fd","client_comm_id":"0203e57e4ecd42c49c480cb7bb198b5e"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"start","kind":"Any","default":0},{"name":"end","kind":"Any","default":100},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"ReactiveESM1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"JSComponent1","properties":[{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"ReactComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"AnyWidgetComponent1","properties":[{"name":"use_shadow_dom","kind":"Any","default":true},{"name":"esm_constants","kind":"Any","default":{"type":"map"}}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"max_notifications","kind":"Any","default":5},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"n ...
#   var render_items = [{"docid":"d67399f1-4483-419e-bdbb-4ad5d1c5175a","roots":{"3dbdbc3e-0577-4766-9a10-8f5cdb9d8f2c":"a871c752-7fe0-4e00-9f5c-3c6159029ed5"},"root_ids":["3dbdbc3e-0577-4766-9a10-8f5cdb9d8f2c"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(version);
#     } else if (root.Bokeh.version === version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined && ( root.Tabulator !== undefined) && ( root.Tabulator !== undefined))
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#   > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
# ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# BokehModel(combine_events=True, render_bundle={'docs_json': {'a2d49c8b-2f77-488e-b8aa-e846129c3d99': {'version…

# %% [markdown]
# ---
# ## Step 10 · 🦆 Build Local DuckDB Catalog
#
# Create a persistent `lakehouse_catalog.duckdb` file that maps all your Delta tables as SQL views.
# Open this file in **DBeaver** (DuckDB driver) to browse and query your entire lakehouse with standard SQL.
#
# ```sql
# -- Once opened in DBeaver, just run:
# SELECT * FROM silver_trips WHERE city_code = 'LON' LIMIT 100;
# ```

# %%
import duckdb

catalog_path = str(LAKEHOUSE / f"lakehouse_catalog_{registry.domain}.duckdb")
con = duckdb.connect(catalog_path)

con.execute("INSTALL delta; LOAD delta;")

# Build views for every Delta table in the lakehouse
domain_root = LAKEHOUSE / registry.domain
for layer in ["bronze", "silver", "gold", "quarantine", "_logs"]:
    layer_path = domain_root / layer
    if not layer_path.exists():
        continue
    for table_dir in sorted(layer_path.iterdir()):
        if table_dir.is_dir() and not table_dir.name.startswith("_"):
            view_name = table_dir.name
            try:
                con.execute(f"CREATE OR REPLACE VIEW {view_name} AS SELECT * FROM delta_scan('{table_dir.as_posix()}')")
                row_count = con.execute(f"SELECT COUNT(*) FROM {view_name}").fetchone()[0]
                print(f"  ✅ {view_name}: {row_count:,} rows")
            except Exception as e:
                print(f"  ⚠️ {view_name}: {e}")

con.close()
print(f"\n🦆 Catalog saved → {catalog_path}")
print("   Open this file in DBeaver (DuckDB driver) to browse your lakehouse!")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[19], line 6
#       3 catalog_path = str(LAKEHOUSE / f"lakehouse_catalog_{registry.domain}.duckdb")
#       4 con = duckdb.connect(catalog_path)
# ----> 6 con.execute("INSTALL delta; LOAD delta;")
#       8 # Build views for every Delta table in the lakehouse
#       9 domain_root = LAKEHOUSE / registry.domain
#
# IOException: IO Error: Extension "C:\Users\colli\.duckdb\extensions\v1.4.4\windows_amd64\delta.duckdb_extension" could not be loaded: An Application Control policy has blocked this file.

# %% [markdown]
# ---
# ## 🔄 Bonus: Incremental Streaming Mode
#
# Re-run the simulator for additional windows and watch the dashboard update live.
# This simulates what would happen in production with Databricks Structured Streaming.

# %%
import time

if enable_incremental_streaming:

    # Generate 6 more hours of data, one window at a time with a pause
    EXTRA_WINDOWS = 6
    PAUSE_SECONDS = 2  # Pause between windows to see dashboard animate

    print(f"Streaming {EXTRA_WINDOWS} more windows...")
    for window in sim.run(num_windows=EXTRA_WINDOWS, include_seed=False, micro_batches=10, up_to=datetime.now(timezone.utc), resume=True):
        # Re-ingest the new window through Bronze → Silver
        for entity_name, row_count in window.entities.items():
            csv_path = window.files_written.get(entity_name, "")
            if not csv_path:
                continue

            new_df = pl.read_csv(csv_path, infer_schema_length=0)

            # Find the matching bronze contract
            matching = [c for c in bronze_contracts if c.entity == entity_name]
            if not matching:
                continue

            # Append to Bronze
            bronze_path = LAKEHOUSE / registry.domain / f"bronze_{registry.system}_{entity_name}"
            if bronze_path.exists():
                proc = ll.DataProcessor(matching[0].contract_dict, engine="polars")
                good, bad = proc.run(new_df)
                if len(good) > 0:
                    try:
                        good.write_delta(str(bronze_path), mode="append")
                    except Exception:
                        good.write_parquet(str(bronze_path / f"part-{window.index}.parquet"))

        # Refresh Silver trips (full re-process for simplicity)
        trip_bronze = LAKEHOUSE / registry.domain / f"bronze_{registry.system}_trip_completed"
        if trip_bronze.exists():
            trips_contract = [c for c in silver_contracts if "trips" in c.entity]
            if trips_contract:
                try:
                    source = pl.read_delta(str(trip_bronze))
                except Exception:
                    parquets = list(trip_bronze.rglob("*.parquet"))
                    source = pl.concat([pl.read_parquet(p) for p in parquets]) if parquets else None
                if source is not None:
                    proc = ll.DataProcessor(trips_contract[0].contract_dict, engine="polars")
                    good, _ = proc.run(source)
                    silver_out = LAKEHOUSE / registry.domain / "silver_rideflow_trips"
                    try:
                        good.write_delta(str(silver_out), mode="overwrite")
                    except Exception:
                        good.write_parquet(str(silver_out / "part-0.parquet"))

        print(f"  Window {window.index}: +{window.total_rows:,} rows → dashboard refreshing...")
        time.sleep(PAUSE_SECONDS)

    print(f"\n✅ Incremental streaming complete — check the dashboard above!")

# %% [markdown]
# ---
# ## ✅ Data Products Published
#
# This domain pipeline has successfully generated and published the following data products to the shared lakehouse:
#
# | Data Product | Consumers |
# | :-- | :-- |
# | `silver_rideflow_trips` | Payments (reconciliation), Operations (support enrichment) |
# | `silver_rideflow_driver_profiles` | Operations (background checks), Marketing (attribution) |
# | `gold_rideflow_trip_kpis` | Executive Dashboard, Mesh Products |
# | `gold_rideflow_rider_lifetime_value` | Marketing (LTV attribution), Finance (forecasting) |
#
# Other domain pipelines (`08_rideflow_payments`, `09_rideflow_operations`, `10_rideflow_marketing`) read from these outputs — never from our internal Bronze tables. This enforces clean Data Mesh boundaries.
#
# ### Next Notebooks
#
# - **`08_rideflow_payments.ipynb`** — Payments domain pipeline (Stripe charges, payouts, reconciliation)
# - **`12_compliance_gdpr_rtbf.ipynb`** — Execute a Right-to-Be-Forgotten request across all domains
# - **`14_data_mesh_dashboards.ipynb`** — Live observability across all domain pipelines
