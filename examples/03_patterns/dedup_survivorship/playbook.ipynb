# %% [markdown]
# # Dedup and Survivorship
# Keep the most recent record per customer and derive active status.

# %%
import os
from lakelogic import DataProcessor

os.environ["LAKELOGIC_ENGINE"] = "duckdb"

# %%
processor = DataProcessor(contract="contract.yaml")
good_df, bad_df = processor.run_source("data/customer_updates.csv")
processor.last_report

# %%
print("GOOD DATA")
print(good_df)

print("BAD DATA")
print(bad_df)
