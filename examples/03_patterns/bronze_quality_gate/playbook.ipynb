# %% [markdown]
# # Bronze Quality Gate
# Validate raw signups, apply schema rules, and capture lineage before data hits Silver.

# %%
import os
from lakeguard import DataProcessor

os.environ["LAKEGUARD_ENGINE"] = "polars"

# %%
processor = DataProcessor(contract="contract.yaml")
good_df, bad_df = processor.run_source("data/raw_signups.csv")
processor.last_report

# %%
print("GOOD DATA")
print(good_df)

print("BAD DATA")
print(bad_df)
