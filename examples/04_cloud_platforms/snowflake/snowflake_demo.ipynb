# %% [markdown]
# # Snowflake
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/04_cloud_platforms/snowflake/snowflake_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/04_cloud_platforms/snowflake/snowflake_demo.ipynb)
#
# ## Business Scenario
#
# Snowflake hosts analytics and warehouse data. You need a standard ingestion and validation workflow.
#
# ## Value Proposition
#
# - Contract-driven schema enforcement
# - Consistent extraction and validation
# - Ready-to-load outputs
#
# ---
#
# ## Goals
#
# 1. Connect to Snowflake
# 2. Run validation with a contract
# 3. Inspect results

# %% [markdown]
# ## Step 1: Install Dependencies
#
# Install the required extras before running this example.

# %%
# !pip install "lakelogic[snowflake]"

# %% [markdown]
# ## Step 2: Review the Contract
#
# Open `snowflake_contract.yaml` to see the schema, source config, and quality rules.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract="snowflake_contract.yaml")
# processor.run()
