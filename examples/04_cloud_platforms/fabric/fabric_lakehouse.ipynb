# %% [markdown]
# # 🧪 Microsoft Fabric Lakehouse Integration
#
# This notebook demonstrates how to interact with Microsoft Fabric OneLake using a LakeLogic YAML contract file.
#
# ---
#
# ## 🎯 Goals
#
# 1. Connect to Microsoft Fabric Lakehouse
# 2. Execute extraction using `fabric_contract.yaml` directly
# 3. Use Azure AD transparent authentication

# %% [markdown]
# ## 🚀 Setup
#
# Install Azure dependencies.

# %%
# !pip install "lakelogic[azure]"

# %% [markdown]
# ## 📝 Configuration
#
# Set the Fabric connection parameters used by the YAML contract.

# %%
import os

os.environ["FABRIC_ENDPOINT"] = "your-workspace.datawarehouse.pbidedicated.windows.net"
os.environ["LAKEHOUSE_NAME"] = "YourLakehouseName"

# %% [markdown]
# ## ▶️ Run the Extraction
#
# Specify the YAML path directly in the `DataProcessor`.

# %%
from lakelogic.core.processor import DataProcessor

print("🚀 Executing contract: fabric_contract.yaml")

# processor = DataProcessor(contract="fabric_contract.yaml")
# result = processor.run()

print("\n✅ Fabric example setup complete. Add actual endpoint and run!")
