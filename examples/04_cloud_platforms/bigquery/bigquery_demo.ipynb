# %% [markdown]
# # BigQuery
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/04_cloud_platforms/bigquery/bigquery_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/04_cloud_platforms/bigquery/bigquery_demo.ipynb)
#
# ## Business Scenario
#
# BigQuery is used for large-scale analytics. You need validated ingestion and repeatable contracts.
#
# ## Value Proposition
#
# - Contract-based schema enforcement
# - Consistent BigQuery extraction
# - Clean outputs for downstream use
#
# ---
#
# ## Goals
#
# 1. Connect to BigQuery
# 2. Validate data with a contract
# 3. Review outputs

# %% [markdown]
# ## Step 1: Install Dependencies
#
# Install the required extras before running this example.

# %%
# !pip install "lakelogic[bigquery]"

# %% [markdown]
# ## Step 2: Review the Contract
#
# Open `bigquery_contract.yaml` to see the schema, source config, and quality rules.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract="bigquery_contract.yaml")
# processor.run()
