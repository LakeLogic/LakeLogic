# %% [markdown]
# # CSV Ingestion
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/files/csv/csv_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/files/csv/csv_demo.ipynb)
#
# ## Business Scenario
#
# CSV drops are common for partner feeds and exports. You need schema validation before loading them.
#
# ## Value Proposition
#
# - Define CSV schema in YAML
# - Validate rows on ingestion
# - Produce clean outputs
#
# ---
#
# ## Goals
#
# 1. Load a CSV file
# 2. Validate against contract
# 3. Inspect results

# %% [markdown]
# ## Step 2: Review the Contract
#
# Open `csv_contract.yaml` to see the schema, source config, and quality rules.

# %% [markdown]
# ## Step 3: Run the Contract
#
# Run LakeLogic using the YAML contract. Update credentials as needed.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract="csv_contract.yaml")
# processor.run()
