# %% [markdown]
# # Delta Ingestion
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/files/delta/delta_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/files/delta/delta_demo.ipynb)
#
# ## Business Scenario
#
# Delta tables are common in lakehouses. You need validation and rule enforcement before downstream use.
#
# ## Value Proposition
#
# - Validate Delta inputs
# - Apply quality rules
# - Standardize outputs
#
# ---
#
# ## Goals
#
# 1. Read from Delta
# 2. Validate using contract
# 3. Review results

# %% [markdown]
# ## Step 1: Install Dependencies
#
# Install the required extras before running this example.

# %%
# !pip install "lakelogic[delta]"

# %% [markdown]
# ## Step 2: Review the Contract
#
# Open `delta_contract.yaml` to see the schema, source config, and quality rules.

# %% [markdown]
# ## Step 3: Run the Contract
#
# Run LakeLogic using the YAML contract. Update credentials as needed.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract="delta_contract.yaml")
# processor.run()
