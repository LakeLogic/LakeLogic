# %% [markdown]
# # SQLite Extraction
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/databases/sqlite/sqlite_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/databases/sqlite/sqlite_demo.ipynb)
#
# ## Business Scenario
#
# Local SQLite databases are common in prototypes and edge apps. You need a quick extraction flow.
#
# ## Value Proposition
#
# - Minimal setup for local extraction
# - Contract-based schema enforcement
# - Simple validation for small datasets
#
# ---
#
# ## Goals
#
# 1. Define a SQLite contract
# 2. Run extraction
# 3. Validate output

# %% [markdown]
# ## Step 2: Review the Contract
#
# Open `sqlite_contract.yaml` to see the schema, source config, and quality rules.

# %% [markdown]
# ## Step 3: Run the Contract
#
# Run LakeLogic using the YAML contract. Update credentials as needed.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract="sqlite_contract.yaml")
# processor.run()
