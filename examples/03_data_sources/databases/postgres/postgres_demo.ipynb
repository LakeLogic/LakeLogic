# %% [markdown]
# # Postgres Extraction
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/databases/postgres/postgres_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/databases/postgres/postgres_demo.ipynb)
#
# ## Business Scenario
#
# Postgres powers many product databases. You need a fast, repeatable extraction path.
#
# ## Value Proposition
#
# - Contract-driven extraction
# - Schema validation at ingestion
# - Simple setup for local or cloud Postgres
#
# ---
#
# ## Goals
#
# 1. Configure Postgres connection
# 2. Run extraction
# 3. Validate results

# %% [markdown]
# ## Step 1: Install Dependencies
#
# Install the required extras before running this example.

# %%
# !pip install "lakelogic[postgresql]"

# %% [markdown]
# ## Step 2: Review the Contract
#
# Open `postgres_contract.yaml` to see the schema, source config, and quality rules.

# %% [markdown]
# ## Step 3: Run the Contract
#
# Run LakeLogic using the YAML contract. Update credentials as needed.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract="postgres_contract.yaml")
# processor.run()
