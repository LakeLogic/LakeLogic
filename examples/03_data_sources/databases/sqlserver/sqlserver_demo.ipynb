# %% [markdown]
# # SQL Server Extraction
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/databases/sqlserver/sqlserver_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/03_data_sources/databases/sqlserver/sqlserver_demo.ipynb)
#
# ## Business Scenario
#
# On-prem SQL Server stores critical operational data. You need a standard extraction path into your lakehouse.
#
# ## Value Proposition
#
# - Standardized SQL Server extraction
# - Schema validation via contract
# - Consistent outputs for downstream jobs
#
# ---
#
# ## Goals
#
# 1. Connect to SQL Server
# 2. Run extraction using contract
# 3. Review validated data

# %% [markdown]
# ## Step 1: Install Dependencies
#
# Install the required extras before running this example.

# %%
# !pip install "lakelogic[sqlserver]"

# %% [markdown]
# ## Step 2: Review the Contract
#
# Open `sqlserver_contract.yaml` to see the schema, source config, and quality rules.

# %% [markdown]
# ## Step 3: Run the Contract
#
# Run LakeLogic using the YAML contract. Update credentials as needed.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract="sqlserver_contract.yaml")
# processor.run()
