# %% [markdown]
# # Dagster Orchestration
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/05_orchestration/dagster/dagster_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/05_orchestration/dagster/dagster_demo.ipynb)
#
# ## Business Scenario
#
# Dagster is used for asset-driven pipelines. You need a template that runs LakeLogic with clear lineage and observability.
#
# ## Value Proposition
#
# - Asset-driven orchestration
# - Structured logs and metadata
# - Registry-driven pipeline runs
#
# ---
#
# ## Goals
#
# 1. Configure a Dagster job
# 2. Run LakeLogic via the driver
# 3. Inspect run metadata

# %% [markdown]
# ## Step 1: Review the Template
#
# These files define the orchestration configuration:
#
# - dagster_job.yaml

# %% [markdown]
# ## Step 2: Configure Registry and Environment
#
# Set registry path, secrets, and storage destinations for your environment.

# %%
# Example driver call
lakelogic_driver_cmd = (
    'lakelogic-driver --registry contracts/_registry.yaml '
    '--layers bronze,silver --summary-path output/run_summary.json'
)
print(lakelogic_driver_cmd)

# %% [markdown]
# ## Step 3: Deploy
#
# Apply the template in your orchestration platform and monitor runs.
