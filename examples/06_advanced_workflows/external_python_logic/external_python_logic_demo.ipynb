# %% [markdown]
# # External Python Logic
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/06_advanced_workflows/external_python_logic/external_python_logic_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/06_advanced_workflows/external_python_logic/external_python_logic_demo.ipynb)
#
# ## Business Scenario
#
# Some workflows require custom Python transformations beyond declarative YAML. You need a governed way to plug in custom logic.
#
# ## Value Proposition
#
# - Extend LakeLogic with external logic
# - Keep validation and schema enforcement
# - Reuse contracts across environments
#
# ---
#
# ## Goals
#
# 1. Review external logic contracts
# 2. Run the contract
# 3. Inspect Gold outputs

# %% [markdown]
# ## Step 1: Review the Contracts
#
# This example uses external logic contracts:
#
# - contract_notebook.yaml
# - contract_python.yaml

# %% [markdown]
# ## Step 2: Run the Contract
#
# Choose one contract and run it using the LakeLogic driver.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract='contract_notebook.yaml')
# processor.run()
