# %% [markdown]
# # Contract Template (CI/CD)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/LineageLogic/LakeLogic/blob/main/examples/07_production/ci_cd/contract_template/contract_template_demo.ipynb)
# [![GitHub Repo](https://img.shields.io/badge/GitHub-Repo-blue?logo=github)](https://github.com/LineageLogic/LakeLogic/blob/main/examples/07_production/ci_cd/contract_template/contract_template_demo.ipynb)
#
# ## Business Scenario
#
# Production teams need standardized contracts that pass CI checks before deployment.
#
# ## Value Proposition
#
# - Production-ready contract skeleton
# - CI-friendly validation rules
# - Reusable template for new datasets
#
# ---
#
# ## Goals
#
# 1. Review the template contract
# 2. Validate with LakeLogic
# 3. Integrate into CI

# %% [markdown]
# ## Step 1: Review contract.yaml
#
# Open contract.yaml for the full production-ready template.

# %%
from lakelogic import DataProcessor

processor = DataProcessor(contract='contract.yaml')
# processor.run('data/customers.csv')
